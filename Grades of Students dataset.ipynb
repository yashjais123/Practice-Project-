# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Grades.csv')
data.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
#Lets check the shape of dataset
data.shape
# Out:
# (571, 43)

# %% [raw]
#  So , here we have 571 rows and 43 columns

# %% [markdown]
# # Data is Duplicated ?

# %%
data.duplicated().sum()
# Out:
# 0

# %% [raw]
# so,  here we have 0 Duplicated Data

# %%
#Lets check the data type of dataset
data.dtypes
# Out:
# Seat No.      object
# PH-121        object
# HS-101        object
# CY-105        object
# HS-105/12     object
# MT-111        object
# CS-105        object
# CS-106        object
# EL-102        object
# EE-119        object
# ME-107        object
# CS-107        object
# HS-205/20     object
# MT-222        object
# EE-222        object
# MT-224        object
# CS-210        object
# CS-211        object
# CS-203        object
# CS-214        object
# EE-217        object
# CS-212        object
# CS-215        object
# MT-331        object
# EF-303        object
# HS-304        object
# CS-301        object
# CS-302        object
# TC-383        object
# MT-442        object
# EL-332        object
# CS-318        object
# CS-306        object
# CS-312        object
# CS-317        object
# CS-403        object
# CS-421        object
# CS-406        object
# CS-414        object
# CS-419        object
# CS-423        object
# CS-412        object
# CGPA         float64
# ...

# %% [raw]
# so here we have

# %% [raw]
# Object type - All the Features columns

# %% [raw]
# Float Type - only Label column

# %%
#Lets Discribe the dataset 
data.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
data.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
#Lets plot PH-121 data .Using count plot
sns.countplot(x='PH-121',data=data)
plt.show()
data['PH-121'].value_counts()
# Out:
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64

# %%
#Lets plot HS-101 data .Using count plot
sns.countplot(x='HS-101',data=data)
plt.show()
data['HS-101'].value_counts()
# Out:
# A-    82
# B-    78
# C     68
# B     63
# B+    59
# C-    50
# C+    47
# D     45
# A     38
# D+    36
# A+     4
# F      1
# Name: HS-101, dtype: int64

# %%
#Lets plot CY-105 data .Using count plot
sns.countplot(x='CY-105',data=data)
plt.show()
data['CY-105'].value_counts()
# Out:
# A     177
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# F       1
# Name: CY-105, dtype: int64

# %%
#Lets plot HS-105/12 data .Using count plot
sns.countplot(x='HS-105/12',data=data)
plt.show()
data['HS-105/12'].value_counts()
# Out:
# A     96
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# F      1
# Name: HS-105/12, dtype: int64

# %%
#Lets plot CY-105 data .Using count plot
sns.countplot(x='MT-111',data=data)
plt.show()
data['MT-111'].value_counts()
# Out:
# A-    105
# A     100
# B-     70
# B+     62
# B      55
# C-     39
# C+     33
# C      30
# D      26
# A+     23
# D+     21
# WU      3
# F       2
# Name: MT-111, dtype: int64

# %%
#Lets plot CS-105 data .Using count plot
sns.countplot(x='CS-105',data=data)
plt.show()
data['CS-105'].value_counts()
# Out:
# A     151
# A-    134
# B+     60
# B      51
# A+     43
# B-     38
# C+     23
# C      22
# C-     22
# D+     15
# D      12
# Name: CS-105, dtype: int64

# %%
#Lets plot CS-106 data .Using count plot
sns.countplot(x='CS-106',data=data)
plt.show()
data['CS-106'].value_counts()
# Out:
# A-    116
# B+    101
# B      96
# A      56
# B-     54
# C+     41
# D+     29
# C-     27
# D      24
# C      18
# A+      4
# WU      2
# F       1
# Name: CS-106, dtype: int64

# %%
#Lets plot EL-102 data .Using count plot
sns.countplot(x='EL-102',data=data)
plt.show()
data['EL-102'].value_counts()
# Out:
# A-    105
# A      92
# B+     69
# B      59
# B-     53
# D      38
# C+     35
# C-     32
# C      30
# A+     29
# D+     23
# WU      3
# F       1
# Name: EL-102, dtype: int64

# %%
#Lets plot EE-119 data .Using count plot
sns.countplot(x='EE-119',data=data)
plt.show()
data['EE-119'].value_counts()
# Out:
# A-    137
# B+     83
# B      77
# A      68
# B-     48
# C      48
# C+     38
# D+     26
# C-     26
# D      11
# A+      6
# WU      1
# Name: EE-119, dtype: int64

# %%
#Lets plot ME-107 data .Using count plot
sns.countplot(x='ME-107',data=data)
plt.show()
data['ME-107'].value_counts()
# Out:
# A-    79
# A     77
# B+    68
# D     56
# B-    56
# B     50
# C     49
# C-    48
# C+    37
# D+    37
# A+     8
# WU     2
# F      2
# Name: ME-107, dtype: int64

# %%
#Lets plot CS-107 data .Using count plot
sns.countplot(x='CS-107',data=data)
plt.show()
data['CS-107'].value_counts()
# Out:
# A     105
# A-     81
# B+     57
# B      55
# C-     49
# B-     43
# A+     42
# D      38
# C+     34
# D+     31
# C      30
# WU      2
# I       1
# F       1
# Name: CS-107, dtype: int64

# %%
#Lets plot HS-205/20 data .Using count plot
sns.countplot(x='HS-205/20',data=data)
plt.show()
data['HS-205/20'].value_counts()
# Out:
# A-    150
# A     118
# B      97
# B+     89
# B-     36
# C+     33
# C      15
# C-     11
# D+      9
# D       3
# A+      2
# F       2
# WU      1
# Name: HS-205/20, dtype: int64

# %%
#Lets plot MT-222 data .Using count plot
sns.countplot(x='MT-222',data=data)
plt.show()
data['MT-222'].value_counts()
# Out:
# A-    86
# A     80
# D     66
# B     61
# B-    52
# D+    46
# C     43
# B+    42
# C+    39
# C-    30
# A+    16
# F      3
# WU     1
# W      1
# Name: MT-222, dtype: int64

# %%
#Lets plot  EE-222 data .Using count plot
sns.countplot(x='EE-222',data=data)
plt.show()
data['EE-222'].value_counts()
# Out:
# A     122
# A-    121
# B+     65
# B      53
# C      39
# B-     35
# A+     32
# C+     29
# D      25
# D+     21
# C-     16
# F       4
# W       2
# Name: EE-222, dtype: int64

# %%
#Lets plot  MT-224 data .Using count plot
sns.countplot(x='MT-224',data=data)
plt.show()
data['MT-224'].value_counts()
# Out:
# A-    120
# A      80
# B+     65
# B      57
# B-     49
# C-     43
# C+     39
# D+     37
# D      31
# C      30
# A+     10
# WU      1
# W       1
# F       1
# Name: MT-224, dtype: int64

# %%
#Lets plot  CS-210 data .Using count plot
sns.countplot(x='CS-210',data=data)
plt.show()
data['CS-210'].value_counts()
# Out:
# A-    133
# A     101
# B+     84
# B      59
# B-     58
# C      30
# C+     27
# C-     24
# D+     21
# D      12
# A+     12
# WU      1
# W       1
# F       1
# Name: CS-210, dtype: int64

# %%
#Lets plot  CS-211 data .Using count plot
sns.countplot(x='CS-211',data=data)
plt.show()
data['CS-211'].value_counts()
# Out:
# A-    68
# A     67
# B-    60
# D+    56
# B+    56
# B     56
# C+    55
# C-    50
# C     39
# D     33
# A+    21
# F      3
# WU     1
# W      1
# Name: CS-211, dtype: int64

# %%
data.columns
# Out:
# Index(['Seat No.', 'PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111',
#        'CS-105', 'CS-106', 'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20',
#        'MT-222', 'EE-222', 'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214',
#        'EE-217', 'CS-212', 'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301',
#        'CS-302', 'TC-383', 'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312',
#        'CS-317', 'CS-403', 'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423',
#        'CS-412', 'CGPA'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# # fill the NULL Vales

# %%
data['CS-412']=data['CS-412'].fillna(data['CS-412'].mode()[0])
data['CS-423']=data['CS-423'].fillna(data['CS-423'].mode()[0])
data['CS-419']=data['CS-419'].fillna(data['CS-419'].mode()[0])
data['CS-414']=data['CS-414'].fillna(data['CS-414'].mode()[0])
data['CS-406']=data['CS-406'].fillna(data['CS-406'].mode()[0])
data['CS-421']=data['CS-421'].fillna(data['CS-421'].mode()[0])
data['CS-403']=data['CS-403'].fillna(data['CS-403'].mode()[0])
data['CS-317']=data['CS-317'].fillna(data['CS-317'].mode()[0])
data['CS-312']=data['CS-312'].fillna(data['CS-312'].mode()[0])

# %%
data['CS-306']=data['CS-306'].fillna(data['CS-306'].mode()[0])
data['CS-318']=data['CS-318'].fillna(data['CS-318'].mode()[0])
data['EL-332']=data['EL-332'].fillna(data['EL-332'].mode()[0])
data['MT-442']=data['MT-442'].fillna(data['MT-442'].mode()[0])
data['TC-383']=data['TC-383'].fillna(data['TC-383'].mode()[0])
data['CS-302']=data['CS-302'].fillna(data['CS-302'].mode()[0])
data['CS-301']=data['CS-301'].fillna(data['CS-301'].mode()[0])
data['HS-304']=data['HS-304'].fillna(data['HS-304'].mode()[0])
data['EF-303']=data['EF-303'].fillna(data['EF-303'].mode()[0])

# %%
data['CY-105']=data['CY-105'].fillna(data['CY-105'].mode()[0])
data['HS-105/12']=data['HS-105/12'].fillna(data['HS-105/12'].mode()[0])
data['MT-111']=data['MT-111'].fillna(data['MT-111'].mode()[0])
data['CS-106']=data['CS-106'].fillna(data['CS-106'].mode()[0])
data['EL-102']=data['EL-102'].fillna(data['EL-102'].mode()[0])
data['EE-119']=data['EE-119'].fillna(data['EE-119'].mode()[0])
data['ME-107']=data['ME-107'].fillna(data['ME-107'].mode()[0])
data['CS-107']=data['CS-107'].fillna(data['CS-107'].mode()[0])
data['HS-205/20']=data['HS-205/20'].fillna(data['HS-205/20'].mode()[0])
data['MT-222']=data['MT-222'].fillna(data['MT-222'].mode()[0])
data['EE-222']=data['EE-222'].fillna(data['EE-222'].mode()[0])

# %%
data['MT-224']=data['MT-224'].fillna(data['MT-224'].mode()[0])
data['CS-210']=data['CS-210'].fillna(data['CS-210'].mode()[0])
data['CS-211']=data['CS-211'].fillna(data['CS-211'].mode()[0])
data['CS-203']=data['CS-203'].fillna(data['CS-203'].mode()[0])
data['CS-214']=data['CS-214'].fillna(data['CS-214'].mode()[0])
data['EE-217']=data['EE-217'].fillna(data['EE-217'].mode()[0])
data['CS-212']=data['CS-212'].fillna(data['CS-212'].mode()[0])
data['CS-215']=data['CS-215'].fillna(data['CS-215'].mode()[0])

# %%
data['MT-331']=data['MT-331'].fillna(data['MT-331'].mode()[0])

# %% [markdown]
# # converting categorical feature to Numerical

# %% [markdown]
# # Using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
df2 = lab_enc.fit_transform(data['PH-121'])
pd.Series(df2)
# Out:
# 0      5
# 1      0
# 2      0
# 3      9
# 4      2
#       ..
# 566    3
# 567    1
# 568    3
# 569    0
# 570    6
# Length: 571, dtype: int32

# %%
data['PH-121']=df2

# %%
df2 = lab_enc.fit_transform(data['HS-101'])
pd.Series(df2)
# Out:
# 0      10
# 1       9
# 2       3
# 3       7
# 4       2
#        ..
# 566     0
# 567     0
# 568     0
# 569     4
# 570     9
# Length: 571, dtype: int32

# %%
data['HS-101']=df2

# %%
df2 = lab_enc.fit_transform(data['CY-105'])
pd.Series(df2)
data['CY-105']=df2

# %%
df2 = lab_enc.fit_transform(data['HS-105/12'])
pd.Series(df2)
data['HS-105/12']=df2

# %%
df2 = lab_enc.fit_transform(data['MT-111'])
pd.Series(df2)
data['MT-111']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-105'])
pd.Series(df2)
data['CS-105']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-106'])
pd.Series(df2)
data['CS-106']=df2

# %%
df2 = lab_enc.fit_transform(data['EL-102'])
pd.Series(df2)
data['EL-102']=df2

# %%
df2 = lab_enc.fit_transform(data['EE-119'])
pd.Series(df2)
data['EE-119']=df2

# %%
df2 = lab_enc.fit_transform(data['ME-107'])
pd.Series(df2)
data['ME-107']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-107'])
pd.Series(df2)
data['CS-107']=df2

# %%
df2 = lab_enc.fit_transform(data['HS-205/20'])
pd.Series(df2)
data['HS-205/20']=df2

# %%
df2 = lab_enc.fit_transform(data['MT-222'])
pd.Series(df2)
data['MT-222']=df2

# %%
df2 = lab_enc.fit_transform(data['EE-222'])
pd.Series(df2)
data['EE-222']=df2

# %%
df2 = lab_enc.fit_transform(data['MT-224'])
pd.Series(df2)
data['MT-224']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-210'])
pd.Series(df2)
data['CS-210']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-211'])
pd.Series(df2)
data['CS-211']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-203'])
pd.Series(df2)
data['CS-203']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-214'])
pd.Series(df2)
data['CS-214']=df2

# %%
df2 = lab_enc.fit_transform(data['EE-217'])
pd.Series(df2)
data['EE-217']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-212'])
pd.Series(df2)
data['CS-212']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-215'])
pd.Series(df2)
data['CS-215']=df2

# %%
df2 = lab_enc.fit_transform(data['MT-331'])
pd.Series(df2)
data['MT-331']=df2

# %%
df2 = lab_enc.fit_transform(data['EF-303'])
pd.Series(df2)
data['EF-303']=df2

# %%
df2 = lab_enc.fit_transform(data['HS-304'])
pd.Series(df2)
data['HS-304']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-301'])
pd.Series(df2)
data['CS-301']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-302'])
pd.Series(df2)
data['CS-302']=df2

# %%
df2 = lab_enc.fit_transform(data['TC-383'])
pd.Series(df2)
data['TC-383']=df2

# %%
df2 = lab_enc.fit_transform(data['MT-442'])
pd.Series(df2)
data['MT-442']=df2

# %%
df2 = lab_enc.fit_transform(data['EL-332'])
pd.Series(df2)
data['EL-332']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-318'])
pd.Series(df2)
data['CS-318']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-306'])
pd.Series(df2)
data['CS-306']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-312'])
pd.Series(df2)
data['CS-312']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-317'])
pd.Series(df2)
data['CS-317']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-403'])
pd.Series(df2)
data['CS-403']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-421'])
pd.Series(df2)
data['CS-421']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-406'])
pd.Series(df2)
data['CS-406']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-414'])
pd.Series(df2)
data['CS-414']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-419'])
pd.Series(df2)
data['CS-419']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-423'])
pd.Series(df2)
data['CS-423']=df2

# %%
df2 = lab_enc.fit_transform(data['CS-412'])
pd.Series(df2)
data['CS-412']=df2

# %%
df2 = lab_enc.fit_transform(data['Seat No.'])
pd.Series(df2)
data['Seat No.']=df2

# %%
data
# Out:
#      Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0           0       5      10       8          6       8      10       9
# 1           1       0       9      10          9       5       6       9
# 2           2       0       3       0          5       4       0       5
# 3           3       9       7      10          9       9       2      10
# 4           4       2       2       2          4       0       0       2
# ..        ...     ...     ...     ...        ...     ...     ...     ...
# 566       566       3       0       0          2       1       0       2
# 567       567       1       0       0          0       0       0       0
# 568       568       3       0       2          4       0       0       0
# 569       569       0       4       9          0       9      10       5
# 570       570       6       9       9          6       6      10       3
#
#      EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# ...

# %%
data.dtypes
# Out:
# Seat No.       int32
# PH-121         int32
# HS-101         int32
# CY-105         int32
# HS-105/12      int32
# MT-111         int32
# CS-105         int32
# CS-106         int32
# EL-102         int32
# EE-119         int32
# ME-107         int32
# CS-107         int32
# HS-205/20      int32
# MT-222         int32
# EE-222         int32
# MT-224         int32
# CS-210         int32
# CS-211         int32
# CS-203         int32
# CS-214         int32
# EE-217         int32
# CS-212         int32
# CS-215         int32
# MT-331         int32
# EF-303         int32
# HS-304         int32
# CS-301         int32
# CS-302         int32
# TC-383         int32
# MT-442         int32
# EL-332         int32
# CS-318         int32
# CS-306         int32
# CS-312         int32
# CS-317         int32
# CS-403         int32
# CS-421         int32
# CS-406         int32
# CS-414         int32
# CS-419         int32
# CS-423         int32
# CS-412         int32
# CGPA         float64
# ...

# %% [markdown]
# # fill NAN Values

# %%
data.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [raw]
# * No Missing value

# %% [markdown]
# # EDA (Exploratory data analysis)
# # Basic Analysis with Visualisation

# %%
sns.relplot(x='PH-121',y='CGPA',data=data,kind='scatter')
plt.show()

# %% [markdown]
# # As the number of CGPA increase the PH-121 decrease ,We can clearly see that there is no relationship. in CGPA and PH column

# %%
sns.relplot(x='HS-101',y='CGPA',data=data,kind='scatter')
plt.show()

# %% [markdown]
# # We can clearly see that there is no relationship. in CGPA and HS column¶

# %%
sns.relplot(x='CY-105',y='CGPA',data=data,kind='scatter')
plt.show()

# %% [markdown]
# # We can clearly see that there is no relationship. in CGPA and CY column¶

# %%
sns.relplot(x='HS-105/12',y='CGPA',data=data,kind='scatter')
plt.show()

# %% [markdown]
# # We can clearly see that there is no relationship. in CGPA and HS column¶

# %%
sns.relplot(x='MT-111',y='CGPA',data=data,kind='scatter')
plt.show()

# %% [markdown]
# # We can clearly see that there is no relationship. in CGPA and MT column¶

# %%
sns.relplot(x='CS-105',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-106',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='EL-102',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='EE-119',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='ME-107',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-107',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='HS-205/20',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='MT-222',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='EE-222',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='MT-224',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-210',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-211',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-203',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-214',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='EE-217',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-212',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-215',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='MT-331',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='EF-303',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='HS-304',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-301',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-419',y='CGPA',data=data,kind='scatter')
plt.show()

# %%
sns.relplot(x='CS-412',y='CGPA',data=data,kind='scatter')
plt.show()

# %% [markdown]
# # We can clearly see that there is no relationship. in CGPA and All  column¶

# %%
data.shape
# Out:
# (571, 43)

# %%
plt.figure(figsize=(30,35))
plotnumber=1

for column in data:
    if plotnumber<=43:
        ax=plt.subplot(10,5,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Observation

# %% [markdown]
# # HS-101 - > HS-101 in noramlly Distributed
# # CS-210 - > CS-210 Is normal, We consider as noraml distributed
# # than ALl the columns are some outliers because we have the Normal
# # CGPA - > CGPA is our target column

# %%
plt.figure(figsize=(30,35))
plotnumber=1
for column in data:
    if plotnumber <=43:
        ax=plt.subplot(10,5,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column,fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# # First we have to check correlatiom before losing any data because we have small dataset .

# %%
plt.figure(figsize=(30,35))
sns.heatmap(data.corr(),annot=True,fmt='.2f',)
plt.show()

# %% [markdown]
# # Observations

# %%
#Lets check correlation with target columns
data.corr()['CGPA']
# Out:
# Seat No.     0.054342
# PH-121      -0.663135
# HS-101      -0.537170
# CY-105      -0.658282
# HS-105/12   -0.613989
# MT-111      -0.730095
# CS-105      -0.613169
# CS-106      -0.534995
# EL-102      -0.642262
# EE-119      -0.646829
# ME-107      -0.663023
# CS-107      -0.615309
# HS-205/20   -0.460525
# MT-222      -0.656320
# EE-222      -0.575335
# MT-224      -0.692696
# CS-210      -0.761468
# CS-211      -0.628070
# CS-203      -0.644191
# CS-214      -0.733848
# EE-217      -0.655993
# CS-212      -0.642878
# CS-215      -0.730460
# MT-331      -0.508428
# EF-303      -0.485478
# HS-304      -0.557912
# CS-301      -0.664117
# CS-302      -0.696112
# TC-383      -0.572329
# MT-442      -0.582592
# EL-332      -0.729609
# CS-318      -0.566393
# CS-306      -0.708299
# CS-312      -0.458019
# CS-317      -0.760792
# CS-403      -0.544543
# CS-421      -0.633001
# CS-406      -0.474419
# CS-414      -0.384003
# CS-419      -0.641804
# CS-423      -0.520968
# ...

# %% [raw]
# # As we seen before this code . almost same we get not.

# %% [markdown]
# # Dividing data in feature and vectors

# %%
x=data.drop(columns='CGPA')#Feature
y=data.CGPA#Target

# %%
#Lets import standardscaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[-1.7290201 ,  0.40040198,  1.77089951, ...,  1.74051347,
#         -0.34612103, -0.45017773],
#        [-1.72295336, -1.24205154,  1.4115592 , ...,  0.90041779,
#          0.72798282, -0.02104337],
#        [-1.71688662, -1.24205154, -0.74448263, ..., -1.61986925,
#         -0.70415565, -1.30844646],
#        ...,
#        [ 1.71688662, -0.25657943, -1.82250355, ...,  0.06032211,
#         -0.70415565, -0.45017773],
#        [ 1.72295336, -1.24205154, -0.38514232, ..., -0.35972573,
#          0.3699482 ,  1.26635973],
#        [ 1.7290201 ,  0.72889268,  1.4115592 , ...,  0.06032211,
#          1.80208667,  2.12462846]])

# %% [markdown]
# # Now use VIF for checking multicollinearity problem

# %% [raw]
# VIF - > Variance Inflation Factor

# %%
#Lets import VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i)for i in range(x_scaled.shape[1])]
vif['feature']=x.columns

# %%
#Lets check how lookinf VIF score
vif
# Out:
#          vif    feature
# 0   4.091578   Seat No.
# 1   2.829134     PH-121
# 2   1.781333     HS-101
# 3   2.554339     CY-105
# 4   2.369888  HS-105/12
# 5   2.680229     MT-111
# 6   2.366879     CS-105
# 7   1.932090     CS-106
# 8   1.969639     EL-102
# 9   2.191411     EE-119
# 10  2.340341     ME-107
# 11  2.366197     CS-107
# 12  1.675694  HS-205/20
# 13  2.277266     MT-222
# 14  2.311788     EE-222
# 15  2.801982     MT-224
# 16  3.138503     CS-210
# 17  2.640907     CS-211
# 18  2.644694     CS-203
# 19  2.688612     CS-214
# 20  2.445759     EE-217
# 21  2.775222     CS-212
# 22  3.027049     CS-215
# 23  2.080543     MT-331
# 24  2.156242     EF-303
# 25  2.499687     HS-304
# 26  3.097437     CS-301
# 27  2.742736     CS-302
# 28  2.966417     TC-383
# 29  2.031352     MT-442
# 30  3.280833     EL-332
# 31  2.474213     CS-318
# 32  3.534399     CS-306
# 33  3.336643     CS-312
# 34  3.161512     CS-317
# 35  2.599356     CS-403
# 36  2.905131     CS-421
# ...

# %% [markdown]
# # In VIF we consider threshold 5 VIF Score . if any feature is greater then 5 VIF Score it means it contains multicollinearity problmem/
#
# # So in our dataset no feature have more then 5 vif score . so it means out dataset is not contain any multicollinearity problem.

# %%
#lets do train test split
#Import train test split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.25,random_state=876)

# %% [markdown]
# # * LinearRegression

# %%
#Import Linear Regression
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_train,y_train)
# Out:
# 0.9205883525930736

# %%
reg.score(x_test,y_test)
# Out:
# 0.9537860918658697

# %% [markdown]
# # * Ridge Regularization

# %%
from sklearn.linear_model import Ridge,RidgeCV

# %%
ridgecv=RidgeCV(alphas=np.arange(0.001,0.1,0.01),normalize=True)

# %%
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.09099999999999998

# %%
ridge_model = Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.09099999999999998)

# %%
ridge_model.score(x_train,y_train)
# Out:
# 0.9205883438496316

# %%
ridge_model.score(x_test,y_test)
# Out:
# 0.9538112028113866

# %% [markdown]
# # * Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor()
tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
tree.score(x_train,y_train)
# Out:
# 1.0

# %%
tree.score(x_test,y_test)
# Out:
# 0.7971476604544889

# %% [markdown]
# # * AdaBoost

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada=AdaBoostRegressor()
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred = ada.predict(x_train)

# %%
from sklearn import metrics

# %%
accuracy = metrics.r2_score(y_train,y_pred)

print("R Square score",accuracy)
# Out:
# R Square score 0.9307179798252786

# %%
# predicting Test data with the model 
y_test_pred = ada.predict(x_test)

# %% [markdown]
# # * Model Evalution

# %%
accuracy = metrics.r2_score(y_test,y_test_pred)

print("R Squaree score:",accuracy)
# Out:
# R Squaree score: 0.8880312888108145

# %% [markdown]
# # * Hyperparameter Tuning Using RandomizedSearchCv

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params={'n_estimators':[47,50,60,70],'learning_rate':[0.25,0.30,0.40]}

rnd_srch = RandomizedSearchCV(AdaBoostRegressor(),cv=5,param_distributions = params)

rnd_srch.fit(x_train,y_train)

rnd_srch.best_estimator_

ada = AdaBoostRegressor(learning_rate=0.26,n_estimators=70)

ada.fit(x_train,y_train)

y_pred = ada.predict(x_test)

print("*** accuracy post tuning ***")
print(metrics.r2_score(y_test,y_pred))
# Out:
# *** accuracy post tuning ***
# 0.883600839913368

# %% [markdown]
# # Lets Save Our Model

# %%
import pickle
filename='Gradesstudents.'
pickle.dump(ada,open(filename,'wb'))

# %% [markdown]
# # Conclusion

# %%
loaded_model=pickle.load(open('Gradesstudents','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 88.36008399133681

# %%
# batch  No - ds0522
# Data Trained
