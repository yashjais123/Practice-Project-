# %% [markdown]
# # * Zomato Restaurant Project

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# # Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# # cuisines of every part of the world which lies in their budget. This analysis is also for those who
# # want to find the value for money restaurants in various parts of the country for the cuisines.
# # Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# # the country and which locality of that country serves that cuisines with maximum number of
# # restaurants.

# %% [markdown]
# # Data Storage:

# %% [markdown]
# # Problem statement : In this dataset predict 2 things –
# # 1) Average Cost for two
# # 2) Price range

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_excel(r"C:\Users\yjjai\Downloads\Country-Code.xlsx")

# %%
df2 = pd.read_csv(r"D:\New folder\zomato.csv",encoding="latin-1")

# %%
df=pd.merge(df1,df2)

# %%
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# 4                               Pinch Of Spice            Agra
# ...                                        ...             ...
# 9546                       The Screaming Eagle        Waterloo
# 9547                             The Thai Bowl        Waterloo
# 9548                Tokyo Japanese Steak House        Waterloo
# 9549  Theo Yianni's Authentic Greek Restaurant         Weirton
# 9550                 Fishpatrick's Crabby Cafe  Winchester Bay
#
#                                                 Address        Locality  \
# 0     E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...      Agra Cantt
# 1     E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...      Agra Cantt
# 2           Main Market, Sadar Bazaar, Agra Cantt, Agra      Agra Cantt
# 3     1/48, Delhi Gate, Station Road, Raja Mandi, Ci...     Civil Lines
# 4     23/453, Opposite Sanjay Cinema, Wazipura Road,...     Civil Lines
# ...                                                 ...             ...
# 9546                  228 E 4th St., Waterloo, IA 50703        Waterloo
# 9547            624 Sycamore Street, Waterloo, IA 50703        Waterloo
# 9548              1931 Sears Street, Waterloo, IA 50702        Waterloo
# 9549                322 American Way, Weirton, WV 26062         Weirton
# 9550        196 Bayfront Loop, Winchester Bay, OR 97467  Winchester Bay
#
#                     Locality Verbose   Longitude   Latitude  ...  \
# 0                   Agra Cantt, Agra   78.011544  27.161661  ...
# 1                   Agra Cantt, Agra    0.000000   0.000000  ...
# 2                   Agra Cantt, Agra   78.011608  27.160832  ...
# 3                  Civil Lines, Agra   77.998092  27.195928  ...
# 4                  Civil Lines, Agra   78.007553  27.201725  ...
# ...                              ...         ...        ...  ...
# 9546              Waterloo, Waterloo  -92.335523  42.498400  ...
# 9547              Waterloo, Waterloo  -92.335769  42.497919  ...
# 9548              Waterloo, Waterloo  -92.323400  42.465580  ...
# 9549                Weirton, Weirton  -80.529488  40.396043  ...
# 9550  Winchester Bay, Winchester Bay -124.175346  43.678998  ...
#
#                 Currency  Has Table booking Has Online delivery  \
# 0     Indian Rupees(Rs.)                 No                  No
# 1     Indian Rupees(Rs.)                 No                  No
# 2     Indian Rupees(Rs.)                 No                  No
# 3     Indian Rupees(Rs.)                 No                  No
# 4     Indian Rupees(Rs.)                 No                  No
# ...                  ...                ...                 ...
# 9546           Dollar($)                 No                  No
# 9547           Dollar($)                 No                  No
# 9548           Dollar($)                 No                  No
# 9549           Dollar($)                 No                  No
# 9550           Dollar($)                 No                  No
#
#      Is delivering now Switch to order menu Price range Aggregate rating  \
# 0                   No                   No           3              3.9
# 1                   No                   No           2              3.5
# 2                   No                   No           2              3.6
# 3                   No                   No           2              4.0
# 4                   No                   No           3              4.2
# ...                ...                  ...         ...              ...
# 9546                No                   No           1              3.7
# 9547                No                   No           1              3.5
# 9548                No                   No           2              3.9
# 9549                No                   No           2              3.9
# 9550                No                   No           2              3.2
#
#       Rating color  Rating text Votes
# 0           Yellow         Good   140
# 1           Yellow         Good    71
# 2           Yellow         Good    94
# 3            Green    Very Good    87
# 4            Green    Very Good   177
# ...            ...          ...   ...
# 9546        Yellow         Good   101
# 9547        Yellow         Good    58
# 9548        Yellow         Good   156
# 9549        Yellow         Good   156
# 9550        Orange      Average    16
#
# [9551 rows x 22 columns]

# %%
#Lets check the shape of dataset
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# So , here we have 9551 rows and 22 columns

# %% [markdown]
# # Data is Duplicated ?

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# so, here we have 0 Duplicated Data

# %%
#Lets check the data type of dataset
df.dtypes
# Out:
# Country Code              int64
# Country                  object
# Restaurant ID             int64
# Restaurant Name          object
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# so here we have
#
# float64 type - Aggregate rating ,Latitude , Longitude columns
#
# int64 type - Country Code , Restaurant ID , Average Cost for two , Price range , Votes columns
#
# Oject type - Than All columns are object columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   int64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
#  15  Is delivering now     9551 non-null   object
#  16  Switch to order menu  9551 non-null   object
#  17  Price range           9551 non-null   int64
#  18  Aggregate rating      9551 non-null   float64
#  19  Rating color          9551 non-null   object
#  20  Rating text           9551 non-null   object
#  21  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(5), object(14)
# memory usage: 1.7+ MB

# %%
# Missing values
df.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# 0 Null values are present

# %% [markdown]
# # value count Function

# %%
df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
df['Country Code'].value_counts()
# Out:
# 1      8652
# 216     434
# 215      80
# 30       60
# 189      60
# 214      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 166      20
# 184      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
df['Restaurant ID'].value_counts()
# Out:
# 3400025     1
# 309811      1
# 18460981    1
# 18287389    1
# 1629        1
#            ..
# 4096        1
# 18358700    1
# 2217        1
# 18398571    1
# 17559793    1
# Name: Restaurant ID, Length: 9551, dtype: int64

# %%
df['Restaurant Name'].value_counts()
# Out:
# Cafe Coffee Day                       83
# Domino's Pizza                        79
# Subway                                63
# Green Chick Chop                      51
# McDonald's                            48
#                                       ..
# Chor Bizarre - Hotel Broadway          1
# Thugs - Hotel Broadway                 1
# The Kylin Experience - Holiday Inn     1
# Cafe on 3 - Holiday Inn                1
# Fishpatrick's Crabby Cafe              1
# Name: Restaurant Name, Length: 7446, dtype: int64

# %%
df['City'].value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Vineland Station       1
# Yorkton                1
# Bandung                1
# Quezon City            1
# Winchester Bay         1
# Name: City, Length: 141, dtype: int64

# %%
df['Address'].value_counts()
# Out:
# Sector 41, Noida                                                                      11
# Dilli Haat, INA, New Delhi                                                            11
# Greater Kailash (GK) 1, New Delhi                                                     10
# The Imperial, Janpath, New Delhi                                                       9
# The Lalit, Barakhamba Avenue, Barakhamba Road, New Delhi                               8
#                                                                                       ..
# G-4, Local Shopping Complex, Gujranwala Town, New Delhi                                1
# State Bank Colony, Near Nanak Piau Gurudwara, GTK Road, Gujranwala Town, New Delhi     1
# Shop 6 & 7, DDA Market, Near Pentamed Hospital, Gujranwala Town, New Delhi             1
# A-199, Gujranwala Town, New Delhi                                                      1
# 196 Bayfront Loop, Winchester Bay, OR 97467                                            1
# Name: Address, Length: 8918, dtype: int64

# %%
df['Locality'].value_counts()
# Out:
# Connaught Place    122
# Rajouri Garden      99
# Shahdara            87
# Defence Colony      86
# Pitampura           85
#                   ...
# Waltair Uplands      1
# Armidale             1
# Balingup             1
# Beechworth           1
# Winchester Bay       1
# Name: Locality, Length: 1208, dtype: int64

# %%
df['Locality Verbose'].value_counts()
# Out:
# Connaught Place, New Delhi             122
# Rajouri Garden, New Delhi               99
# Shahdara, New Delhi                     87
# Defence Colony, New Delhi               86
# Pitampura, New Delhi                    85
#                                       ...
# Hotel Maurya, Lodipur, Patna             1
# Maurya Lok, Fraser Road Area, Patna      1
# Patliputra Colony, Patna                 1
# Heritage Town, Puducherry                1
# Winchester Bay, Winchester Bay           1
# Name: Locality Verbose, Length: 1265, dtype: int64

# %%
df['Longitude'].value_counts()
# Out:
#  0.000000      498
#  77.353663      19
#  77.230412      12
#  77.088688      10
#  77.251426       9
#               ...
#  77.303872       1
#  77.307939       1
#  77.299597       1
#  77.299004       1
# -124.175346      1
# Name: Longitude, Length: 8120, dtype: int64

# %%
df['Latitude'].value_counts()
# Out:
# 0.000000     498
# 28.574309     16
# 28.551456      9
# 28.574300      9
# 28.597103      8
#             ...
# 28.701519      1
# 28.699157      1
# 28.694336      1
# 28.699116      1
# 43.678998      1
# Name: Latitude, Length: 8677, dtype: int64

# %%
df['Cuisines'].value_counts()
# Out:
# North Indian                                 936
# North Indian, Chinese                        511
# Fast Food                                    354
# Chinese                                      354
# North Indian, Mughlai                        334
#                                             ...
# Cafe, Mexican, Continental                     1
# North Indian, Continental, Asian, Italian      1
# Continental, Cafe                              1
# North Indian, Biryani, Mughlai                 1
# Burger, Greek, Sandwich                        1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
df['Average Cost for two'].value_counts()
# Out:
# 500       900
# 300       897
# 400       857
# 200       687
# 600       652
#          ...
# 70000       1
# 165000      1
# 450000      1
# 120000      1
# 4300        1
# Name: Average Cost for two, Length: 140, dtype: int64

# %%
df['Currency'].value_counts()
# Out:
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(£)                  80
# Brazilian Real(R$)          60
# Rand(R)                     60
# Emirati Diram(AED)          60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64

# %%
df['Has Table booking'].value_counts()
# Out:
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64

# %%
df['Has Online delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %%
df['Is delivering now'].value_counts()
# Out:
# No     9517
# Yes      34
# Name: Is delivering now, dtype: int64

# %%
df['Switch to order menu'].value_counts()
# Out:
# No    9551
# Name: Switch to order menu, dtype: int64

# %%
df['Aggregate rating'].value_counts()
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
df['Rating text'].value_counts()
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %%
df['Rating color'].value_counts()
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64

# %% [markdown]
# # 0 To 11 columns are Continue columns
# # 12 To 20 columns are categorical columns

# %%
df.describe()
# Out:
#        Country Code  Restaurant ID    Longitude     Latitude  \
# count   9551.000000   9.551000e+03  9551.000000  9551.000000
# mean      18.365616   9.051128e+06    64.126574    25.854381
# std       56.750546   8.791521e+06    41.467058    11.007935
# min        1.000000   5.300000e+01  -157.948486   -41.330428
# 25%        1.000000   3.019625e+05    77.081343    28.478713
# 50%        1.000000   6.004089e+06    77.191964    28.570469
# 75%        1.000000   1.835229e+07    77.282006    28.642758
# max      216.000000   1.850065e+07   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %%
sns.countplot(x='Country Code',data=df)
plt.show()

# %% [markdown]
# * Whose are having 1 as country code they are having more count.

# %%
sns.countplot(x='Price range',data=df)
plt.show()

# %% [markdown]
# * We can see, Price range of 1 has maximum price range followed by 2.
# * All Price range are decreasing in order.

# %%
plt.figure(figsize=(7,5))
sns.countplot(y='Currency',data=df)
plt.show()

# %% [markdown]
# * We can see, Indian Rupees is most used currecny. It means that zomato has main business in India followed by Dollar.
# * Remaining all has no such used, it means zomato not functioning in that country as zomato does in India.

# %%
sns.countplot(x='Has Table booking',data=df)
plt.show()

# %% [markdown]
# * We can see, Zomato has not provivded the table booking. But in some place it provided table booking. May be their zomaato own its Restaurant.

# %%
sns.countplot(x='Has Online delivery',data=df)
plt.show()

# %% [markdown]
# * Most of places has no online delivery available.
# * But in few places has availabled online delivery.

# %%
#  Which countries do have online deliveries option
a=df[df['Has Online delivery']=='Yes'].Country.value_counts()

# %%
plt.figure(figsize=(7,5))
a.plot.pie(autopct = '%1.1f%%')
plt.title('Country has online delivery')
plt.show()

# %% [markdown]
# * we can see, India has 98.9% online delivery available but UAE has only 1.1% online delivery.
# * But rest of all countries haven't online deliovery.

# %%
sns.countplot(x='Is delivering now',data=df)
plt.show()

# %% [markdown]
# * Most of the places has not availavel delivery Now system.

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Aggregate rating',data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# * Most of the coustomer has gives 0 aggregate rating than others.
# * 3.1 and 3.2 is most given rating after a 0 aggregate rating.

# %%
sns.countplot(x='Rating color',data=df)
plt.show()

# %% [markdown]
# * We can see, orange is most used color for rating followed by white.
# * Red color are less used for rating. It means no one dislike the food delivered by zomato

# %%
sns.countplot(x='Rating text',data=df)
plt.show()

# %% [markdown]
# * In rating text, Average is the most used test followed by good.
# * But some of customer are not rated the zomato service.
# * Very few customers gives poor rating.

# %%
plt.figure(figsize=(22,7))
sns.countplot(x='Country',data=df)
plt.show()

# %% [markdown]
# * As we observed before that Indian currency is most used. It because of in India is the most of Zomato businees do followed by USA.
# * Rest of all counteries zomato not gives service as in India they gives.

# %%
city_values = df.City.value_counts().values
city_labels = df.City.value_counts().index

# %%
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# * 68.7% zomato works in New Delhi foolowed by Gurgaon.
# * In this we can observed here these cities are comes in Delhi NCR Region. It means that zomato mostly works in Delhi NCR region.

# %%
# Find top 10 Cuisine
cuisin_val=df.Cuisines.value_counts().values
cuisin_label = df.Cuisines.value_counts().index

# %%
plt.pie(cuisin_val[:10],labels=cuisin_label[:10],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# * We can see, 26.58% people or customers like to eat north Indian cuisine followed by Chinese.
# * These are the top 10 Cuisine like by customes.

# %%
# Find top 10 location
val=df.Locality.value_counts().values
label = df.Locality.value_counts().index

# %%
plt.pie(val[:10],labels=label[:10],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# * These are the top 10 place where most of zomato allines restaurant are located.
# * In which Connaught Place is top among the others it has 13.74% restaurant in it place followed by Rajouri Graden.

# %%
sns.countplot(x='Average Cost for two',data=df)
plt.show()

# %%
sns.distplot(df['Average Cost for two'])
plt.show()

# %% [markdown]
# * We can see 50% restaurand are affortable.

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(20,6))
df_good = df.sort_values(by="Average Cost for two",ascending=False)
sns.barplot(x="Country",y="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# * We can see, Indonesia has high Average cost for two. It means that Indonesia has high cost of foos than others.
# * Rest of all having low avwerage cost for two.

# %%
plt.figure(figsize=(20,6))
df_good = df.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(x="Restaurant Name",y="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# * These are the top 10 restaurant name where average cost for two is low than others.
# * In which Satoo hotel has high average cost for two followed by Skye.

# %%
df_good = df.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(y="City",x="Average Cost for two",data=df_good)
plt.show()

# %% [markdown]
# * These are top cities where has high average cost for two in which Jakartha is in to followed bt Tangerang.

# %%
sns.boxplot(x='Has Online delivery',y='Votes',data=df)
plt.title('Has Online delivery VS Votes')
plt.show()

# %% [markdown]
# * Yes,you can observe that median number of votes for both categories vary.
# * Restaurants accepting online orders tend to get more votes from customers as there is a rating option poping up after each order through zomato application.

# %%
df.groupby('Restaurant Name')['Aggregate rating'].mean().nlargest(10).plot.bar()
plt.show()

# %% [markdown]
# * These are the top 10 restaurant name where most of the coustomers gives good aggregate rating.
# * In which Atlanta is top among the others.

# %%
sns.boxplot(x='Has Online delivery',y='Average Cost for two',data=df)
plt.title('Has Online delivery VS Average Cost for two')
plt.show()

# %% [markdown]
# * Average cost for two has not affected by online delivery system.

# %%
df.groupby('Restaurant Name')['Votes'].mean().nlargest(10).plot.bar()
plt.show()

# %% [markdown]
# * We can see, top 10 reaturant on basis of the customers votes.
# * Toit is top restaurant top among the others whose have top votes followed by Hauz Khans.

# %%
rating=df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating count'})

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating count',data=rating)
plt.show()

# %% [markdown]
# *  0 rating given by many people

# %%
sns.barplot(x='Price range',y='Average Cost for two',data=df)
plt.show()

# %% [markdown]
# * Many restaurant are having as price range 3 it means that those are also having high average price range.
# * it may have directly proportional to each others.

# %%
sns.barplot(x='Rating text',y='Average Cost for two',data=df)
plt.show()

# %% [markdown]
# * Whose having as rating text Excellent those restaurant are having high average cost for two.
# * According to rating test average coat for to is depend.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Rating text',y='Aggregate rating',data=rating)
plt.show()

# %% [markdown]
# * We can see, Many restaurant are having Excellent as rating text and their Aggrege=ate rating also high it mean more than 4.5.
# * Similarly, Rating text is depending upon the aggregate rating. Whose are having good rating thier rating text also good.

# %%
Delhi = df[(df.City == 'New Delhi')]
top_locality = Delhi.Locality.value_counts().head(10)
plt.figure(figsize=(12,6))
sns.countplot(y= "Locality", hue="Has Online delivery", data=Delhi[Delhi.Locality.isin(top_locality.index)])
plt.title('Resturants Online Delivery')
plt.show()

# %% [markdown]
# * We can see, most of the place has no online delivery option. or online order system.
# * But Malviya Nagar is top among the restaurant whose having online ordered or online delivery.

# %%
Gurgaon = df[(df.City == 'Gurgaon')]
top_locality = Delhi.Locality.value_counts().head(10)
plt.figure(figsize=(12,6))
sns.countplot(y= "Locality", hue="Has Online delivery", data=Delhi[Delhi.Locality.isin(top_locality.index)])
plt.title('Resturants Online Delivery')
plt.show()

# %% [markdown]
# * We can see, most of the place has no online delivery option. or online order system.
# * But DLF Phase 3 is top among the restaurant whose having online ordered or online delivery.

# %%
sns.countplot(x='Has Online delivery',hue='Has Table booking',data=df)
plt.show()

# %% [markdown]
# * We can see, those are not providing online delivery they also have less table booking but it doe not have any impact on business because most of the restaurant has not provided online delivery.

# %%
plt.figure(figsize=(9,7))
sns.countplot(x='Rating color',hue='Price range',data=df)
plt.show()

# %% [markdown]
# * We can see, As per price range the rating color has change. In Which the Orange rating color has more count than others.

# %% [markdown]
# # CHECKING FOR OUTLIERS

# %%
df.describe()
# Out:
#        Country Code  Restaurant ID    Longitude     Latitude  \
# count   9551.000000   9.551000e+03  9551.000000  9551.000000
# mean      18.365616   9.051128e+06    64.126574    25.854381
# std       56.750546   8.791521e+06    41.467058    11.007935
# min        1.000000   5.300000e+01  -157.948486   -41.330428
# 25%        1.000000   3.019625e+05    77.081343    28.478713
# 50%        1.000000   6.004089e+06    77.191964    28.570469
# 75%        1.000000   1.835229e+07    77.282006    28.642758
# max      216.000000   1.850065e+07   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
numerical_col=['Country Code','Restaurant ID','Longitude','Latitude','Average Cost for two','Price range','Aggregate rating','Votes']
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in numerical_col:
    if plotnumber<=8:
        ax = plt.subplot(4,2,plotnumber)
        sns.boxplot(df[column],color='y')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# * Restaurant ID, are not having Outliers.
# * Some feature are having outliers but those are categorical features.

# %%
column=['Average Cost for two','Votes','Longitude','Latitude']

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# # Zscore method:

# %%
from scipy.stats import zscore
z_score=zscore(df[['Average Cost for two','Votes','Longitude','Latitude']])
abs_z_score=np.abs(z_score)

# %%
filtering_entry=(abs_z_score<3).all(axis=1)
df=df[filtering_entry]
df.describe()
# Out:
#        Country Code  Restaurant ID    Longitude     Latitude  \
# count   8756.000000   8.756000e+03  8756.000000  8756.000000
# mean       6.795797   8.756953e+06    71.975030    26.601350
# std       33.695999   8.876165e+06    19.754006     7.594189
# min        1.000000   5.300000e+01    -3.208363     0.000000
# 25%        1.000000   3.013122e+05    77.094199    28.487517
# 50%        1.000000   3.100362e+06    77.199977    28.569833
# 75%        1.000000   1.836120e+07    77.285361    28.639206
# max      215.000000   1.850065e+07   174.779441    55.976980
#
#        Average Cost for two  Price range  Aggregate rating        Votes
# count           8756.000000  8756.000000       8756.000000  8756.000000
# mean             604.233097     1.741092          2.541549    98.637848
# std              594.255263     0.869435          1.513054   189.443083
# min                0.000000     1.000000          0.000000     0.000000
# 25%              300.000000     1.000000          2.200000     4.000000
# 50%              450.000000     2.000000          3.100000    25.000000
# 75%              700.000000     2.000000          3.600000   100.000000
# max             8000.000000     4.000000          4.900000  1439.000000

# %% [markdown]
# # Checking and removing Skewness:

# %%
numerical_col=['Country Code','Restaurant ID','Longitude','Latitude','Average Cost for two','Price range','Aggregate rating','Votes']
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in numerical_col:
    if plotnumber<=8:
        ax = plt.subplot(4,2,plotnumber)
        sns.distplot(df[column],color='r')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
df.skew()
# Out:
# Country Code            5.692926
# Restaurant ID           0.133623
# Longitude              -3.179687
# Latitude               -2.246169
# Average Cost for two    3.667387
# Price range             0.987956
# Aggregate rating       -0.887535
# Votes                   3.555810
# dtype: float64

# %%
from sklearn.preprocessing import power_transform

df[['Average Cost for two','Votes','Longitude','Latitude']]=power_transform(df[['Average Cost for two','Votes','Longitude','Latitude']])

# %%
df.skew()
# Out:
# Country Code            5.692926
# Restaurant ID           0.133623
# Longitude              -0.963748
# Latitude                0.409584
# Average Cost for two    0.053731
# Price range             0.987956
# Aggregate rating       -0.887535
# Votes                  -0.012360
# dtype: float64

# %%
df
# Out:
#       Country Code         Country  Restaurant ID  \
# 0                1           India        3400025
# 1                1           India        3400341
# 2                1           India        3400005
# 3                1           India        3400021
# 4                1           India        3400017
# ...            ...             ...            ...
# 9112           215  United Kingdom        6800892
# 9113           215  United Kingdom        6800263
# 9114           215  United Kingdom        6801039
# 9115           215  United Kingdom        6801873
# 9116           215  United Kingdom        6800782
#
#                                Restaurant Name        City  \
# 0                                   Jahanpanah        Agra
# 1                          Rangrezz Restaurant        Agra
# 2                      Time2Eat - Mama Chicken        Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya        Agra
# 4                               Pinch Of Spice        Agra
# ...                                        ...         ...
# 9112                                    Gaucho  Manchester
# 9113                                    Akbars  Manchester
# 9114                                 San Carlo  Manchester
# 9115  Mr Cooper's House & Garden - The Midland  Manchester
# 9116   The French by Simon Rogan - The Midland  Manchester
#
#                                                 Address  \
# 0     E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 1     E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 2           Main Market, Sadar Bazaar, Agra Cantt, Agra
# 3     1/48, Delhi Gate, Station Road, Raja Mandi, Ci...
# 4     23/453, Opposite Sanjay Cinema, Wazipura Road,...
# ...                                                 ...
# 9112  2A St Mary's Street, Spinningfields, Mancheste...
# 9113  73-83 Liverpool Road, Spinningfields, Manchest...
# 9114  40-42 King Street West, Spinningfields, Manche...
# 9115  The Midland, Peter Street, Deansgate, Manchest...
# 9116  The Midland, Peter Street, Deansgate, Manchest...
#
#                     Locality                    Locality Verbose  Longitude  \
# 0                 Agra Cantt                    Agra Cantt, Agra   0.308199
# 1                 Agra Cantt                    Agra Cantt, Agra  -3.280600
# 2                 Agra Cantt                    Agra Cantt, Agra   0.308205
# 3                Civil Lines                   Civil Lines, Agra   0.306819
# 4                Civil Lines                   Civil Lines, Agra   0.307789
# ...                      ...                                 ...        ...
# 9112          Spinningfields          Spinningfields, Manchester  -3.281027
# 9113          Spinningfields          Spinningfields, Manchester  -3.281028
# 9114          Spinningfields          Spinningfields, Manchester  -3.281027
# 9115  The Midland, Deansgate  The Midland, Deansgate, Manchester  -3.281027
# 9116  The Midland, Deansgate  The Midland, Deansgate, Manchester  -3.281027
#
#       Latitude  ...            Currency  Has Table booking  \
# 0    -0.046351  ...  Indian Rupees(Rs.)                 No
# 1    -2.875395  ...  Indian Rupees(Rs.)                 No
# 2    -0.046495  ...  Indian Rupees(Rs.)                 No
# 3    -0.040389  ...  Indian Rupees(Rs.)                 No
# 4    -0.039380  ...  Indian Rupees(Rs.)                 No
# ...        ...  ...                 ...                ...
# 9112  5.979089  ...          Pounds(£)                 No
# 9113  5.977472  ...          Pounds(£)                 No
# 9114  5.978851  ...          Pounds(£)                 No
# 9115  5.977713  ...          Pounds(£)                Yes
# 9116  5.977655  ...          Pounds(£)                 No
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                     No                No                   No           3
# 1                     No                No                   No           2
# 2                     No                No                   No           2
# 3                     No                No                   No           2
# 4                     No                No                   No           3
# ...                  ...               ...                  ...         ...
# 9112                  No                No                   No           4
# 9113                  No                No                   No           2
# 9114                  No                No                   No           2
# 9115                  No                No                   No           3
# 9116                  No                No                   No           4
#
#      Aggregate rating  Rating color  Rating text     Votes
# 0                 3.9        Yellow         Good  0.947713
# 1                 3.5        Yellow         Good  0.589157
# 2                 3.6        Yellow         Good  0.736464
# 3                 4.0         Green    Very Good  0.695710
# 4                 4.2         Green    Very Good  1.073156
# ...               ...           ...          ...       ...
# 9112              4.5    Dark Green    Excellent  1.739599
# 9113              4.2         Green    Very Good  1.491217
# 9114              4.3         Green    Very Good  1.857507
# 9115              4.2         Green    Very Good  0.558885
# 9116              4.3         Green    Very Good  0.838464
#
# [8756 rows x 22 columns]

# %% [markdown]
# # Encoding:

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
df1 = df.copy()
df1 = df1.apply(LabelEncoder().fit_transform)
df1.head()
# Out:
#    Country Code  Country  Restaurant ID  Restaurant Name  City  Address  \
# 0             0        0           4425             2883     1     3938
# 1             0        0           4434             4768     1     3989
# 2             0        0           4420             6274     1     5560
# 3             0        0           4424             1500     1       95
# 4             0        0           4422             4441     1     1086
#
#    Locality  Locality Verbose  Longitude  Latitude  ...  Currency  \
# 0        15                15       7059       613  ...         3
# 1        15                15         77         0  ...         3
# 2        15                15       7060       611  ...         3
# 3       157               158       7057       618  ...         3
# 4       157               158       7058       619  ...         3
#
#    Has Table booking  Has Online delivery  Is delivering now  \
# 0                  0                    0                  0
# 1                  0                    0                  0
# 2                  0                    0                  0
# 3                  0                    0                  0
# 4                  0                    0                  0
#
#    Switch to order menu  Price range  Aggregate rating  Rating color  \
# 0                     0            2                22             5
# 1                     0            1                18             5
# 2                     0            1                19             5
# 3                     0            1                23             1
# 4                     0            2                25             1
#
#    Rating text  Votes
# 0            2    140
# 1            2     71
# 2            2     94
# 3            5     87
# 4            5    177
#
# [5 rows x 22 columns]

# %% [markdown]
# # Correlation using HEAT map:

# %%
# Checking the correlation between features and the target
cor = df1.corr()
cor
# Out:
#                       Country Code   Country  Restaurant ID  Restaurant Name  \
# Country Code              1.000000  1.000000       0.028316         0.019339
# Country                   1.000000  1.000000       0.028316         0.019339
# Restaurant ID             0.028316  0.028316       1.000000         0.004978
# Restaurant Name           0.019339  0.019339       0.004978         1.000000
# City                     -0.190775 -0.190775      -0.014328         0.001480
# Address                  -0.052089 -0.052089       0.161676         0.003419
# Locality                 -0.075868 -0.075868       0.086978         0.007021
# Locality Verbose         -0.074458 -0.074458       0.087219         0.007049
# Longitude                -0.176344 -0.176344      -0.040832         0.011117
# Latitude                  0.052018  0.052018      -0.146810        -0.001388
# Cuisines                 -0.036503 -0.036503      -0.058740         0.057685
# Average Cost for two     -0.262893 -0.262893      -0.168382         0.049292
# Currency                  0.479234  0.479234      -0.003045         0.011840
# Has Table booking         0.015574  0.015574      -0.136953         0.039287
# Has Online delivery      -0.054965 -0.054965      -0.110958         0.030244
# Is delivering now        -0.010216 -0.010216       0.021445         0.012731
# Switch to order menu           NaN       NaN            NaN              NaN
# Price range               0.236200  0.236200      -0.150910         0.067217
# Aggregate rating          0.227160  0.227160      -0.328105         0.030855
# Rating color             -0.157810 -0.157810       0.162724        -0.009391
# Rating text               0.129722  0.129722       0.306124         0.010931
# Votes                     0.170027  0.170027      -0.296393         0.029660
#
#                           City   Address  Locality  Locality Verbose  \
# Country Code         -0.190775 -0.052089 -0.075868         -0.074458
# Country              -0.190775 -0.052089 -0.075868         -0.074458
# Restaurant ID        -0.014328  0.161676  0.086978          0.087219
# Restaurant Name       0.001480  0.003419  0.007021          0.007049
# City                  1.000000 -0.073703 -0.013498         -0.017258
# Address              -0.073703  1.000000  0.148533          0.150355
# Locality             -0.013498  0.148533  1.000000          0.999162
# Locality Verbose     -0.017258  0.150355  0.999162          1.000000
# Longitude             0.292715 -0.056783 -0.005789         -0.003783
# Latitude              0.393899 -0.106789 -0.023126         -0.025951
# Cuisines              0.017744 -0.013820 -0.011836         -0.012912
# Average Cost for two -0.040495  0.027060 -0.054069         -0.052465
# Currency             -0.179236 -0.039459 -0.041923         -0.041409
# Has Table booking    -0.008279 -0.009390 -0.070233         -0.069349
# Has Online delivery  -0.003063 -0.000654 -0.046986         -0.047377
# Is delivering now    -0.019945  0.029356 -0.010331         -0.010310
# Switch to order menu       NaN       NaN       NaN               NaN
# Price range          -0.145719 -0.021549 -0.114817         -0.111872
# Aggregate rating     -0.160148 -0.095684 -0.172385         -0.170881
# Rating color          0.098000  0.058493  0.018026          0.018265
# Rating text          -0.083796  0.043551 -0.008356         -0.006807
# Votes                -0.107232 -0.087794 -0.164352         -0.161798
#
#                       Longitude  Latitude  ...  Currency  Has Table booking  \
# Country Code          -0.176344  0.052018  ...  0.479234           0.015574
# Country               -0.176344  0.052018  ...  0.479234           0.015574
# Restaurant ID         -0.040832 -0.146810  ... -0.003045          -0.136953
# Restaurant Name        0.011117 -0.001388  ...  0.011840           0.039287
# City                   0.292715  0.393899  ... -0.179236          -0.008279
# Address               -0.056783 -0.106789  ... -0.039459          -0.009390
# Locality              -0.005789 -0.023126  ... -0.041923          -0.070233
# Locality Verbose      -0.003783 -0.025951  ... -0.041409          -0.069349
# Longitude              1.000000  0.144191  ... -0.139589          -0.002606
# Latitude               0.144191  1.000000  ...  0.143996          -0.021239
# Cuisines               0.022043  0.074282  ...  0.012402           0.040587
# Average Cost for two   0.055520 -0.165785  ... -0.137384           0.544646
# Currency              -0.139589  0.143996  ...  1.000000          -0.050276
# Has Table booking     -0.002606 -0.021239  ... -0.050276           1.000000
# Has Online delivery    0.038072 -0.000338  ... -0.059697           0.078956
# Is delivering now     -0.015235 -0.004793  ... -0.004601          -0.018039
# Switch to order menu        NaN       NaN  ...       NaN                NaN
# Price range           -0.053710 -0.169623  ...  0.077260           0.555907
# Aggregate rating      -0.035507 -0.064963  ...  0.101177           0.232658
# Rating color          -0.005099 -0.006314  ... -0.069481          -0.027527
# Rating text           -0.073960 -0.128065  ...  0.076251           0.049518
# Votes                 -0.020077 -0.089152  ...  0.058067           0.320381
#
#                       Has Online delivery  Is delivering now  \
# Country Code                    -0.054965          -0.010216
# Country                         -0.054965          -0.010216
# Restaurant ID                   -0.110958           0.021445
# Restaurant Name                  0.030244           0.012731
# City                            -0.003063          -0.019945
# Address                         -0.000654           0.029356
# Locality                        -0.046986          -0.010331
# Locality Verbose                -0.047377          -0.010310
# Longitude                        0.038072          -0.015235
# Latitude                        -0.000338          -0.004793
# Cuisines                        -0.038201           0.005417
# Average Cost for two             0.171716           0.025118
# Currency                        -0.059697          -0.004601
# Has Table booking                0.078956          -0.018039
# Has Online delivery              1.000000           0.101781
# Is delivering now                0.101781           1.000000
# Switch to order menu                  NaN                NaN
# Price range                      0.114600           0.016481
# Aggregate rating                 0.246226           0.018211
# Rating color                    -0.010297          -0.001324
# Rating text                     -0.059638          -0.030151
# Votes                            0.215303           0.021518
#
#                       Switch to order menu  Price range  Aggregate rating  \
# Country Code                           NaN     0.236200          0.227160
# Country                                NaN     0.236200          0.227160
# Restaurant ID                          NaN    -0.150910         -0.328105
# Restaurant Name                        NaN     0.067217          0.030855
# City                                   NaN    -0.145719         -0.160148
# Address                                NaN    -0.021549         -0.095684
# Locality                               NaN    -0.114817         -0.172385
# Locality Verbose                       NaN    -0.111872         -0.170881
# Longitude                              NaN    -0.053710         -0.035507
# Latitude                               NaN    -0.169623         -0.064963
# Cuisines                               NaN     0.010874         -0.074043
# Average Cost for two                   NaN     0.731513          0.330252
# Currency                               NaN     0.077260          0.101177
# Has Table booking                      NaN     0.555907          0.232658
# Has Online delivery                    NaN     0.114600          0.246226
# Is delivering now                      NaN     0.016481          0.018211
# Switch to order menu                   NaN          NaN               NaN
# Price range                            NaN     1.000000          0.465570
# Aggregate rating                       NaN     0.465570          1.000000
# Rating color                           NaN    -0.096374         -0.273179
# Rating text                            NaN     0.120186         -0.106967
# Votes                                  NaN     0.468812          0.562443
#
#                       Rating color  Rating text     Votes
# Country Code             -0.157810     0.129722  0.170027
# Country                  -0.157810     0.129722  0.170027
# Restaurant ID             0.162724     0.306124 -0.296393
# Restaurant Name          -0.009391     0.010931  0.029660
# City                      0.098000    -0.083796 -0.107232
# Address                   0.058493     0.043551 -0.087794
# Locality                  0.018026    -0.008356 -0.164352
# Locality Verbose          0.018265    -0.006807 -0.161798
# Longitude                -0.005099    -0.073960 -0.020077
# Latitude                 -0.006314    -0.128065 -0.089152
# Cuisines                 -0.039417    -0.060839 -0.032460
# Average Cost for two     -0.027215     0.018381  0.352423
# Currency                 -0.069481     0.076251  0.058067
# Has Table booking        -0.027527     0.049518  0.320381
# Has Online delivery      -0.010297    -0.059638  0.215303
# Is delivering now        -0.001324    -0.030151  0.021518
# Switch to order menu           NaN          NaN       NaN
# Price range              -0.096374     0.120186  0.468812
# Aggregate rating         -0.273179    -0.106967  0.562443
# Rating color              1.000000     0.284384 -0.054986
# Rating text               0.284384     1.000000  0.236346
# Votes                    -0.054986     0.236346  1.000000
#
# [22 rows x 22 columns]

# %%
df1.drop(columns=['Switch to order menu'],axis=1,inplace=True)

# %%
# Visualizing the correlation matrix by plotting heat map.
plt.figure(figsize=(16,9))
sns.heatmap(df1.corr(),linewidths=.1,fmt='0.3f', annot = True)
plt.yticks(rotation=0)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5]),
#  [Text(0, 0.5, 'Country Code'),
#   Text(0, 1.5, 'Country'),
#   Text(0, 2.5, 'Restaurant ID'),
#   Text(0, 3.5, 'Restaurant Name'),
#   Text(0, 4.5, 'City'),
#   Text(0, 5.5, 'Address'),
#   Text(0, 6.5, 'Locality'),
#   Text(0, 7.5, 'Locality Verbose'),
#   Text(0, 8.5, 'Longitude'),
#   Text(0, 9.5, 'Latitude'),
#   Text(0, 10.5, 'Cuisines'),
#   Text(0, 11.5, 'Average Cost for two'),
#   Text(0, 12.5, 'Currency'),
#   Text(0, 13.5, 'Has Table booking'),
#   Text(0, 14.5, 'Has Online delivery'),
#   Text(0, 15.5, 'Is delivering now'),
#   Text(0, 16.5, 'Price range'),
#   Text(0, 17.5, 'Aggregate rating'),
#   Text(0, 18.5, 'Rating color'),
#   Text(0, 19.5, 'Rating text'),
#   Text(0, 20.5, 'Votes')])

# %%
cor['Average Cost for two'].sort_values(ascending=False)
# Out:
# Average Cost for two    1.000000
# Price range             0.731513
# Has Table booking       0.544646
# Votes                   0.352423
# Aggregate rating        0.330252
# Has Online delivery     0.171716
# Longitude               0.055520
# Restaurant Name         0.049292
# Address                 0.027060
# Is delivering now       0.025118
# Rating text             0.018381
# Cuisines               -0.004419
# Rating color           -0.027215
# City                   -0.040495
# Locality Verbose       -0.052465
# Locality               -0.054069
# Currency               -0.137384
# Latitude               -0.165785
# Restaurant ID          -0.168382
# Country                -0.262893
# Country Code           -0.262893
# Switch to order menu         NaN
# Name: Average Cost for two, dtype: float64

# %% [markdown]
# # Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize=(18,7))
df1.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('target',fontsize=14)
plt.title('correlation between label and feature using bar plot',fontsize=18)
plt.show()

# %% [markdown]
# # Dividing data in feature and Label

# %%
x = df1.drop(columns=['Average Cost for two'],axis=1)
y = df1['Average Cost for two']

# %%
#Lets import standardscaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[-0.163627  , -0.163627  ,  0.01879224, ...,  1.39110501,
#          0.20158538,  0.3490639 ],
#        [-0.163627  , -0.163627  ,  0.02235287, ...,  1.39110501,
#          0.20158538, -0.12188601],
#        [-0.163627  , -0.163627  ,  0.01681411, ...,  1.39110501,
#          0.20158538,  0.03509729],
#        ...,
#        [ 7.33751449,  7.33751449,  0.12719377, ..., -1.43352609,
#          2.03893607,  3.46142856],
#        [ 7.33751449,  7.33751449,  0.12956753, ..., -1.43352609,
#          2.03893607, -0.14918746],
#        [ 7.33751449,  7.33751449,  0.12600689, ..., -1.43352609,
#          2.03893607,  0.17160451]])

# %% [markdown]
# # Now use VIF for checking multicollinearity problem
# VIF - > Variance Inflation Factor

# %%
x
# Out:
#       Country Code  Country  Restaurant ID  Restaurant Name  City  Address  \
# 0                0        0           4425             2883     1     3938
# 1                0        0           4434             4768     1     3989
# 2                0        0           4420             6274     1     5560
# 3                0        0           4424             1500     1       95
# 4                0        0           4422             4441     1     1086
# ...            ...      ...            ...              ...   ...      ...
# 9112             8        8           4697             2336    35     1319
# 9113             8        8           4688              194    35     2314
# 9114             8        8           4699             5006    35     1805
# 9115             8        8           4705             3885    35     7887
# 9116             8        8           4696             5983    35     7887
#
#       Locality  Locality Verbose  Longitude  Latitude  Cuisines  Currency  \
# 0           15                15       7059       613      1210         3
# 1           15                15         77         0      1210         3
# 2           15                15       7060       611      1006         3
# 3          157               158       7057       618      1330         3
# 4          157               158       7058       619      1072         3
# ...        ...               ...        ...       ...       ...       ...
# 9112       788               841         23      7873        57         5
# 9113       788               841         20      7866       753         5
# 9114       788               841         22      7871       774         5
# 9115       838               891         27      7868       600         5
# 9116       838               891         26      7867       689         5
#
#       Has Table booking  Has Online delivery  Is delivering now  Price range  \
# 0                     0                    0                  0            2
# 1                     0                    0                  0            1
# 2                     0                    0                  0            1
# 3                     0                    0                  0            1
# 4                     0                    0                  0            2
# ...                 ...                  ...                ...          ...
# 9112                  0                    0                  0            3
# 9113                  0                    0                  0            1
# 9114                  0                    0                  0            1
# 9115                  1                    0                  0            2
# 9116                  0                    0                  0            3
#
#       Aggregate rating  Rating color  Rating text  Votes
# 0                   22             5            2    140
# 1                   18             5            2     71
# 2                   19             5            2     94
# 3                   23             1            5     87
# 4                   25             1            5    177
# ...                ...           ...          ...    ...
# 9112                28             0            1    527
# 9113                25             1            5    376
# 9114                26             1            5    596
# 9115                25             1            5     67
# 9116                26             1            5    114
#
# [8756 rows x 20 columns]

# %%
#Lets import VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i)for i in range(x_scaled.shape[1])]
vif['feature']=x.columns

# %%
vif
# Out:
#            vif              feature
# 0          inf         Country Code
# 1          inf              Country
# 2     1.397168        Restaurant ID
# 3     1.009726      Restaurant Name
# 4     1.391785                 City
# 5     1.067433              Address
# 6   611.911379             Locality
# 7   611.829480     Locality Verbose
# 8     1.134134            Longitude
# 9     1.365996             Latitude
# 10    1.033828             Cuisines
# 11    1.378973             Currency
# 12    1.527094    Has Table booking
# 13    1.113728  Has Online delivery
# 14    1.016879    Is delivering now
# 15    1.984458          Price range
# 16    1.987724     Aggregate rating
# 17    1.208187         Rating color
# 18    1.479000          Rating text
# 19    1.988668                Votes

# %% [markdown]
# # Droping columns whose having multicollinearity

# %%
x.drop(columns=['Country Code','Country'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
scaled= sc.fit_transform(x)

VIF= pd.DataFrame()
VIF['features']=x.columns

VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(scaled.shape[1])]
VIF
# Out:
#                features         vif
# 0         Restaurant ID    1.384679
# 1       Restaurant Name    1.009699
# 2                  City    1.385130
# 3               Address    1.066191
# 4              Locality  611.727922
# 5      Locality Verbose  611.669804
# 6             Longitude    1.121240
# 7              Latitude    1.351105
# 8              Cuisines    1.032341
# 9              Currency    1.153595
# 10    Has Table booking    1.512771
# 11  Has Online delivery    1.107576
# 12    Is delivering now    1.016709
# 13          Price range    1.929012
# 14     Aggregate rating    1.970085
# 15         Rating color    1.188001
# 16          Rating text    1.468050
# 17                Votes    1.986949

# %%
x.drop(columns=['Locality','Locality Verbose'],axis=1,inplace=True)

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # MODEL BUILDING

# %% [markdown]
# # * LinearRegression

# %%
#Import Linear Regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
#Import R2_score
from sklearn.metrics import r2_score,mean_squared_error

# %%
#Lets check with diffrent method
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    x_pred=lr.predict(x_train)
    y_pred=lr.predict(x_test)
    print(f" At random state {i} , the Training accuracy is :- {r2_score(y_train,x_pred)}")
    print(f" At random state {i} , the testing accuracy is :- {r2_score(y_test,y_pred)}")
    print("\n")
# Out:
#  At random state 0 , the Training accuracy is :- 0.6111379959432262
#  At random state 0 , the testing accuracy is :- 0.6248077692315309
#
#
#  At random state 1 , the Training accuracy is :- 0.6158375433084882
#  At random state 1 , the testing accuracy is :- 0.6051571233478228
#
#
#  At random state 2 , the Training accuracy is :- 0.6246590639679558
#  At random state 2 , the testing accuracy is :- 0.5698258335209314
#
#
#  At random state 3 , the Training accuracy is :- 0.6093500744859721
#  At random state 3 , the testing accuracy is :- 0.6310571813293817
#
#
#  At random state 4 , the Training accuracy is :- 0.6235742319911679
#  At random state 4 , the testing accuracy is :- 0.5768859409523877
#
#
#  At random state 5 , the Training accuracy is :- 0.618335898548111
#  At random state 5 , the testing accuracy is :- 0.5948547745061463
#
#
#  At random state 6 , the Training accuracy is :- 0.6058177078572569
#  At random state 6 , the testing accuracy is :- 0.6441285932660779
#
#
#  At random state 7 , the Training accuracy is :- 0.6194777978010562
#  At random state 7 , the testing accuracy is :- 0.5886184274609249
#
#
#  At random state 8 , the Training accuracy is :- 0.6115282410299192
#  At random state 8 , the testing accuracy is :- 0.6213883704584369
#
#
#  At random state 9 , the Training accuracy is :- 0.6149798847823963
#  At random state 9 , the testing accuracy is :- 0.6079832444127333
#
#
#  At random state 10 , the Training accuracy is :- 0.6149676305093187
#  At random state 10 , the testing accuracy is :- 0.6066856139265908
#
#
#  At random state 11 , the Training accuracy is :- 0.6058021149742332
#  At random state 11 , the testing accuracy is :- 0.6455555970788661
#
#
#  At random state 12 , the Training accuracy is :- 0.6136686450559983
#  At random state 12 , the testing accuracy is :- 0.6132630904224059
#
#
#  At random state 13 , the Training accuracy is :- 0.6209881807722704
#  At random state 13 , the testing accuracy is :- 0.5836767664110698
#
#
#  At random state 14 , the Training accuracy is :- 0.6146673293651288
#  At random state 14 , the testing accuracy is :- 0.6096534413942392
#
#
#  At random state 15 , the Training accuracy is :- 0.6152792867664815
#  At random state 15 , the testing accuracy is :- 0.6071659743943925
#
#
#  At random state 16 , the Training accuracy is :- 0.6043920442449857
#  At random state 16 , the testing accuracy is :- 0.6504321070025396
#
#
#  At random state 17 , the Training accuracy is :- 0.6048997849443939
#  At random state 17 , the testing accuracy is :- 0.6460691360612121
#
#
#  At random state 18 , the Training accuracy is :- 0.6167003504004842
#  At random state 18 , the testing accuracy is :- 0.6011419176277237
#
#
#  At random state 19 , the Training accuracy is :- 0.6197951125426087
#  At random state 19 , the testing accuracy is :- 0.5869486128958734
#
#
#  At random state 20 , the Training accuracy is :- 0.6143913049748388
#  At random state 20 , the testing accuracy is :- 0.6103987027088474
#
#
#  At random state 21 , the Training accuracy is :- 0.6189208634869197
#  At random state 21 , the testing accuracy is :- 0.5914449574114349
#
#
#  At random state 22 , the Training accuracy is :- 0.6091791383236091
#  At random state 22 , the testing accuracy is :- 0.6324858966305615
#
#
#  At random state 23 , the Training accuracy is :- 0.6117924530136105
#  At random state 23 , the testing accuracy is :- 0.6220886173686324
#
#
#  At random state 24 , the Training accuracy is :- 0.611026338746665
#  At random state 24 , the testing accuracy is :- 0.6258307355673032
#
#
#  At random state 25 , the Training accuracy is :- 0.6104973586436275
#  At random state 25 , the testing accuracy is :- 0.6261320878498793
#
#
#  At random state 26 , the Training accuracy is :- 0.6114144976886032
#  At random state 26 , the testing accuracy is :- 0.6208199933466098
#
#
#  At random state 27 , the Training accuracy is :- 0.6012223721011787
#  At random state 27 , the testing accuracy is :- 0.6618699007010571
#
#
#  At random state 28 , the Training accuracy is :- 0.6107074178499967
#  At random state 28 , the testing accuracy is :- 0.6252540846185601
#
#
#  At random state 29 , the Training accuracy is :- 0.6267876318410339
#  At random state 29 , the testing accuracy is :- 0.5583784620457576
#
#
#  At random state 30 , the Training accuracy is :- 0.619399835821904
#  At random state 30 , the testing accuracy is :- 0.5908391522280871
#
#
#  At random state 31 , the Training accuracy is :- 0.599984344229903
#  At random state 31 , the testing accuracy is :- 0.6688593929700707
#
#
#  At random state 32 , the Training accuracy is :- 0.6195230166332768
#  At random state 32 , the testing accuracy is :- 0.5901995880104305
#
#
#  At random state 33 , the Training accuracy is :- 0.6148491309706001
#  At random state 33 , the testing accuracy is :- 0.6081603827687858
#
#
#  At random state 34 , the Training accuracy is :- 0.6182124127398055
#  At random state 34 , the testing accuracy is :- 0.5953516202766844
#
#
#  At random state 35 , the Training accuracy is :- 0.610116369552056
#  At random state 35 , the testing accuracy is :- 0.628733093760093
#
#
#  At random state 36 , the Training accuracy is :- 0.6254986491925685
#  At random state 36 , the testing accuracy is :- 0.5639521773554705
#
#
#  At random state 37 , the Training accuracy is :- 0.6148266072247839
#  At random state 37 , the testing accuracy is :- 0.6078634164386352
#
#
#  At random state 38 , the Training accuracy is :- 0.6138403730112598
#  At random state 38 , the testing accuracy is :- 0.6125580322341591
#
#
#  At random state 39 , the Training accuracy is :- 0.6139305828641881
#  At random state 39 , the testing accuracy is :- 0.6104955670244578
#
#
#  At random state 40 , the Training accuracy is :- 0.6183126741721061
#  At random state 40 , the testing accuracy is :- 0.5957245084548044
#
#
#  At random state 41 , the Training accuracy is :- 0.6102370360313973
#  At random state 41 , the testing accuracy is :- 0.6285673730422798
#
#
#  At random state 42 , the Training accuracy is :- 0.6250468778419325
#  At random state 42 , the testing accuracy is :- 0.5697103486483709
#
#
#  At random state 43 , the Training accuracy is :- 0.6207963035960881
#  At random state 43 , the testing accuracy is :- 0.5856840638232309
#
#
#  At random state 44 , the Training accuracy is :- 0.6171384941619312
#  At random state 44 , the testing accuracy is :- 0.5980821955322431
#
#
#  At random state 45 , the Training accuracy is :- 0.602880906698041
#  At random state 45 , the testing accuracy is :- 0.6546718564377914
#
#
#  At random state 46 , the Training accuracy is :- 0.6171350640545072
#  At random state 46 , the testing accuracy is :- 0.5994829943673967
#
#
#  At random state 47 , the Training accuracy is :- 0.6133293891881497
#  At random state 47 , the testing accuracy is :- 0.614736132881625
#
#
#  At random state 48 , the Training accuracy is :- 0.6156304148920981
#  At random state 48 , the testing accuracy is :- 0.6045708899447516
#
#
#  At random state 49 , the Training accuracy is :- 0.615148173103684
#  At random state 49 , the testing accuracy is :- 0.6076458093463958
#
#
#  At random state 50 , the Training accuracy is :- 0.620765891883704
#  At random state 50 , the testing accuracy is :- 0.5854529441886541
#
#
#  At random state 51 , the Training accuracy is :- 0.622604947482448
#  At random state 51 , the testing accuracy is :- 0.5785904729151121
#
#
#  At random state 52 , the Training accuracy is :- 0.6166839136702555
#  At random state 52 , the testing accuracy is :- 0.6013399099626482
#
#
#  At random state 53 , the Training accuracy is :- 0.6200705329272528
#  At random state 53 , the testing accuracy is :- 0.587291211360015
#
#
#  At random state 54 , the Training accuracy is :- 0.6108483213585855
#  At random state 54 , the testing accuracy is :- 0.6247874603777712
#
#
#  At random state 55 , the Training accuracy is :- 0.6161625452455208
#  At random state 55 , the testing accuracy is :- 0.6036357193532316
#
#
#  At random state 56 , the Training accuracy is :- 0.6106534344043977
#  At random state 56 , the testing accuracy is :- 0.6252896123558368
#
#
#  At random state 57 , the Training accuracy is :- 0.6120605323019872
#  At random state 57 , the testing accuracy is :- 0.6206170179512887
#
#
#  At random state 58 , the Training accuracy is :- 0.6268610097324292
#  At random state 58 , the testing accuracy is :- 0.5590130679132732
#
#
#  At random state 59 , the Training accuracy is :- 0.6189287935913693
#  At random state 59 , the testing accuracy is :- 0.5908774261516577
#
#
#  At random state 60 , the Training accuracy is :- 0.6145152207114086
#  At random state 60 , the testing accuracy is :- 0.6100636395967574
#
#
#  At random state 61 , the Training accuracy is :- 0.6186666085088575
#  At random state 61 , the testing accuracy is :- 0.5898893997171901
#
#
#  At random state 62 , the Training accuracy is :- 0.6245411013458713
#  At random state 62 , the testing accuracy is :- 0.5667376968997391
#
#
#  At random state 63 , the Training accuracy is :- 0.6162043091958391
#  At random state 63 , the testing accuracy is :- 0.6030354233605018
#
#
#  At random state 64 , the Training accuracy is :- 0.607943821273299
#  At random state 64 , the testing accuracy is :- 0.6365686815684644
#
#
#  At random state 65 , the Training accuracy is :- 0.615008322910737
#  At random state 65 , the testing accuracy is :- 0.6071049121229952
#
#
#  At random state 66 , the Training accuracy is :- 0.6215762196044208
#  At random state 66 , the testing accuracy is :- 0.5802423136049675
#
#
#  At random state 67 , the Training accuracy is :- 0.619543506807984
#  At random state 67 , the testing accuracy is :- 0.5899288873337734
#
#
#  At random state 68 , the Training accuracy is :- 0.6224719207382781
#  At random state 68 , the testing accuracy is :- 0.576333226489107
#
#
#  At random state 69 , the Training accuracy is :- 0.6097342850593226
#  At random state 69 , the testing accuracy is :- 0.6284322684708181
#
#
#  At random state 70 , the Training accuracy is :- 0.6165642205111886
#  At random state 70 , the testing accuracy is :- 0.6006082246065373
#
#
#  At random state 71 , the Training accuracy is :- 0.6205080134735825
#  At random state 71 , the testing accuracy is :- 0.5849386302057404
#
#
#  At random state 72 , the Training accuracy is :- 0.6153655647255195
#  At random state 72 , the testing accuracy is :- 0.6069298701379136
#
#
#  At random state 73 , the Training accuracy is :- 0.6180306042538444
#  At random state 73 , the testing accuracy is :- 0.5953618635895047
#
#
#  At random state 74 , the Training accuracy is :- 0.6186319174520154
#  At random state 74 , the testing accuracy is :- 0.5916847416409645
#
#
#  At random state 75 , the Training accuracy is :- 0.6103981454058243
#  At random state 75 , the testing accuracy is :- 0.6279982104922921
#
#
#  At random state 76 , the Training accuracy is :- 0.601468857731106
#  At random state 76 , the testing accuracy is :- 0.6652508842024961
#
#
#  At random state 77 , the Training accuracy is :- 0.6111125687424395
#  At random state 77 , the testing accuracy is :- 0.6230808488368524
#
#
#  At random state 78 , the Training accuracy is :- 0.6213462964241443
#  At random state 78 , the testing accuracy is :- 0.5826741058760196
#
#
#  At random state 79 , the Training accuracy is :- 0.6117027857014732
#  At random state 79 , the testing accuracy is :- 0.6192563621647675
#
#
#  At random state 80 , the Training accuracy is :- 0.6193047689977231
#  At random state 80 , the testing accuracy is :- 0.5941879193515682
#
#
#  At random state 81 , the Training accuracy is :- 0.6294779152813574
#  At random state 81 , the testing accuracy is :- 0.5475414128475069
#
#
#  At random state 82 , the Training accuracy is :- 0.6137568502510841
#  At random state 82 , the testing accuracy is :- 0.6138712065594445
#
#
#  At random state 83 , the Training accuracy is :- 0.6007612700262699
#  At random state 83 , the testing accuracy is :- 0.6612932176370925
#
#
#  At random state 84 , the Training accuracy is :- 0.6064639930345992
#  At random state 84 , the testing accuracy is :- 0.6393412366401638
#
#
#  At random state 85 , the Training accuracy is :- 0.6104979528650676
#  At random state 85 , the testing accuracy is :- 0.6214987989686751
#
#
#  At random state 86 , the Training accuracy is :- 0.6127410176870611
#  At random state 86 , the testing accuracy is :- 0.6179888838243234
#
#
#  At random state 87 , the Training accuracy is :- 0.6106604033390879
#  At random state 87 , the testing accuracy is :- 0.6267344552986732
#
#
#  At random state 88 , the Training accuracy is :- 0.6110331005165999
#  At random state 88 , the testing accuracy is :- 0.6223919570664869
#
#
#  At random state 89 , the Training accuracy is :- 0.615629687169189
#  At random state 89 , the testing accuracy is :- 0.6050230783741353
#
#
#  At random state 90 , the Training accuracy is :- 0.6048394241473043
#  At random state 90 , the testing accuracy is :- 0.6456116652618633
#
#
#  At random state 91 , the Training accuracy is :- 0.6175031339484296
#  At random state 91 , the testing accuracy is :- 0.5990652462595474
#
#
#  At random state 92 , the Training accuracy is :- 0.6162164698879256
#  At random state 92 , the testing accuracy is :- 0.6024635574993925
#
#
#  At random state 93 , the Training accuracy is :- 0.6158159074212444
#  At random state 93 , the testing accuracy is :- 0.6039939077315808
#
#
#  At random state 94 , the Training accuracy is :- 0.6161842469308401
#  At random state 94 , the testing accuracy is :- 0.6034044704711862
#
#
#  At random state 95 , the Training accuracy is :- 0.6160762786372838
#  At random state 95 , the testing accuracy is :- 0.6041003315271544
#
#
#  At random state 96 , the Training accuracy is :- 0.6169859127421298
#  At random state 96 , the testing accuracy is :- 0.599274174839032
#
#
#  At random state 97 , the Training accuracy is :- 0.618756951288046
#  At random state 97 , the testing accuracy is :- 0.587393929634841
#
#
#  At random state 98 , the Training accuracy is :- 0.6292580300822304
#  At random state 98 , the testing accuracy is :- 0.547140050777273
#
#
#  At random state 99 , the Training accuracy is :- 0.6054065417735457
#  At random state 99 , the testing accuracy is :- 0.6440175341830785

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=14)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Lets Print Training Score
pred_train=lr.predict(x_train)
print(r2_score(y_train,pred_train))
# Out:
# 0.6146673293651288

# %%
#Lets Print Testing Score
pred_test=lr.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.6096534413942392

# %% [markdown]
# # Cross Validation of the Model

# %%
train_accuracy=r2_score(y_train,x_pred)
test_accuracy=r2_score(y_test,y_pred)
#Lets import Cross Validation
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x_scaled,y,cv=j)
    cv_mean=cv_score.mean()
    
    print(f"At cross fold {j} the CV Score is {cv_mean} and accuracy for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the CV Score is -1.1264447525859146e+19 and accuracy for training is -0.6002333616404376 and accuracy for testing is -0.6285169345680306
#
#
# At cross fold 3 the CV Score is -2.923709885746786e+18 and accuracy for training is -0.6002333616404376 and accuracy for testing is -0.6285169345680306
#
#
# At cross fold 4 the CV Score is -5.775221171582084e+16 and accuracy for training is -0.6002333616404376 and accuracy for testing is -0.6285169345680306
#
#
# At cross fold 5 the CV Score is -4.305250841187777e+17 and accuracy for training is -0.6002333616404376 and accuracy for testing is -0.6285169345680306
#
#
# At cross fold 6 the CV Score is -9380964830905978.0 and accuracy for training is -0.6002333616404376 and accuracy for testing is -0.6285169345680306
#
#
# At cross fold 7 the CV Score is -1.574383879274185e+18 and accuracy for training is -0.6002333616404376 and accuracy for testing is -0.6285169345680306
#
#
# At cross fold 8 the CV Score is -3.7863957938219994e+17 and accuracy for training is -0.6002333616404376 and accuracy for testing is -0.6285169345680306
#
#
# At cross fold 9 the CV Score is -9.290841834587744e+16 and accuracy for training is -0.6002333616404376 and accuracy for testing is -0.6285169345680306

# %% [markdown]
# # Lets Plot Best Fit Line and Check How Data points are Close to the Best Fit Line

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Acutal Charges ",fontsize=14)
plt.ylabel("Predicted Charges ",fontsize=14)
plt.title("Linear Regression ",fontsize=18)
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
#lets import Lasso (Least absolute shrinkage and selection operator)
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV
#LASSOCV will return best alpha after max iteration
#normalize is subtracting the mean and divide by L2_norm
import warnings
warnings.filterwarnings('ignore')

lasscv=LassoCV(alphas = None , max_iter =100,normalize=True)
lasscv.fit(x_train,y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
#best alpha paremetere
alpha=lasscv.alpha_
alpha
# Out:
# 0.0004894892514482163

# %%
#Now that we have best parameter,Lets use Lasso regression and see how well our data has fitted before
lasso_reg=Lasso(alpha)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.0004894892514482163)

# %%
lasso_reg.score(x_train,y_train)#Testing Score
# Out:
# 0.6146670281890982

# %%
lasso_reg.score(x_test,y_test) #Testing Score
# Out:
# 0.6096471951283374

# %% [markdown]
# # Using Ridge Regression Model.

# %%
# Ridge will return best alpha and coefficients after performing 10 Cross validation

ridgecv=RidgeCV(alphas =np.arange(0.001,0.1,0.01),normalize=True)
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([0.001, 0.011, 0.021, 0.031, 0.041, 0.051, 0.061, 0.071, 0.081,
#        0.091]),
#         normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.001

# %%
ridge_model = Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.001)

# %%
ridge_model.score(x_train,y_train)#Training Score
# Out:
# 0.61466732936493

# %%
ridge_model.score(x_test,y_test)#Testing Score
# Out:
# 0.6096534335620696

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
y_pred=ridge_model.predict(x_test)

# %%
#MAE
mean_absolute_error(y_test,y_pred)
# Out:
# 6.05053153399668

# %%
#MSE
mean_squared_error(y_test,y_pred)
# Out:
# 84.61751916568792

# %%
#RMSE

np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 9.198778134387627

# %% [markdown]
# # Lets Plot With Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()

# %%
#Lets check with diffrent method
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    dt.fit(x_train,y_train)
    x_pred=dt.predict(x_train)
    y_pred=dt.predict(x_test)
    print(f" At random state {i} , the Training accuracy is :- {r2_score(y_train,x_pred)}")
    print(f" At random state {i} , the testing accuracy is :- {r2_score(y_test,y_pred)}")
    print("\n")
# Out:
#  At random state 0 , the Training accuracy is :- 1.0
#  At random state 0 , the testing accuracy is :- 0.7313663770994179
#
#
#  At random state 1 , the Training accuracy is :- 1.0
#  At random state 1 , the testing accuracy is :- 0.7340255444660639
#
#
#  At random state 2 , the Training accuracy is :- 1.0
#  At random state 2 , the testing accuracy is :- 0.7503798940298272
#
#
#  At random state 3 , the Training accuracy is :- 1.0
#  At random state 3 , the testing accuracy is :- 0.7284971377333203
#
#
#  At random state 4 , the Training accuracy is :- 1.0
#  At random state 4 , the testing accuracy is :- 0.7630014393875413
#
#
#  At random state 5 , the Training accuracy is :- 1.0
#  At random state 5 , the testing accuracy is :- 0.7261025655831357
#
#
#  At random state 6 , the Training accuracy is :- 1.0
#  At random state 6 , the testing accuracy is :- 0.7563589538496269
#
#
#  At random state 7 , the Training accuracy is :- 1.0
#  At random state 7 , the testing accuracy is :- 0.727843434672907
#
#
#  At random state 8 , the Training accuracy is :- 1.0
#  At random state 8 , the testing accuracy is :- 0.7437860068145521
#
#
#  At random state 9 , the Training accuracy is :- 1.0
#  At random state 9 , the testing accuracy is :- 0.7169770978942296
#
#
#  At random state 10 , the Training accuracy is :- 1.0
#  At random state 10 , the testing accuracy is :- 0.7248633726738225
#
#
#  At random state 11 , the Training accuracy is :- 1.0
#  At random state 11 , the testing accuracy is :- 0.7275705945775869
#
#
#  At random state 12 , the Training accuracy is :- 1.0
#  At random state 12 , the testing accuracy is :- 0.7329475267157284
#
#
#  At random state 13 , the Training accuracy is :- 1.0
#  At random state 13 , the testing accuracy is :- 0.7383800965189171
#
#
#  At random state 14 , the Training accuracy is :- 1.0
#  At random state 14 , the testing accuracy is :- 0.7260989495937593
#
#
#  At random state 15 , the Training accuracy is :- 1.0
#  At random state 15 , the testing accuracy is :- 0.7136638767708783
#
#
#  At random state 16 , the Training accuracy is :- 1.0
#  At random state 16 , the testing accuracy is :- 0.7361346635576225
#
#
#  At random state 17 , the Training accuracy is :- 1.0
#  At random state 17 , the testing accuracy is :- 0.7323760418091267
#
#
#  At random state 18 , the Training accuracy is :- 1.0
#  At random state 18 , the testing accuracy is :- 0.7360496815082541
#
#
#  At random state 19 , the Training accuracy is :- 1.0
#  At random state 19 , the testing accuracy is :- 0.709896300191406
#
#
#  At random state 20 , the Training accuracy is :- 1.0
#  At random state 20 , the testing accuracy is :- 0.7446157180473167
#
#
#  At random state 21 , the Training accuracy is :- 1.0
#  At random state 21 , the testing accuracy is :- 0.7168032152944233
#
#
#  At random state 22 , the Training accuracy is :- 1.0
#  At random state 22 , the testing accuracy is :- 0.7415599214769482
#
#
#  At random state 23 , the Training accuracy is :- 1.0
#  At random state 23 , the testing accuracy is :- 0.7305046426568529
#
#
#  At random state 24 , the Training accuracy is :- 1.0
#  At random state 24 , the testing accuracy is :- 0.7369762816172336
#
#
#  At random state 25 , the Training accuracy is :- 1.0
#  At random state 25 , the testing accuracy is :- 0.7508950319206951
#
#
#  At random state 26 , the Training accuracy is :- 1.0
#  At random state 26 , the testing accuracy is :- 0.7189816598524315
#
#
#  At random state 27 , the Training accuracy is :- 1.0
#  At random state 27 , the testing accuracy is :- 0.7260437598898135
#
#
#  At random state 28 , the Training accuracy is :- 1.0
#  At random state 28 , the testing accuracy is :- 0.7377187796617801
#
#
#  At random state 29 , the Training accuracy is :- 1.0
#  At random state 29 , the testing accuracy is :- 0.712534086570425
#
#
#  At random state 30 , the Training accuracy is :- 1.0
#  At random state 30 , the testing accuracy is :- 0.7111437139258834
#
#
#  At random state 31 , the Training accuracy is :- 1.0
#  At random state 31 , the testing accuracy is :- 0.7283262574146132
#
#
#  At random state 32 , the Training accuracy is :- 1.0
#  At random state 32 , the testing accuracy is :- 0.7487877181974829
#
#
#  At random state 33 , the Training accuracy is :- 1.0
#  At random state 33 , the testing accuracy is :- 0.6999069818736154
#
#
#  At random state 34 , the Training accuracy is :- 1.0
#  At random state 34 , the testing accuracy is :- 0.7338571480029774
#
#
#  At random state 35 , the Training accuracy is :- 1.0
#  At random state 35 , the testing accuracy is :- 0.7021663362883559
#
#
#  At random state 36 , the Training accuracy is :- 1.0
#  At random state 36 , the testing accuracy is :- 0.733718226719968
#
#
#  At random state 37 , the Training accuracy is :- 1.0
#  At random state 37 , the testing accuracy is :- 0.7163325342905711
#
#
#  At random state 38 , the Training accuracy is :- 1.0
#  At random state 38 , the testing accuracy is :- 0.7360503620244208
#
#
#  At random state 39 , the Training accuracy is :- 1.0
#  At random state 39 , the testing accuracy is :- 0.7323549037227388
#
#
#  At random state 40 , the Training accuracy is :- 1.0
#  At random state 40 , the testing accuracy is :- 0.7327509273612994
#
#
#  At random state 41 , the Training accuracy is :- 1.0
#  At random state 41 , the testing accuracy is :- 0.6916167179682968
#
#
#  At random state 42 , the Training accuracy is :- 1.0
#  At random state 42 , the testing accuracy is :- 0.750968410996177
#
#
#  At random state 43 , the Training accuracy is :- 1.0
#  At random state 43 , the testing accuracy is :- 0.7654163721216671
#
#
#  At random state 44 , the Training accuracy is :- 1.0
#  At random state 44 , the testing accuracy is :- 0.6717993975261958
#
#
#  At random state 45 , the Training accuracy is :- 1.0
#  At random state 45 , the testing accuracy is :- 0.7496332073530615
#
#
#  At random state 46 , the Training accuracy is :- 1.0
#  At random state 46 , the testing accuracy is :- 0.7476066708392302
#
#
#  At random state 47 , the Training accuracy is :- 1.0
#  At random state 47 , the testing accuracy is :- 0.7407204929584281
#
#
#  At random state 48 , the Training accuracy is :- 1.0
#  At random state 48 , the testing accuracy is :- 0.7425820561177993
#
#
#  At random state 49 , the Training accuracy is :- 1.0
#  At random state 49 , the testing accuracy is :- 0.7275035168795544
#
#
#  At random state 50 , the Training accuracy is :- 1.0
#  At random state 50 , the testing accuracy is :- 0.7552282201464671
#
#
#  At random state 51 , the Training accuracy is :- 1.0
#  At random state 51 , the testing accuracy is :- 0.7275614408045226
#
#
#  At random state 52 , the Training accuracy is :- 1.0
#  At random state 52 , the testing accuracy is :- 0.7261837927364075
#
#
#  At random state 53 , the Training accuracy is :- 1.0
#  At random state 53 , the testing accuracy is :- 0.7440181972972106
#
#
#  At random state 54 , the Training accuracy is :- 1.0
#  At random state 54 , the testing accuracy is :- 0.7707937591248625
#
#
#  At random state 55 , the Training accuracy is :- 1.0
#  At random state 55 , the testing accuracy is :- 0.7453756053513281
#
#
#  At random state 56 , the Training accuracy is :- 1.0
#  At random state 56 , the testing accuracy is :- 0.7325665128552984
#
#
#  At random state 57 , the Training accuracy is :- 1.0
#  At random state 57 , the testing accuracy is :- 0.7177185152826719
#
#
#  At random state 58 , the Training accuracy is :- 1.0
#  At random state 58 , the testing accuracy is :- 0.7390118257126062
#
#
#  At random state 59 , the Training accuracy is :- 1.0
#  At random state 59 , the testing accuracy is :- 0.7502655286673696
#
#
#  At random state 60 , the Training accuracy is :- 1.0
#  At random state 60 , the testing accuracy is :- 0.7651858936619398
#
#
#  At random state 61 , the Training accuracy is :- 1.0
#  At random state 61 , the testing accuracy is :- 0.734527319277377
#
#
#  At random state 62 , the Training accuracy is :- 1.0
#  At random state 62 , the testing accuracy is :- 0.7131549424669923
#
#
#  At random state 63 , the Training accuracy is :- 1.0
#  At random state 63 , the testing accuracy is :- 0.6996947131137048
#
#
#  At random state 64 , the Training accuracy is :- 1.0
#  At random state 64 , the testing accuracy is :- 0.7584414174616099
#
#
#  At random state 65 , the Training accuracy is :- 1.0
#  At random state 65 , the testing accuracy is :- 0.717990448381689
#
#
#  At random state 66 , the Training accuracy is :- 1.0
#  At random state 66 , the testing accuracy is :- 0.716821866319159
#
#
#  At random state 67 , the Training accuracy is :- 1.0
#  At random state 67 , the testing accuracy is :- 0.6945788943204251
#
#
#  At random state 68 , the Training accuracy is :- 1.0
#  At random state 68 , the testing accuracy is :- 0.7432873608982068
#
#
#  At random state 69 , the Training accuracy is :- 1.0
#  At random state 69 , the testing accuracy is :- 0.7652149138201194
#
#
#  At random state 70 , the Training accuracy is :- 1.0
#  At random state 70 , the testing accuracy is :- 0.7548531608273626
#
#
#  At random state 71 , the Training accuracy is :- 1.0
#  At random state 71 , the testing accuracy is :- 0.7255505767918289
#
#
#  At random state 72 , the Training accuracy is :- 1.0
#  At random state 72 , the testing accuracy is :- 0.7227222035309098
#
#
#  At random state 73 , the Training accuracy is :- 1.0
#  At random state 73 , the testing accuracy is :- 0.7055874209718722
#
#
#  At random state 74 , the Training accuracy is :- 1.0
#  At random state 74 , the testing accuracy is :- 0.734269042963132
#
#
#  At random state 75 , the Training accuracy is :- 1.0
#  At random state 75 , the testing accuracy is :- 0.711483721305824
#
#
#  At random state 76 , the Training accuracy is :- 1.0
#  At random state 76 , the testing accuracy is :- 0.7312073518068547
#
#
#  At random state 77 , the Training accuracy is :- 1.0
#  At random state 77 , the testing accuracy is :- 0.7202307393597059
#
#
#  At random state 78 , the Training accuracy is :- 1.0
#  At random state 78 , the testing accuracy is :- 0.7637563879576957
#
#
#  At random state 79 , the Training accuracy is :- 1.0
#  At random state 79 , the testing accuracy is :- 0.7639973308914602
#
#
#  At random state 80 , the Training accuracy is :- 1.0
#  At random state 80 , the testing accuracy is :- 0.7597386491528446
#
#
#  At random state 81 , the Training accuracy is :- 1.0
#  At random state 81 , the testing accuracy is :- 0.7410735167481421
#
#
#  At random state 82 , the Training accuracy is :- 1.0
#  At random state 82 , the testing accuracy is :- 0.7152523772224848
#
#
#  At random state 83 , the Training accuracy is :- 1.0
#  At random state 83 , the testing accuracy is :- 0.7278721750962838
#
#
#  At random state 84 , the Training accuracy is :- 1.0
#  At random state 84 , the testing accuracy is :- 0.7499666122867061
#
#
#  At random state 85 , the Training accuracy is :- 1.0
#  At random state 85 , the testing accuracy is :- 0.7539168090763284
#
#
#  At random state 86 , the Training accuracy is :- 1.0
#  At random state 86 , the testing accuracy is :- 0.6754329452581658
#
#
#  At random state 87 , the Training accuracy is :- 1.0
#  At random state 87 , the testing accuracy is :- 0.7207521298064596
#
#
#  At random state 88 , the Training accuracy is :- 1.0
#  At random state 88 , the testing accuracy is :- 0.7396411217536214
#
#
#  At random state 89 , the Training accuracy is :- 1.0
#  At random state 89 , the testing accuracy is :- 0.7113012261310308
#
#
#  At random state 90 , the Training accuracy is :- 1.0
#  At random state 90 , the testing accuracy is :- 0.7403250559834542
#
#
#  At random state 91 , the Training accuracy is :- 1.0
#  At random state 91 , the testing accuracy is :- 0.7316454881118524
#
#
#  At random state 92 , the Training accuracy is :- 1.0
#  At random state 92 , the testing accuracy is :- 0.7352697422361311
#
#
#  At random state 93 , the Training accuracy is :- 1.0
#  At random state 93 , the testing accuracy is :- 0.7539649132762001
#
#
#  At random state 94 , the Training accuracy is :- 1.0
#  At random state 94 , the testing accuracy is :- 0.7380639154728708
#
#
#  At random state 95 , the Training accuracy is :- 1.0
#  At random state 95 , the testing accuracy is :- 0.7287245540740204
#
#
#  At random state 96 , the Training accuracy is :- 1.0
#  At random state 96 , the testing accuracy is :- 0.7292017353028217
#
#
#  At random state 97 , the Training accuracy is :- 1.0
#  At random state 97 , the testing accuracy is :- 0.7129855178617619
#
#
#  At random state 98 , the Training accuracy is :- 1.0
#  At random state 98 , the testing accuracy is :- 0.7002237310568835
#
#
#  At random state 99 , the Training accuracy is :- 1.0
#  At random state 99 , the testing accuracy is :- 0.7666169040779376

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
#Lets Print Training Score
pred_train=dt.predict(x_train)
print(r2_score(y_train,pred_train))
# Out:
# 1.0

# %%
#Lets Print Testing Score
train_pred=dt.predict(x_test)
print(r2_score(y_test,train_pred))
# Out:
# 0.7714146648969058

# %% [markdown]
# # Cross Validation of the Model

# %%
train_accuracy=r2_score(y_train,x_pred)
test_accuracy=r2_score(y_test,y_pred)
#Lets import Cross Validation
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(dt,x,y,cv=j)
    cv_mean=cv_score.mean()
    
    print(f"At cross fold {j} the CV Score is {cv_mean} and accuracy for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the CV Score is -0.29569024497286955 and accuracy for training is -1.0207183930795272 and accuracy for testing is -0.9977211296326078
#
#
# At cross fold 3 the CV Score is 0.04750269986494934 and accuracy for training is -1.0207183930795272 and accuracy for testing is -0.9977211296326078
#
#
# At cross fold 4 the CV Score is -0.6232189159822653 and accuracy for training is -1.0207183930795272 and accuracy for testing is -0.9977211296326078
#
#
# At cross fold 5 the CV Score is -0.01684382537239475 and accuracy for training is -1.0207183930795272 and accuracy for testing is -0.9977211296326078
#
#
# At cross fold 6 the CV Score is 0.3530832556084457 and accuracy for training is -1.0207183930795272 and accuracy for testing is -0.9977211296326078
#
#
# At cross fold 7 the CV Score is 0.413163668797315 and accuracy for training is -1.0207183930795272 and accuracy for testing is -0.9977211296326078
#
#
# At cross fold 8 the CV Score is 0.4984685364958897 and accuracy for training is -1.0207183930795272 and accuracy for testing is -0.9977211296326078
#
#
# At cross fold 9 the CV Score is 0.5284104997457146 and accuracy for training is -1.0207183930795272 and accuracy for testing is -0.9977211296326078

# %% [markdown]
# # Lets Plot Best Fit Line and Check How Data points are Close to the Best Fit Line

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=train_pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Acutal Charges ",fontsize=14)
plt.ylabel("Predicted Charges ",fontsize=14)
plt.title("Decision Tree Regression ",fontsize=18)
plt.savefig('dt.png')
plt.show()

# %% [markdown]
# # Lets Plot With Ada Boost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()

# %%
#Lets check with diffrent method
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    ada.fit(x_train,y_train)
    x_pred=ada.predict(x_train)
    y_pred=ada.predict(x_test)
    print(f" At random state {i} , the Training accuracy is :- {r2_score(y_train,x_pred)}")
    print(f" At random state {i} , the testing accuracy is :- {r2_score(y_test,y_pred)}")
    print("\n")
# Out:
#  At random state 0 , the Training accuracy is :- 0.7222498880308253
#  At random state 0 , the testing accuracy is :- 0.7094080195956924
#
#
#  At random state 1 , the Training accuracy is :- 0.6553796318421916
#  At random state 1 , the testing accuracy is :- 0.6473082494609164
#
#
#  At random state 2 , the Training accuracy is :- 0.6699202135309179
#  At random state 2 , the testing accuracy is :- 0.656300103305683
#
#
#  At random state 3 , the Training accuracy is :- 0.6497222586869771
#  At random state 3 , the testing accuracy is :- 0.6635687302040791
#
#
#  At random state 4 , the Training accuracy is :- 0.5358312037951287
#  At random state 4 , the testing accuracy is :- 0.5392991634046097
#
#
#  At random state 5 , the Training accuracy is :- 0.5842414476379276
#  At random state 5 , the testing accuracy is :- 0.5940954435460557
#
#
#  At random state 6 , the Training accuracy is :- 0.491396747656352
#  At random state 6 , the testing accuracy is :- 0.4792892265133464
#
#
#  At random state 7 , the Training accuracy is :- 0.6032104044104241
#  At random state 7 , the testing accuracy is :- 0.574726058527251
#
#
#  At random state 8 , the Training accuracy is :- 0.6567902622886501
#  At random state 8 , the testing accuracy is :- 0.6093782357127513
#
#
#  At random state 9 , the Training accuracy is :- 0.4929574117204185
#  At random state 9 , the testing accuracy is :- 0.47470482264144076
#
#
#  At random state 10 , the Training accuracy is :- 0.6292625607813316
#  At random state 10 , the testing accuracy is :- 0.587314036672343
#
#
#  At random state 11 , the Training accuracy is :- 0.5778913218130481
#  At random state 11 , the testing accuracy is :- 0.5660546566328409
#
#
#  At random state 12 , the Training accuracy is :- 0.6642176273754802
#  At random state 12 , the testing accuracy is :- 0.6470853331849885
#
#
#  At random state 13 , the Training accuracy is :- 0.6791798622965798
#  At random state 13 , the testing accuracy is :- 0.6644789781470996
#
#
#  At random state 14 , the Training accuracy is :- 0.5681572955353513
#  At random state 14 , the testing accuracy is :- 0.5536338051977734
#
#
#  At random state 15 , the Training accuracy is :- 0.7181503290813023
#  At random state 15 , the testing accuracy is :- 0.6950439193347528
#
#
#  At random state 16 , the Training accuracy is :- 0.6179999812400558
#  At random state 16 , the testing accuracy is :- 0.6146712092127236
#
#
#  At random state 17 , the Training accuracy is :- 0.6077226845394124
#  At random state 17 , the testing accuracy is :- 0.6262454093420986
#
#
#  At random state 18 , the Training accuracy is :- 0.6154951156130374
#  At random state 18 , the testing accuracy is :- 0.6016000644440469
#
#
#  At random state 19 , the Training accuracy is :- 0.5229366773668336
#  At random state 19 , the testing accuracy is :- 0.5168674608031891
#
#
#  At random state 20 , the Training accuracy is :- 0.4878419756274829
#  At random state 20 , the testing accuracy is :- 0.4669725611686296
#
#
#  At random state 21 , the Training accuracy is :- 0.632438527826562
#  At random state 21 , the testing accuracy is :- 0.5958935765175934
#
#
#  At random state 22 , the Training accuracy is :- 0.7028083623205692
#  At random state 22 , the testing accuracy is :- 0.6842775670550392
#
#
#  At random state 23 , the Training accuracy is :- 0.6544013967519163
#  At random state 23 , the testing accuracy is :- 0.6393376036115246
#
#
#  At random state 24 , the Training accuracy is :- 0.6243242224669148
#  At random state 24 , the testing accuracy is :- 0.5636311322734885
#
#
#  At random state 25 , the Training accuracy is :- 0.6251310546492537
#  At random state 25 , the testing accuracy is :- 0.6262166359002665
#
#
#  At random state 26 , the Training accuracy is :- 0.7274318100603476
#  At random state 26 , the testing accuracy is :- 0.7187582892629669
#
#
#  At random state 27 , the Training accuracy is :- 0.5415377150294928
#  At random state 27 , the testing accuracy is :- 0.5491699564019622
#
#
#  At random state 28 , the Training accuracy is :- 0.5785671179713903
#  At random state 28 , the testing accuracy is :- 0.5754773602714202
#
#
#  At random state 29 , the Training accuracy is :- 0.6580378444351473
#  At random state 29 , the testing accuracy is :- 0.6424604924942143
#
#
#  At random state 30 , the Training accuracy is :- 0.6848068781538135
#  At random state 30 , the testing accuracy is :- 0.6675520690636758
#
#
#  At random state 31 , the Training accuracy is :- 0.6103815644558143
#  At random state 31 , the testing accuracy is :- 0.5972201606810226
#
#
#  At random state 32 , the Training accuracy is :- 0.6323572061101295
#  At random state 32 , the testing accuracy is :- 0.6242815701477714
#
#
#  At random state 33 , the Training accuracy is :- 0.7266358960967182
#  At random state 33 , the testing accuracy is :- 0.6876745783177882
#
#
#  At random state 34 , the Training accuracy is :- 0.5908541873114915
#  At random state 34 , the testing accuracy is :- 0.5777091248000421
#
#
#  At random state 35 , the Training accuracy is :- 0.6566524737102719
#  At random state 35 , the testing accuracy is :- 0.6589385844467809
#
#
#  At random state 36 , the Training accuracy is :- 0.5904547045310675
#  At random state 36 , the testing accuracy is :- 0.5490506963936224
#
#
#  At random state 37 , the Training accuracy is :- 0.7485994256323468
#  At random state 37 , the testing accuracy is :- 0.7291475003103379
#
#
#  At random state 38 , the Training accuracy is :- 0.5815998927844104
#  At random state 38 , the testing accuracy is :- 0.5593674577956778
#
#
#  At random state 39 , the Training accuracy is :- 0.5356560201031029
#  At random state 39 , the testing accuracy is :- 0.5105223382800599
#
#
#  At random state 40 , the Training accuracy is :- 0.710199144088272
#  At random state 40 , the testing accuracy is :- 0.7241430828177058
#
#
#  At random state 41 , the Training accuracy is :- 0.590866268359542
#  At random state 41 , the testing accuracy is :- 0.544261507262073
#
#
#  At random state 42 , the Training accuracy is :- 0.5849838490163778
#  At random state 42 , the testing accuracy is :- 0.595264409691139
#
#
#  At random state 43 , the Training accuracy is :- 0.7276970365873843
#  At random state 43 , the testing accuracy is :- 0.7263336803758587
#
#
#  At random state 44 , the Training accuracy is :- 0.7474306187902715
#  At random state 44 , the testing accuracy is :- 0.7251794829427642
#
#
#  At random state 45 , the Training accuracy is :- 0.5241808919655292
#  At random state 45 , the testing accuracy is :- 0.5166913229308204
#
#
#  At random state 46 , the Training accuracy is :- 0.553665760285895
#  At random state 46 , the testing accuracy is :- 0.5472115616615326
#
#
#  At random state 47 , the Training accuracy is :- 0.623775300480784
#  At random state 47 , the testing accuracy is :- 0.6298717989944492
#
#
#  At random state 48 , the Training accuracy is :- 0.638441939835598
#  At random state 48 , the testing accuracy is :- 0.5952843873347002
#
#
#  At random state 49 , the Training accuracy is :- 0.6167470605501653
#  At random state 49 , the testing accuracy is :- 0.5965273690320904
#
#
#  At random state 50 , the Training accuracy is :- 0.668417341391873
#  At random state 50 , the testing accuracy is :- 0.6628479505447693
#
#
#  At random state 51 , the Training accuracy is :- 0.7031941179706978
#  At random state 51 , the testing accuracy is :- 0.6950362510002549
#
#
#  At random state 52 , the Training accuracy is :- 0.6292209659918229
#  At random state 52 , the testing accuracy is :- 0.6144262224710888
#
#
#  At random state 53 , the Training accuracy is :- 0.6080092842021347
#  At random state 53 , the testing accuracy is :- 0.5929058696987513
#
#
#  At random state 54 , the Training accuracy is :- 0.717417141168633
#  At random state 54 , the testing accuracy is :- 0.7285703243134978
#
#
#  At random state 55 , the Training accuracy is :- 0.6329238980658015
#  At random state 55 , the testing accuracy is :- 0.6294594665972266
#
#
#  At random state 56 , the Training accuracy is :- 0.6688998203237229
#  At random state 56 , the testing accuracy is :- 0.6781768766408028
#
#
#  At random state 57 , the Training accuracy is :- 0.6811046499094918
#  At random state 57 , the testing accuracy is :- 0.6620640855991139
#
#
#  At random state 58 , the Training accuracy is :- 0.6896608120862523
#  At random state 58 , the testing accuracy is :- 0.6493470231444085
#
#
#  At random state 59 , the Training accuracy is :- 0.7226873188487914
#  At random state 59 , the testing accuracy is :- 0.7328128090361503
#
#
#  At random state 60 , the Training accuracy is :- 0.5767829111649998
#  At random state 60 , the testing accuracy is :- 0.6115949046927358
#
#
#  At random state 61 , the Training accuracy is :- 0.6784951566101584
#  At random state 61 , the testing accuracy is :- 0.6272219599081147
#
#
#  At random state 62 , the Training accuracy is :- 0.7582418275712706
#  At random state 62 , the testing accuracy is :- 0.730313891225711
#
#
#  At random state 63 , the Training accuracy is :- 0.753235876377292
#  At random state 63 , the testing accuracy is :- 0.736784394902479
#
#
#  At random state 64 , the Training accuracy is :- 0.6529863686556593
#  At random state 64 , the testing accuracy is :- 0.6541850637043162
#
#
#  At random state 65 , the Training accuracy is :- 0.6516223178667973
#  At random state 65 , the testing accuracy is :- 0.6352420449492633
#
#
#  At random state 66 , the Training accuracy is :- 0.5100523191040645
#  At random state 66 , the testing accuracy is :- 0.46327025863594906
#
#
#  At random state 67 , the Training accuracy is :- 0.546377041264688
#  At random state 67 , the testing accuracy is :- 0.5289324987802302
#
#
#  At random state 68 , the Training accuracy is :- 0.678072114454985
#  At random state 68 , the testing accuracy is :- 0.6378211671759626
#
#
#  At random state 69 , the Training accuracy is :- 0.5680937172094067
#  At random state 69 , the testing accuracy is :- 0.5835288157742533
#
#
#  At random state 70 , the Training accuracy is :- 0.5257852672995599
#  At random state 70 , the testing accuracy is :- 0.5175579769954309
#
#
#  At random state 71 , the Training accuracy is :- 0.5490070335875501
#  At random state 71 , the testing accuracy is :- 0.5542766604559488
#
#
#  At random state 72 , the Training accuracy is :- 0.646201928013169
#  At random state 72 , the testing accuracy is :- 0.6438059265108276
#
#
#  At random state 73 , the Training accuracy is :- 0.6094581716674896
#  At random state 73 , the testing accuracy is :- 0.5961065327575683
#
#
#  At random state 74 , the Training accuracy is :- 0.7423878179587056
#  At random state 74 , the testing accuracy is :- 0.7321421041470342
#
#
#  At random state 75 , the Training accuracy is :- 0.6533509494410145
#  At random state 75 , the testing accuracy is :- 0.6374258269898118
#
#
#  At random state 76 , the Training accuracy is :- 0.5890726928747115
#  At random state 76 , the testing accuracy is :- 0.5645865144249815
#
#
#  At random state 77 , the Training accuracy is :- 0.65669615602869
#  At random state 77 , the testing accuracy is :- 0.650892200612367
#
#
#  At random state 78 , the Training accuracy is :- 0.6966746521630407
#  At random state 78 , the testing accuracy is :- 0.7018557117245392
#
#
#  At random state 79 , the Training accuracy is :- 0.5363539765637073
#  At random state 79 , the testing accuracy is :- 0.5502891660283789
#
#
#  At random state 80 , the Training accuracy is :- 0.6062815103837234
#  At random state 80 , the testing accuracy is :- 0.6342672502002669
#
#
#  At random state 81 , the Training accuracy is :- 0.5985925007361852
#  At random state 81 , the testing accuracy is :- 0.5900828432359025
#
#
#  At random state 82 , the Training accuracy is :- 0.5059861412398213
#  At random state 82 , the testing accuracy is :- 0.47496990098495406
#
#
#  At random state 83 , the Training accuracy is :- 0.6683439277251014
#  At random state 83 , the testing accuracy is :- 0.6693962996041986
#
#
#  At random state 84 , the Training accuracy is :- 0.5396643094359664
#  At random state 84 , the testing accuracy is :- 0.5644677411441925
#
#
#  At random state 85 , the Training accuracy is :- 0.6973609742154725
#  At random state 85 , the testing accuracy is :- 0.7049097453444737
#
#
#  At random state 86 , the Training accuracy is :- 0.7514206115164052
#  At random state 86 , the testing accuracy is :- 0.7322170981128102
#
#
#  At random state 87 , the Training accuracy is :- 0.6028756596273035
#  At random state 87 , the testing accuracy is :- 0.5719693778879356
#
#
#  At random state 88 , the Training accuracy is :- 0.7003464643657944
#  At random state 88 , the testing accuracy is :- 0.6792948270490247
#
#
#  At random state 89 , the Training accuracy is :- 0.6183746402350077
#  At random state 89 , the testing accuracy is :- 0.6034040251934263
#
#
#  At random state 90 , the Training accuracy is :- 0.7309778996230768
#  At random state 90 , the testing accuracy is :- 0.7375926294176649
#
#
#  At random state 91 , the Training accuracy is :- 0.6679603247412746
#  At random state 91 , the testing accuracy is :- 0.670458387410428
#
#
#  At random state 92 , the Training accuracy is :- 0.7618240697426273
#  At random state 92 , the testing accuracy is :- 0.7502590329784381
#
#
#  At random state 93 , the Training accuracy is :- 0.5796675271024818
#  At random state 93 , the testing accuracy is :- 0.5541040769602339
#
#
#  At random state 94 , the Training accuracy is :- 0.5809802194081489
#  At random state 94 , the testing accuracy is :- 0.5698948848305574
#
#
#  At random state 95 , the Training accuracy is :- 0.54394683280613
#  At random state 95 , the testing accuracy is :- 0.5001719111224645
#
#
#  At random state 96 , the Training accuracy is :- 0.5871571607808714
#  At random state 96 , the testing accuracy is :- 0.553294455315539
#
#
#  At random state 97 , the Training accuracy is :- 0.5963140985095581
#  At random state 97 , the testing accuracy is :- 0.5154415981862077
#
#
#  At random state 98 , the Training accuracy is :- 0.6168691028975763
#  At random state 98 , the testing accuracy is :- 0.5946649372468926
#
#
#  At random state 99 , the Training accuracy is :- 0.6435245150407674
#  At random state 99 , the testing accuracy is :- 0.6681425878463697

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=63)

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
#Lets Print Training Score
pred_train=ada.predict(x_train)
print(r2_score(y_train,pred_train))
# Out:
# 0.7141209547816221

# %%
#Lets Print Testing Score
train_pred=ada.predict(x_test)
print(r2_score(y_test,train_pred))
# Out:
# 0.6841789199706019

# %% [markdown]
# # Cross Validation of the Model

# %%
train_accuracy=r2_score(y_train,x_pred)
test_accuracy=r2_score(y_test,y_pred)
#Lets import Cross Validation
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(ada,x,y,cv=j)
    cv_mean=cv_score.mean()
    
    print(f"At cross fold {j} the CV Score is {cv_mean} and accuracy for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the CV Score is 0.34871417644425645 and accuracy for training is -0.767798988312554 and accuracy for testing is -0.8821529744507606
#
#
# At cross fold 3 the CV Score is 0.3347224372613968 and accuracy for training is -0.767798988312554 and accuracy for testing is -0.8821529744507606
#
#
# At cross fold 4 the CV Score is 0.36234761164863405 and accuracy for training is -0.767798988312554 and accuracy for testing is -0.8821529744507606
#
#
# At cross fold 5 the CV Score is 0.34121491108061247 and accuracy for training is -0.767798988312554 and accuracy for testing is -0.8821529744507606
#
#
# At cross fold 6 the CV Score is 0.3535933214025211 and accuracy for training is -0.767798988312554 and accuracy for testing is -0.8821529744507606
#
#
# At cross fold 7 the CV Score is 0.3989238033675801 and accuracy for training is -0.767798988312554 and accuracy for testing is -0.8821529744507606
#
#
# At cross fold 8 the CV Score is 0.37405079164363486 and accuracy for training is -0.767798988312554 and accuracy for testing is -0.8821529744507606
#
#
# At cross fold 9 the CV Score is 0.37636897597747304 and accuracy for training is -0.767798988312554 and accuracy for testing is -0.8821529744507606

# %% [markdown]
# # Lets Plot Best Fit Line and Check How Data points are Close to the Best Fit Line

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=train_pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Acutal Charges ",fontsize=14)
plt.ylabel("Predicted Charges ",fontsize=14)
plt.title("Ada Boost Regression ",fontsize=18)
plt.savefig('ada.png')
plt.show()

# %% [markdown]
# # Lets Plot With XGBOOST Regressor

# %%
import xgboost as xgb
xgb = xgb.XGBRegressor()

# %%
#Lets check with diffrent method
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    xgb.fit(x_train,y_train)
    x_pred=xgb.predict(x_train)
    y_pred=xgb.predict(x_test)
    print(f" At random state {i} , the Training accuracy is :- {r2_score(y_train,x_pred)}")
    print(f" At random state {i} , the testing accuracy is :- {r2_score(y_test,y_pred)}")
    print("\n")
# Out:
#  At random state 0 , the Training accuracy is :- 0.9638592167672033
#  At random state 0 , the testing accuracy is :- 0.857936666505722
#
#
#  At random state 1 , the Training accuracy is :- 0.9621309572669164
#  At random state 1 , the testing accuracy is :- 0.8513330421653084
#
#
#  At random state 2 , the Training accuracy is :- 0.9622220228940234
#  At random state 2 , the testing accuracy is :- 0.8590399174401622
#
#
#  At random state 3 , the Training accuracy is :- 0.9634851738074144
#  At random state 3 , the testing accuracy is :- 0.8616010248616932
#
#
#  At random state 4 , the Training accuracy is :- 0.9636939756695571
#  At random state 4 , the testing accuracy is :- 0.8725655851879951
#
#
#  At random state 5 , the Training accuracy is :- 0.962845963327265
#  At random state 5 , the testing accuracy is :- 0.854261482898031
#
#
#  At random state 6 , the Training accuracy is :- 0.9609022423006184
#  At random state 6 , the testing accuracy is :- 0.8771560634664226
#
#
#  At random state 7 , the Training accuracy is :- 0.9635313753609397
#  At random state 7 , the testing accuracy is :- 0.8591710052643563
#
#
#  At random state 8 , the Training accuracy is :- 0.962009603366502
#  At random state 8 , the testing accuracy is :- 0.8558830670874961
#
#
#  At random state 9 , the Training accuracy is :- 0.9634785945487359
#  At random state 9 , the testing accuracy is :- 0.8600799611654417
#
#
#  At random state 10 , the Training accuracy is :- 0.9646191494097023
#  At random state 10 , the testing accuracy is :- 0.8536075237205658
#
#
#  At random state 11 , the Training accuracy is :- 0.9630741024030218
#  At random state 11 , the testing accuracy is :- 0.852110568833135
#
#
#  At random state 12 , the Training accuracy is :- 0.9621543923127186
#  At random state 12 , the testing accuracy is :- 0.8594036255916806
#
#
#  At random state 13 , the Training accuracy is :- 0.9628596245049956
#  At random state 13 , the testing accuracy is :- 0.8649897290725767
#
#
#  At random state 14 , the Training accuracy is :- 0.9634214169381419
#  At random state 14 , the testing accuracy is :- 0.8623260191188387
#
#
#  At random state 15 , the Training accuracy is :- 0.9634578410235325
#  At random state 15 , the testing accuracy is :- 0.8437745792523786
#
#
#  At random state 16 , the Training accuracy is :- 0.9645445182385027
#  At random state 16 , the testing accuracy is :- 0.8551547198629212
#
#
#  At random state 17 , the Training accuracy is :- 0.962818366229492
#  At random state 17 , the testing accuracy is :- 0.8690599767409523
#
#
#  At random state 18 , the Training accuracy is :- 0.963747573877657
#  At random state 18 , the testing accuracy is :- 0.8633710683575944
#
#
#  At random state 19 , the Training accuracy is :- 0.9642495261719721
#  At random state 19 , the testing accuracy is :- 0.8516113259423914
#
#
#  At random state 20 , the Training accuracy is :- 0.9604420600614635
#  At random state 20 , the testing accuracy is :- 0.8625939761096937
#
#
#  At random state 21 , the Training accuracy is :- 0.9619401228387001
#  At random state 21 , the testing accuracy is :- 0.8470269334115613
#
#
#  At random state 22 , the Training accuracy is :- 0.9653065969150467
#  At random state 22 , the testing accuracy is :- 0.8541516427654694
#
#
#  At random state 23 , the Training accuracy is :- 0.9646092830921909
#  At random state 23 , the testing accuracy is :- 0.8590800664088069
#
#
#  At random state 24 , the Training accuracy is :- 0.9651227502133403
#  At random state 24 , the testing accuracy is :- 0.8491606453405864
#
#
#  At random state 25 , the Training accuracy is :- 0.9652869279831087
#  At random state 25 , the testing accuracy is :- 0.8560140369629137
#
#
#  At random state 26 , the Training accuracy is :- 0.9631417934103342
#  At random state 26 , the testing accuracy is :- 0.8576066520474743
#
#
#  At random state 27 , the Training accuracy is :- 0.964042304793491
#  At random state 27 , the testing accuracy is :- 0.857038636921915
#
#
#  At random state 28 , the Training accuracy is :- 0.9612712713756928
#  At random state 28 , the testing accuracy is :- 0.8635068599769684
#
#
#  At random state 29 , the Training accuracy is :- 0.9638413743107194
#  At random state 29 , the testing accuracy is :- 0.8614249111632384
#
#
#  At random state 30 , the Training accuracy is :- 0.9654724549553143
#  At random state 30 , the testing accuracy is :- 0.847755578008115
#
#
#  At random state 31 , the Training accuracy is :- 0.9646224533324272
#  At random state 31 , the testing accuracy is :- 0.8506785381233807
#
#
#  At random state 32 , the Training accuracy is :- 0.9627373788467417
#  At random state 32 , the testing accuracy is :- 0.8633493838499794
#
#
#  At random state 33 , the Training accuracy is :- 0.9633219237720924
#  At random state 33 , the testing accuracy is :- 0.8478879381308035
#
#
#  At random state 34 , the Training accuracy is :- 0.9630157561917744
#  At random state 34 , the testing accuracy is :- 0.8609424824430293
#
#
#  At random state 35 , the Training accuracy is :- 0.9632717031964485
#  At random state 35 , the testing accuracy is :- 0.8616333366342299
#
#
#  At random state 36 , the Training accuracy is :- 0.9633387675897312
#  At random state 36 , the testing accuracy is :- 0.8485508044811063
#
#
#  At random state 37 , the Training accuracy is :- 0.9608657674128114
#  At random state 37 , the testing accuracy is :- 0.8556151489492281
#
#
#  At random state 38 , the Training accuracy is :- 0.964286784609422
#  At random state 38 , the testing accuracy is :- 0.8536819537829397
#
#
#  At random state 39 , the Training accuracy is :- 0.9647830513212796
#  At random state 39 , the testing accuracy is :- 0.8620287175361057
#
#
#  At random state 40 , the Training accuracy is :- 0.963677798383514
#  At random state 40 , the testing accuracy is :- 0.86412060542768
#
#
#  At random state 41 , the Training accuracy is :- 0.964782321204776
#  At random state 41 , the testing accuracy is :- 0.8416813753237378
#
#
#  At random state 42 , the Training accuracy is :- 0.9613630412550567
#  At random state 42 , the testing accuracy is :- 0.8685534851181596
#
#
#  At random state 43 , the Training accuracy is :- 0.9613602950411728
#  At random state 43 , the testing accuracy is :- 0.8679368120205448
#
#
#  At random state 44 , the Training accuracy is :- 0.9639792125336688
#  At random state 44 , the testing accuracy is :- 0.8494417541272207
#
#
#  At random state 45 , the Training accuracy is :- 0.9633198268814879
#  At random state 45 , the testing accuracy is :- 0.8649499960550604
#
#
#  At random state 46 , the Training accuracy is :- 0.9643553723974753
#  At random state 46 , the testing accuracy is :- 0.8621087199473318
#
#
#  At random state 47 , the Training accuracy is :- 0.964438107709598
#  At random state 47 , the testing accuracy is :- 0.8701287694431742
#
#
#  At random state 48 , the Training accuracy is :- 0.962922350433814
#  At random state 48 , the testing accuracy is :- 0.8603731898740984
#
#
#  At random state 49 , the Training accuracy is :- 0.9634294170947811
#  At random state 49 , the testing accuracy is :- 0.8542802843266106
#
#
#  At random state 50 , the Training accuracy is :- 0.9632320643162519
#  At random state 50 , the testing accuracy is :- 0.8557674235184651
#
#
#  At random state 51 , the Training accuracy is :- 0.9633579480760683
#  At random state 51 , the testing accuracy is :- 0.8598983531026376
#
#
#  At random state 52 , the Training accuracy is :- 0.9631477850508864
#  At random state 52 , the testing accuracy is :- 0.8549676224263575
#
#
#  At random state 53 , the Training accuracy is :- 0.9628502140098374
#  At random state 53 , the testing accuracy is :- 0.8707944120195272
#
#
#  At random state 54 , the Training accuracy is :- 0.9631133284893708
#  At random state 54 , the testing accuracy is :- 0.8697897948504053
#
#
#  At random state 55 , the Training accuracy is :- 0.9642336632209652
#  At random state 55 , the testing accuracy is :- 0.8683177794245357
#
#
#  At random state 56 , the Training accuracy is :- 0.9654401481936247
#  At random state 56 , the testing accuracy is :- 0.8560623141056942
#
#
#  At random state 57 , the Training accuracy is :- 0.9627079965127955
#  At random state 57 , the testing accuracy is :- 0.8567223565702714
#
#
#  At random state 58 , the Training accuracy is :- 0.9641266322837072
#  At random state 58 , the testing accuracy is :- 0.8520055664568217
#
#
#  At random state 59 , the Training accuracy is :- 0.9627445463171798
#  At random state 59 , the testing accuracy is :- 0.8670210033004356
#
#
#  At random state 60 , the Training accuracy is :- 0.9610386624182896
#  At random state 60 , the testing accuracy is :- 0.8659033294406512
#
#
#  At random state 61 , the Training accuracy is :- 0.9657954835709534
#  At random state 61 , the testing accuracy is :- 0.8527049452441651
#
#
#  At random state 62 , the Training accuracy is :- 0.9667524031678283
#  At random state 62 , the testing accuracy is :- 0.8520267069485765
#
#
#  At random state 63 , the Training accuracy is :- 0.9650688283778167
#  At random state 63 , the testing accuracy is :- 0.8386050967018255
#
#
#  At random state 64 , the Training accuracy is :- 0.9660937943189367
#  At random state 64 , the testing accuracy is :- 0.8626530993583945
#
#
#  At random state 65 , the Training accuracy is :- 0.9631756627541079
#  At random state 65 , the testing accuracy is :- 0.8359572131206913
#
#
#  At random state 66 , the Training accuracy is :- 0.964473755156798
#  At random state 66 , the testing accuracy is :- 0.8471312277385583
#
#
#  At random state 67 , the Training accuracy is :- 0.9642118106799399
#  At random state 67 , the testing accuracy is :- 0.8519107560113761
#
#
#  At random state 68 , the Training accuracy is :- 0.9664202602754001
#  At random state 68 , the testing accuracy is :- 0.8506790880859205
#
#
#  At random state 69 , the Training accuracy is :- 0.9627914924096521
#  At random state 69 , the testing accuracy is :- 0.874963957420625
#
#
#  At random state 70 , the Training accuracy is :- 0.9632053826161961
#  At random state 70 , the testing accuracy is :- 0.8550220139911701
#
#
#  At random state 71 , the Training accuracy is :- 0.9645890092900569
#  At random state 71 , the testing accuracy is :- 0.8614051842771728
#
#
#  At random state 72 , the Training accuracy is :- 0.9627104657441774
#  At random state 72 , the testing accuracy is :- 0.8640318684924535
#
#
#  At random state 73 , the Training accuracy is :- 0.9644186338982718
#  At random state 73 , the testing accuracy is :- 0.8460396974026227
#
#
#  At random state 74 , the Training accuracy is :- 0.9615866145387093
#  At random state 74 , the testing accuracy is :- 0.8579181948222682
#
#
#  At random state 75 , the Training accuracy is :- 0.9641481510798985
#  At random state 75 , the testing accuracy is :- 0.850753946011069
#
#
#  At random state 76 , the Training accuracy is :- 0.9655290651121905
#  At random state 76 , the testing accuracy is :- 0.8590672080665992
#
#
#  At random state 77 , the Training accuracy is :- 0.9613766751295822
#  At random state 77 , the testing accuracy is :- 0.8577291168656371
#
#
#  At random state 78 , the Training accuracy is :- 0.9602078889175002
#  At random state 78 , the testing accuracy is :- 0.8607333910169216
#
#
#  At random state 79 , the Training accuracy is :- 0.9638733539834127
#  At random state 79 , the testing accuracy is :- 0.8631544530460239
#
#
#  At random state 80 , the Training accuracy is :- 0.962098350467331
#  At random state 80 , the testing accuracy is :- 0.8588688253895533
#
#
#  At random state 81 , the Training accuracy is :- 0.964537600121
#  At random state 81 , the testing accuracy is :- 0.8556761909616797
#
#
#  At random state 82 , the Training accuracy is :- 0.9623473578914782
#  At random state 82 , the testing accuracy is :- 0.8475636579933215
#
#
#  At random state 83 , the Training accuracy is :- 0.9625832054051243
#  At random state 83 , the testing accuracy is :- 0.8609747888238074
#
#
#  At random state 84 , the Training accuracy is :- 0.9621289276480143
#  At random state 84 , the testing accuracy is :- 0.8717735510470128
#
#
#  At random state 85 , the Training accuracy is :- 0.9636904820381396
#  At random state 85 , the testing accuracy is :- 0.8602378826021272
#
#
#  At random state 86 , the Training accuracy is :- 0.9644660149663249
#  At random state 86 , the testing accuracy is :- 0.8431463158929399
#
#
#  At random state 87 , the Training accuracy is :- 0.9641259382380768
#  At random state 87 , the testing accuracy is :- 0.8547649059882786
#
#
#  At random state 88 , the Training accuracy is :- 0.9654342626119484
#  At random state 88 , the testing accuracy is :- 0.8519995841730114
#
#
#  At random state 89 , the Training accuracy is :- 0.9630671832062716
#  At random state 89 , the testing accuracy is :- 0.8495582540833522
#
#
#  At random state 90 , the Training accuracy is :- 0.9626995494084235
#  At random state 90 , the testing accuracy is :- 0.8687057436908467
#
#
#  At random state 91 , the Training accuracy is :- 0.9607300655800839
#  At random state 91 , the testing accuracy is :- 0.8562553577203067
#
#
#  At random state 92 , the Training accuracy is :- 0.9628707682889407
#  At random state 92 , the testing accuracy is :- 0.8544904983672605
#
#
#  At random state 93 , the Training accuracy is :- 0.9626707524573149
#  At random state 93 , the testing accuracy is :- 0.8595193281765425
#
#
#  At random state 94 , the Training accuracy is :- 0.9645768616343149
#  At random state 94 , the testing accuracy is :- 0.8517714773060433
#
#
#  At random state 95 , the Training accuracy is :- 0.9629123111898191
#  At random state 95 , the testing accuracy is :- 0.8515299267248029
#
#
#  At random state 96 , the Training accuracy is :- 0.9596049669593861
#  At random state 96 , the testing accuracy is :- 0.8522117819218951
#
#
#  At random state 97 , the Training accuracy is :- 0.9619722453040082
#  At random state 97 , the testing accuracy is :- 0.8503340254683212
#
#
#  At random state 98 , the Training accuracy is :- 0.9644882714316307
#  At random state 98 , the testing accuracy is :- 0.8535527921868347
#
#
#  At random state 99 , the Training accuracy is :- 0.9625000688976513
#  At random state 99 , the testing accuracy is :- 0.8606965658272762

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=69)

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
#Lets Print Training Score
pred_train=xgb.predict(x_train)
print(r2_score(y_train,pred_train))
# Out:
# 0.9627914924096521

# %%
#Lets Print Testing Score
train_pred=xgb.predict(x_test)
print(r2_score(y_test,train_pred))
# Out:
# 0.874963957420625

# %% [markdown]
# # Cross Validation of the Model

# %%
train_accuracy=r2_score(y_train,x_pred)
test_accuracy=r2_score(y_test,y_pred)
#Lets import Cross Validation
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(xgb,x,y,cv=j)
    cv_mean=cv_score.mean()
    
    print(f"At cross fold {j} the CV Score is {cv_mean} and accuracy for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the CV Score is 0.3807888432368567 and accuracy for training is -0.9562305231558246 and accuracy for testing is -0.923204303024008
#
#
# At cross fold 3 the CV Score is 0.44985787325462495 and accuracy for training is -0.9562305231558246 and accuracy for testing is -0.923204303024008
#
#
# At cross fold 4 the CV Score is 0.5232700908010617 and accuracy for training is -0.9562305231558246 and accuracy for testing is -0.923204303024008
#
#
# At cross fold 5 the CV Score is 0.6066653771459352 and accuracy for training is -0.9562305231558246 and accuracy for testing is -0.923204303024008
#
#
# At cross fold 6 the CV Score is 0.6410929791801415 and accuracy for training is -0.9562305231558246 and accuracy for testing is -0.923204303024008
#
#
# At cross fold 7 the CV Score is 0.6555233843804585 and accuracy for training is -0.9562305231558246 and accuracy for testing is -0.923204303024008
#
#
# At cross fold 8 the CV Score is 0.6599495354737047 and accuracy for training is -0.9562305231558246 and accuracy for testing is -0.923204303024008
#
#
# At cross fold 9 the CV Score is 0.6727569113879386 and accuracy for training is -0.9562305231558246 and accuracy for testing is -0.923204303024008

# %% [markdown]
# # Lets Plot Best Fit Line and Check How Data points are Close to the Best Fit Line

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=train_pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Acutal Charges ",fontsize=14)
plt.ylabel("Predicted Charges ",fontsize=14)
plt.title("XGBOOST Regression ",fontsize=18)
plt.savefig('xgb.png')
plt.show()

# %% [markdown]
# #  Lets Plot With Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()

# %%
#Lets check with diffrent method
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    gbr.fit(x_train,y_train)
    x_pred=gbr.predict(x_train)
    y_pred=gbr.predict(x_test)
    print(f" At random state {i} , the Training accuracy is :- {r2_score(y_train,x_pred)}")
    print(f" At random state {i} , the testing accuracy is :- {r2_score(y_test,y_pred)}")
    print("\n")
# Out:
#  At random state 0 , the Training accuracy is :- 0.8649108402359912
#  At random state 0 , the testing accuracy is :- 0.8476726446455509
#
#
#  At random state 1 , the Training accuracy is :- 0.8661789465673849
#  At random state 1 , the testing accuracy is :- 0.8478601339060725
#
#
#  At random state 2 , the Training accuracy is :- 0.8649564735722906
#  At random state 2 , the testing accuracy is :- 0.8475638888968033
#
#
#  At random state 3 , the Training accuracy is :- 0.8618463618865355
#  At random state 3 , the testing accuracy is :- 0.8642689343974581
#
#
#  At random state 4 , the Training accuracy is :- 0.8627521716908562
#  At random state 4 , the testing accuracy is :- 0.8515065548994082
#
#
#  At random state 5 , the Training accuracy is :- 0.8656350432224245
#  At random state 5 , the testing accuracy is :- 0.8519402498257969
#
#
#  At random state 6 , the Training accuracy is :- 0.8613677779300751
#  At random state 6 , the testing accuracy is :- 0.8576069036370992
#
#
#  At random state 7 , the Training accuracy is :- 0.8652976261721027
#  At random state 7 , the testing accuracy is :- 0.8400426569580945
#
#
#  At random state 8 , the Training accuracy is :- 0.8677877551286189
#  At random state 8 , the testing accuracy is :- 0.8393610078014817
#
#
#  At random state 9 , the Training accuracy is :- 0.8659887244705957
#  At random state 9 , the testing accuracy is :- 0.8522022520146575
#
#
#  At random state 10 , the Training accuracy is :- 0.8668501334081857
#  At random state 10 , the testing accuracy is :- 0.8440391145101581
#
#
#  At random state 11 , the Training accuracy is :- 0.8630878947265228
#  At random state 11 , the testing accuracy is :- 0.8463306330919207
#
#
#  At random state 12 , the Training accuracy is :- 0.8642964714031323
#  At random state 12 , the testing accuracy is :- 0.8403980954518598
#
#
#  At random state 13 , the Training accuracy is :- 0.8662034303693412
#  At random state 13 , the testing accuracy is :- 0.8432447353624027
#
#
#  At random state 14 , the Training accuracy is :- 0.8622943824699651
#  At random state 14 , the testing accuracy is :- 0.8514583496344075
#
#
#  At random state 15 , the Training accuracy is :- 0.8669045842338726
#  At random state 15 , the testing accuracy is :- 0.8338639090472655
#
#
#  At random state 16 , the Training accuracy is :- 0.8660481725946749
#  At random state 16 , the testing accuracy is :- 0.8483965772932246
#
#
#  At random state 17 , the Training accuracy is :- 0.863275603701315
#  At random state 17 , the testing accuracy is :- 0.8563213177478182
#
#
#  At random state 18 , the Training accuracy is :- 0.865244830248022
#  At random state 18 , the testing accuracy is :- 0.8525127931493721
#
#
#  At random state 19 , the Training accuracy is :- 0.8665080772958849
#  At random state 19 , the testing accuracy is :- 0.8457314507061793
#
#
#  At random state 20 , the Training accuracy is :- 0.8666306452701326
#  At random state 20 , the testing accuracy is :- 0.8526068847290913
#
#
#  At random state 21 , the Training accuracy is :- 0.8657511391277801
#  At random state 21 , the testing accuracy is :- 0.8434646399235706
#
#
#  At random state 22 , the Training accuracy is :- 0.8664186737734891
#  At random state 22 , the testing accuracy is :- 0.8415633933668515
#
#
#  At random state 23 , the Training accuracy is :- 0.8641841171810482
#  At random state 23 , the testing accuracy is :- 0.8497331420615026
#
#
#  At random state 24 , the Training accuracy is :- 0.8687314560725972
#  At random state 24 , the testing accuracy is :- 0.8365416620233226
#
#
#  At random state 25 , the Training accuracy is :- 0.8642899655994122
#  At random state 25 , the testing accuracy is :- 0.8518039750448867
#
#
#  At random state 26 , the Training accuracy is :- 0.8657672675284506
#  At random state 26 , the testing accuracy is :- 0.8442515477205281
#
#
#  At random state 27 , the Training accuracy is :- 0.8657753732934328
#  At random state 27 , the testing accuracy is :- 0.8569012724898559
#
#
#  At random state 28 , the Training accuracy is :- 0.865465000869144
#  At random state 28 , the testing accuracy is :- 0.85344705524943
#
#
#  At random state 29 , the Training accuracy is :- 0.8648263220184537
#  At random state 29 , the testing accuracy is :- 0.850466262901568
#
#
#  At random state 30 , the Training accuracy is :- 0.8666855864431011
#  At random state 30 , the testing accuracy is :- 0.8419837963960641
#
#
#  At random state 31 , the Training accuracy is :- 0.8663555279639235
#  At random state 31 , the testing accuracy is :- 0.8423908435335206
#
#
#  At random state 32 , the Training accuracy is :- 0.865048153116887
#  At random state 32 , the testing accuracy is :- 0.8574692036601191
#
#
#  At random state 33 , the Training accuracy is :- 0.8665863533550213
#  At random state 33 , the testing accuracy is :- 0.8358155877953688
#
#
#  At random state 34 , the Training accuracy is :- 0.8645455030434713
#  At random state 34 , the testing accuracy is :- 0.8462272900009468
#
#
#  At random state 35 , the Training accuracy is :- 0.8646149269657519
#  At random state 35 , the testing accuracy is :- 0.851701741080855
#
#
#  At random state 36 , the Training accuracy is :- 0.8659528110475883
#  At random state 36 , the testing accuracy is :- 0.836490796979191
#
#
#  At random state 37 , the Training accuracy is :- 0.8636102630339306
#  At random state 37 , the testing accuracy is :- 0.8512979999552569
#
#
#  At random state 38 , the Training accuracy is :- 0.8659831346990459
#  At random state 38 , the testing accuracy is :- 0.8440572112805617
#
#
#  At random state 39 , the Training accuracy is :- 0.8655346113451798
#  At random state 39 , the testing accuracy is :- 0.8487210359396347
#
#
#  At random state 40 , the Training accuracy is :- 0.8637647459916727
#  At random state 40 , the testing accuracy is :- 0.8573384329076618
#
#
#  At random state 41 , the Training accuracy is :- 0.8674291666995023
#  At random state 41 , the testing accuracy is :- 0.840018321446834
#
#
#  At random state 42 , the Training accuracy is :- 0.8620010521877557
#  At random state 42 , the testing accuracy is :- 0.8544651317902913
#
#
#  At random state 43 , the Training accuracy is :- 0.8648045243816034
#  At random state 43 , the testing accuracy is :- 0.8529896806057902
#
#
#  At random state 44 , the Training accuracy is :- 0.8648872866639296
#  At random state 44 , the testing accuracy is :- 0.8439598712366677
#
#
#  At random state 45 , the Training accuracy is :- 0.8642020627218223
#  At random state 45 , the testing accuracy is :- 0.8475222730176857
#
#
#  At random state 46 , the Training accuracy is :- 0.8645756526316879
#  At random state 46 , the testing accuracy is :- 0.8480458872545211
#
#
#  At random state 47 , the Training accuracy is :- 0.8627260363557494
#  At random state 47 , the testing accuracy is :- 0.8526699351464744
#
#
#  At random state 48 , the Training accuracy is :- 0.8651796224963724
#  At random state 48 , the testing accuracy is :- 0.8474233171760879
#
#
#  At random state 49 , the Training accuracy is :- 0.8665121652358019
#  At random state 49 , the testing accuracy is :- 0.8449410099916016
#
#
#  At random state 50 , the Training accuracy is :- 0.8637768456134193
#  At random state 50 , the testing accuracy is :- 0.8430420600261805
#
#
#  At random state 51 , the Training accuracy is :- 0.8637106148560941
#  At random state 51 , the testing accuracy is :- 0.8533572571348246
#
#
#  At random state 52 , the Training accuracy is :- 0.8639356412900991
#  At random state 52 , the testing accuracy is :- 0.8457828648860375
#
#
#  At random state 53 , the Training accuracy is :- 0.8656052077644238
#  At random state 53 , the testing accuracy is :- 0.8552498073881742
#
#
#  At random state 54 , the Training accuracy is :- 0.8638101776900187
#  At random state 54 , the testing accuracy is :- 0.8563166970521975
#
#
#  At random state 55 , the Training accuracy is :- 0.8634147302350775
#  At random state 55 , the testing accuracy is :- 0.8439598056028637
#
#
#  At random state 56 , the Training accuracy is :- 0.8681792119937821
#  At random state 56 , the testing accuracy is :- 0.840970359251797
#
#
#  At random state 57 , the Training accuracy is :- 0.8670500323117838
#  At random state 57 , the testing accuracy is :- 0.847088372666533
#
#
#  At random state 58 , the Training accuracy is :- 0.867765714428028
#  At random state 58 , the testing accuracy is :- 0.8343702108980868
#
#
#  At random state 59 , the Training accuracy is :- 0.8635909615559969
#  At random state 59 , the testing accuracy is :- 0.8507870148552704
#
#
#  At random state 60 , the Training accuracy is :- 0.8627377336470987
#  At random state 60 , the testing accuracy is :- 0.8564521036477616
#
#
#  At random state 61 , the Training accuracy is :- 0.8668127981895275
#  At random state 61 , the testing accuracy is :- 0.8413703132097718
#
#
#  At random state 62 , the Training accuracy is :- 0.866661807971951
#  At random state 62 , the testing accuracy is :- 0.8403118198748656
#
#
#  At random state 63 , the Training accuracy is :- 0.8646407080769348
#  At random state 63 , the testing accuracy is :- 0.8460300834799203
#
#
#  At random state 64 , the Training accuracy is :- 0.8645356831014923
#  At random state 64 , the testing accuracy is :- 0.843061965752292
#
#
#  At random state 65 , the Training accuracy is :- 0.868110028184634
#  At random state 65 , the testing accuracy is :- 0.8274716124302551
#
#
#  At random state 66 , the Training accuracy is :- 0.8660006273616181
#  At random state 66 , the testing accuracy is :- 0.843036222093592
#
#
#  At random state 67 , the Training accuracy is :- 0.8680354572817636
#  At random state 67 , the testing accuracy is :- 0.8348499270578612
#
#
#  At random state 68 , the Training accuracy is :- 0.8656856995994187
#  At random state 68 , the testing accuracy is :- 0.842698416562402
#
#
#  At random state 69 , the Training accuracy is :- 0.8627255870535024
#  At random state 69 , the testing accuracy is :- 0.860221057763654
#
#
#  At random state 70 , the Training accuracy is :- 0.8672214243026202
#  At random state 70 , the testing accuracy is :- 0.8476362739472636
#
#
#  At random state 71 , the Training accuracy is :- 0.8643248141819162
#  At random state 71 , the testing accuracy is :- 0.8491888900545819
#
#
#  At random state 72 , the Training accuracy is :- 0.8654099257598933
#  At random state 72 , the testing accuracy is :- 0.8538938454513153
#
#
#  At random state 73 , the Training accuracy is :- 0.8673138610098684
#  At random state 73 , the testing accuracy is :- 0.8426692402314204
#
#
#  At random state 74 , the Training accuracy is :- 0.8648835312873645
#  At random state 74 , the testing accuracy is :- 0.8520603219050058
#
#
#  At random state 75 , the Training accuracy is :- 0.8659032015243687
#  At random state 75 , the testing accuracy is :- 0.8425702978936468
#
#
#  At random state 76 , the Training accuracy is :- 0.8655747993008271
#  At random state 76 , the testing accuracy is :- 0.8486065897171691
#
#
#  At random state 77 , the Training accuracy is :- 0.8643458555312858
#  At random state 77 , the testing accuracy is :- 0.8462595918451813
#
#
#  At random state 78 , the Training accuracy is :- 0.8649007341997799
#  At random state 78 , the testing accuracy is :- 0.8517250402268992
#
#
#  At random state 79 , the Training accuracy is :- 0.8648628147300347
#  At random state 79 , the testing accuracy is :- 0.8506215881409367
#
#
#  At random state 80 , the Training accuracy is :- 0.8628782781624393
#  At random state 80 , the testing accuracy is :- 0.8514160767001251
#
#
#  At random state 81 , the Training accuracy is :- 0.864571270752544
#  At random state 81 , the testing accuracy is :- 0.8478578602879601
#
#
#  At random state 82 , the Training accuracy is :- 0.866952131177912
#  At random state 82 , the testing accuracy is :- 0.840513990505169
#
#
#  At random state 83 , the Training accuracy is :- 0.8650568008466231
#  At random state 83 , the testing accuracy is :- 0.8478590799458431
#
#
#  At random state 84 , the Training accuracy is :- 0.862568416836466
#  At random state 84 , the testing accuracy is :- 0.8625695854328033
#
#
#  At random state 85 , the Training accuracy is :- 0.8638301787081561
#  At random state 85 , the testing accuracy is :- 0.8484551054781001
#
#
#  At random state 86 , the Training accuracy is :- 0.8689743610760358
#  At random state 86 , the testing accuracy is :- 0.8379120319473077
#
#
#  At random state 87 , the Training accuracy is :- 0.864323271595393
#  At random state 87 , the testing accuracy is :- 0.8488282403525909
#
#
#  At random state 88 , the Training accuracy is :- 0.8655619373630926
#  At random state 88 , the testing accuracy is :- 0.8386749310650325
#
#
#  At random state 89 , the Training accuracy is :- 0.8670854220645425
#  At random state 89 , the testing accuracy is :- 0.8441128737635135
#
#
#  At random state 90 , the Training accuracy is :- 0.8631533310974774
#  At random state 90 , the testing accuracy is :- 0.852302750988716
#
#
#  At random state 91 , the Training accuracy is :- 0.8659751549899108
#  At random state 91 , the testing accuracy is :- 0.8405783691973506
#
#
#  At random state 92 , the Training accuracy is :- 0.8662287548545834
#  At random state 92 , the testing accuracy is :- 0.8499221515319623
#
#
#  At random state 93 , the Training accuracy is :- 0.8656657645624954
#  At random state 93 , the testing accuracy is :- 0.8470113671581196
#
#
#  At random state 94 , the Training accuracy is :- 0.867340932760111
#  At random state 94 , the testing accuracy is :- 0.8466647504477443
#
#
#  At random state 95 , the Training accuracy is :- 0.8667369847938736
#  At random state 95 , the testing accuracy is :- 0.8399223923762851
#
#
#  At random state 96 , the Training accuracy is :- 0.8651881296601845
#  At random state 96 , the testing accuracy is :- 0.8392133781420146
#
#
#  At random state 97 , the Training accuracy is :- 0.8658140314618287
#  At random state 97 , the testing accuracy is :- 0.8337424215610704
#
#
#  At random state 98 , the Training accuracy is :- 0.8655441121525363
#  At random state 98 , the testing accuracy is :- 0.8442748071675651
#
#
#  At random state 99 , the Training accuracy is :- 0.8602722059089742
#  At random state 99 , the testing accuracy is :- 0.8563354884923007

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=84)

# %%
gbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
#Lets Print Training Score
pred_train=gbr.predict(x_train)
print(r2_score(y_train,pred_train))
# Out:
# 0.862568416836466

# %%
#Lets Print Testing Score
train_pred=gbr.predict(x_test)
print(r2_score(y_test,train_pred))
# Out:
# 0.8625605332203377

# %% [markdown]
# # Cross Validation of the Model

# %%
train_accuracy=r2_score(y_train,x_pred)
test_accuracy=r2_score(y_test,y_pred)
#Lets import Cross Validation
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(gbr,x,y,cv=j)
    cv_mean=cv_score.mean()
    
    print(f"At cross fold {j} the CV Score is {cv_mean} and accuracy for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the CV Score is 0.5772969544798532 and accuracy for training is -0.7904300759183127 and accuracy for testing is -0.7448383687148641
#
#
# At cross fold 3 the CV Score is 0.5950370588398383 and accuracy for training is -0.7904300759183127 and accuracy for testing is -0.7448383687148641
#
#
# At cross fold 4 the CV Score is 0.6234629173623913 and accuracy for training is -0.7904300759183127 and accuracy for testing is -0.7448383687148641
#
#
# At cross fold 5 the CV Score is 0.6125331501097687 and accuracy for training is -0.7904300759183127 and accuracy for testing is -0.7448383687148641
#
#
# At cross fold 6 the CV Score is 0.6443397900387757 and accuracy for training is -0.7904300759183127 and accuracy for testing is -0.7448383687148641
#
#
# At cross fold 7 the CV Score is 0.6500445517894432 and accuracy for training is -0.7904300759183127 and accuracy for testing is -0.7448383687148641
#
#
# At cross fold 8 the CV Score is 0.6625164823505232 and accuracy for training is -0.7904300759183127 and accuracy for testing is -0.7448383687148641
#
#
# At cross fold 9 the CV Score is 0.6689512209726388 and accuracy for training is -0.7904300759183127 and accuracy for testing is -0.7448383687148641

# %% [markdown]
# # Lets Plot Best Fit Line and Check How Data points are Close to the Best Fit Line

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=train_pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Acutal Charges ",fontsize=14)
plt.ylabel("Predicted Charges ",fontsize=14)
plt.title("Gradient Boosting Regression ",fontsize=18)
plt.savefig('gbr.png')
plt.show()

# %% [markdown]
# # We got accuracy So we dont do the hyperparameter tuning.

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=84)

# %%
param = {
             'min_samples_split':[2,5,10],
             'min_samples_leaf':[1,3,4],
             'max_depth':[5,10,15],
             'learning_rate': [0.1,0.2,0.3],
              'n_estimators':[150,200,250],
             }

# %%
grd = GridSearchCV(gbr,param_grid = param)
grd.fit(X_train,y_train)

print('Best Params ',grd.best_params_)
# Out:
# Best Params  {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 250}

# %%
gbr = GradientBoostingRegressor(learning_rate=0.06, n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_depth=5,)

gbr.fit(X_train,y_train)

pred = gbr.predict(X_test)

r2_score(y_test,pred)
# Out:
# 0.8562122890895798

# %% [markdown]
# # Model Building For Predicting Price range (Classification)

# %%
df1.head()
# Out:
#    Country Code  Country  Restaurant ID  Restaurant Name  City  Address  \
# 0             0        0           4425             2883     1     3938
# 1             0        0           4434             4768     1     3989
# 2             0        0           4420             6274     1     5560
# 3             0        0           4424             1500     1       95
# 4             0        0           4422             4441     1     1086
#
#    Locality  Locality Verbose  Longitude  Latitude  ...  Average Cost for two  \
# 0        15                15       7059       613  ...                    55
# 1        15                15         77         0  ...                    51
# 2        15                15       7060       611  ...                    47
# 3       157               158       7057       618  ...                    43
# 4       157               158       7058       619  ...                    58
#
#    Currency  Has Table booking  Has Online delivery  Is delivering now  \
# 0         3                  0                    0                  0
# 1         3                  0                    0                  0
# 2         3                  0                    0                  0
# 3         3                  0                    0                  0
# 4         3                  0                    0                  0
#
#    Price range  Aggregate rating  Rating color  Rating text  Votes
# 0            2                22             5            2    140
# 1            1                18             5            2     71
# 2            1                19             5            2     94
# 3            1                23             1            5     87
# 4            2                25             1            5    177
#
# [5 rows x 21 columns]

# %%
df1['Price range'].value_counts()
# Out:
# 0    4293
# 1    2880
# 2    1140
# 3     443
# Name: Price range, dtype: int64

# %% [markdown]
# # Dividing data in feature and Label

# %%
x = df1.drop(columns=['Price range'],axis=1)
y = df1['Price range']

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
x_sample,y_sample=smt.fit_resample(x,y)

# %%
#Lets import standardscaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[-0.163627  , -0.163627  ,  0.01879224, ...,  1.39110501,
#          0.20158538,  0.3490639 ],
#        [-0.163627  , -0.163627  ,  0.02235287, ...,  1.39110501,
#          0.20158538, -0.12188601],
#        [-0.163627  , -0.163627  ,  0.01681411, ...,  1.39110501,
#          0.20158538,  0.03509729],
#        ...,
#        [ 7.33751449,  7.33751449,  0.12719377, ..., -1.43352609,
#          2.03893607,  3.46142856],
#        [ 7.33751449,  7.33751449,  0.12956753, ..., -1.43352609,
#          2.03893607, -0.14918746],
#        [ 7.33751449,  7.33751449,  0.12600689, ..., -1.43352609,
#          2.03893607,  0.17160451]])

# %% [markdown]
# # Now use VIF for checking multicollinearity problem
# VIF - > Variance Inflation Factor

# %%
#Lets import VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x_scaled,i)for i in range(x_scaled.shape[1])]
vif['feature']=x.columns

# %%
vif
# Out:
#            vif               feature
# 0          inf          Country Code
# 1          inf               Country
# 2     1.397445         Restaurant ID
# 3     1.008917       Restaurant Name
# 4     1.391815                  City
# 5     1.069462               Address
# 6   611.152448              Locality
# 7   611.105601      Locality Verbose
# 8     1.135815             Longitude
# 9     1.354997              Latitude
# 10    1.031856              Cuisines
# 11    1.923540  Average Cost for two
# 12    1.382824              Currency
# 13    1.536801     Has Table booking
# 14    1.116435   Has Online delivery
# 15    1.016871     Is delivering now
# 16    1.954439      Aggregate rating
# 17    1.208344          Rating color
# 18    1.472822           Rating text
# 19    1.980531                 Votes

# %%
x.drop(columns=['Country Code','Country'],axis=1,inplace=True)

# %%
x.drop(columns=['Locality','Locality Verbose'],axis=1,inplace=True)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,classification_report
from sklearn.model_selection import train_test_split

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At Radom State ",i,"The Model Performs Very Well")
        print("At random State ",i,"The Model performs very well")
        print("Training Accuracy Score is :- ",accuracy_score(y_train,pred_train)*100)
        print("Testing Accuracy Score is : - ",accuracy_score(y_test,pred_test)*100,"\n")
# Out:
# At Radom State  10 The Model Performs Very Well
# At random State  10 The Model performs very well
# Training Accuracy Score is :-  58.05254140491149
# Testing Accuracy Score is : -  58.10502283105022
#
# At Radom State  55 The Model Performs Very Well
# At random State  55 The Model performs very well
# Training Accuracy Score is :-  58.28098229583095
# Testing Accuracy Score is : -  58.333333333333336
#
# At Radom State  125 The Model Performs Very Well
# At random State  125 The Model performs very well
# Training Accuracy Score is :-  57.909765848086806
# Testing Accuracy Score is : -  57.9337899543379
#
# At Radom State  137 The Model Performs Very Well
# At random State  137 The Model performs very well
# Training Accuracy Score is :-  57.881210736721876
# Testing Accuracy Score is : -  57.87671232876712
#
# At Radom State  198 The Model Performs Very Well
# At random State  198 The Model performs very well
# Training Accuracy Score is :-  57.93832095945174
# Testing Accuracy Score is : -  57.87671232876712
#
# At Radom State  253 The Model Performs Very Well
# At random State  253 The Model performs very well
# Training Accuracy Score is :-  58.02398629354655
# Testing Accuracy Score is : -  57.99086757990868
#
# At Radom State  266 The Model Performs Very Well
# At random State  266 The Model performs very well
# Training Accuracy Score is :-  58.10965162764135
# Testing Accuracy Score is : -  58.10502283105022
#
# At Radom State  297 The Model Performs Very Well
# At random State  297 The Model performs very well
# Training Accuracy Score is :-  57.79554540262707
# Testing Accuracy Score is : -  57.76255707762557
#
# At Radom State  312 The Model Performs Very Well
# At random State  312 The Model performs very well
# Training Accuracy Score is :-  58.10965162764135
# Testing Accuracy Score is : -  58.10502283105022
#
# At Radom State  322 The Model Performs Very Well
# At random State  322 The Model performs very well
# Training Accuracy Score is :-  57.82410051399201
# Testing Accuracy Score is : -  57.76255707762557
#
# At Radom State  551 The Model Performs Very Well
# At random State  551 The Model performs very well
# Training Accuracy Score is :-  58.009708737864074
# Testing Accuracy Score is : -  58.04794520547946
#
# At Radom State  706 The Model Performs Very Well
# At random State  706 The Model performs very well
# Training Accuracy Score is :-  57.638492290119935
# Testing Accuracy Score is : -  57.59132420091324
#
# At Radom State  711 The Model Performs Very Well
# At random State  711 The Model performs very well
# Training Accuracy Score is :-  58.08109651627641
# Testing Accuracy Score is : -  58.10502283105022
#
# At Radom State  719 The Model Performs Very Well
# At random State  719 The Model performs very well
# Training Accuracy Score is :-  57.85265562535694
# Testing Accuracy Score is : -  57.87671232876712

# %% [markdown]
# For Logistic Regression we select Random State - 55

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=55)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train,y_train)#Training Score
# Out:
# 0.5828098229583095

# %%
lr.score(x_test,y_test)#Testing Score
# Out:
# 0.5833333333333334

# %% [markdown]
# # Lets check with KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    knn.fit(x_train,y_train)
    x_pred=knn.predict(x_train)
    y_pred=knn.predict(x_test)
    print(f" At random state {i} , the testing accuracy is :- {accuracy_score(y_train,x_pred)}")
    print(f" At random state {i} , the testing accuracy is :- {accuracy_score(y_test,y_pred)}")
    print("\n")
# Out:
#  At random state 0 , the testing accuracy is :- 0.6580525414049114
#  At random state 0 , the testing accuracy is :- 0.4982876712328767
#
#
#  At random state 1 , the testing accuracy is :- 0.6536264991433467
#  At random state 1 , the testing accuracy is :- 0.5125570776255708
#
#
#  At random state 2 , the testing accuracy is :- 0.6583380925185608
#  At random state 2 , the testing accuracy is :- 0.5057077625570776
#
#
#  At random state 3 , the testing accuracy is :- 0.653912050256996
#  At random state 3 , the testing accuracy is :- 0.5039954337899544
#
#
#  At random state 4 , the testing accuracy is :- 0.6561964591661907
#  At random state 4 , the testing accuracy is :- 0.5068493150684932
#
#
#  At random state 5 , the testing accuracy is :- 0.6607652769845802
#  At random state 5 , the testing accuracy is :- 0.5062785388127854
#
#
#  At random state 6 , the testing accuracy is :- 0.6583380925185608
#  At random state 6 , the testing accuracy is :- 0.4863013698630137
#
#
#  At random state 7 , the testing accuracy is :- 0.6603369503141062
#  At random state 7 , the testing accuracy is :- 0.4794520547945205
#
#
#  At random state 8 , the testing accuracy is :- 0.6559109080525414
#  At random state 8 , the testing accuracy is :- 0.4891552511415525
#
#
#  At random state 9 , the testing accuracy is :- 0.6597658480868075
#  At random state 9 , the testing accuracy is :- 0.5165525114155252
#
#
#  At random state 10 , the testing accuracy is :- 0.6521987435751
#  At random state 10 , the testing accuracy is :- 0.5171232876712328
#
#
#  At random state 11 , the testing accuracy is :- 0.6559109080525414
#  At random state 11 , the testing accuracy is :- 0.5051369863013698
#
#
#  At random state 12 , the testing accuracy is :- 0.6486293546544831
#  At random state 12 , the testing accuracy is :- 0.5222602739726028
#
#
#  At random state 13 , the testing accuracy is :- 0.6546259280411194
#  At random state 13 , the testing accuracy is :- 0.5028538812785388
#
#
#  At random state 14 , the testing accuracy is :- 0.6604797258709308
#  At random state 14 , the testing accuracy is :- 0.5005707762557078
#
#
#  At random state 15 , the testing accuracy is :- 0.6643346659051971
#  At random state 15 , the testing accuracy is :- 0.4868721461187215
#
#
#  At random state 16 , the testing accuracy is :- 0.6617647058823529
#  At random state 16 , the testing accuracy is :- 0.4937214611872146
#
#
#  At random state 17 , the testing accuracy is :- 0.6567675613934895
#  At random state 17 , the testing accuracy is :- 0.5005707762557078
#
#
#  At random state 18 , the testing accuracy is :- 0.6529126213592233
#  At random state 18 , the testing accuracy is :- 0.5222602739726028
#
#
#  At random state 19 , the testing accuracy is :- 0.6647629925756711
#  At random state 19 , the testing accuracy is :- 0.4920091324200913
#
#
#  At random state 20 , the testing accuracy is :- 0.6563392347230155
#  At random state 20 , the testing accuracy is :- 0.5062785388127854
#
#
#  At random state 21 , the testing accuracy is :- 0.6586236436322102
#  At random state 21 , the testing accuracy is :- 0.5131278538812786
#
#
#  At random state 22 , the testing accuracy is :- 0.655197030268418
#  At random state 22 , the testing accuracy is :- 0.5205479452054794
#
#
#  At random state 23 , the testing accuracy is :- 0.6557681324957167
#  At random state 23 , the testing accuracy is :- 0.502283105022831
#
#
#  At random state 24 , the testing accuracy is :- 0.6557681324957167
#  At random state 24 , the testing accuracy is :- 0.4920091324200913
#
#
#  At random state 25 , the testing accuracy is :- 0.653912050256996
#  At random state 25 , the testing accuracy is :- 0.4994292237442922
#
#
#  At random state 26 , the testing accuracy is :- 0.6533409480296973
#  At random state 26 , the testing accuracy is :- 0.523972602739726
#
#
#  At random state 27 , the testing accuracy is :- 0.6559109080525414
#  At random state 27 , the testing accuracy is :- 0.5051369863013698
#
#
#  At random state 28 , the testing accuracy is :- 0.6583380925185608
#  At random state 28 , the testing accuracy is :- 0.5102739726027398
#
#
#  At random state 29 , the testing accuracy is :- 0.6601941747572816
#  At random state 29 , the testing accuracy is :- 0.5
#
#
#  At random state 30 , the testing accuracy is :- 0.6619074814391777
#  At random state 30 , the testing accuracy is :- 0.4914383561643836
#
#
#  At random state 31 , the testing accuracy is :- 0.6561964591661907
#  At random state 31 , the testing accuracy is :- 0.4948630136986301
#
#
#  At random state 32 , the testing accuracy is :- 0.6564820102798401
#  At random state 32 , the testing accuracy is :- 0.5068493150684932
#
#
#  At random state 33 , the testing accuracy is :- 0.6563392347230155
#  At random state 33 , the testing accuracy is :- 0.5165525114155252
#
#
#  At random state 34 , the testing accuracy is :- 0.6617647058823529
#  At random state 34 , the testing accuracy is :- 0.5011415525114156
#
#
#  At random state 35 , the testing accuracy is :- 0.6550542547115934
#  At random state 35 , the testing accuracy is :- 0.5011415525114156
#
#
#  At random state 36 , the testing accuracy is :- 0.6584808680753855
#  At random state 36 , the testing accuracy is :- 0.526255707762557
#
#
#  At random state 37 , the testing accuracy is :- 0.6537692747001713
#  At random state 37 , the testing accuracy is :- 0.5125570776255708
#
#
#  At random state 38 , the testing accuracy is :- 0.6546259280411194
#  At random state 38 , the testing accuracy is :- 0.5205479452054794
#
#
#  At random state 39 , the testing accuracy is :- 0.6557681324957167
#  At random state 39 , the testing accuracy is :- 0.514269406392694
#
#
#  At random state 40 , the testing accuracy is :- 0.6521987435751
#  At random state 40 , the testing accuracy is :- 0.5165525114155252
#
#
#  At random state 41 , the testing accuracy is :- 0.6553398058252428
#  At random state 41 , the testing accuracy is :- 0.5114155251141552
#
#
#  At random state 42 , the testing accuracy is :- 0.6620502569960023
#  At random state 42 , the testing accuracy is :- 0.4982876712328767
#
#
#  At random state 43 , the testing accuracy is :- 0.6566247858366647
#  At random state 43 , the testing accuracy is :- 0.5159817351598174
#
#
#  At random state 44 , the testing accuracy is :- 0.6620502569960023
#  At random state 44 , the testing accuracy is :- 0.5079908675799086
#
#
#  At random state 45 , the testing accuracy is :- 0.6613363792118789
#  At random state 45 , the testing accuracy is :- 0.5011415525114156
#
#
#  At random state 46 , the testing accuracy is :- 0.6529126213592233
#  At random state 46 , the testing accuracy is :- 0.5068493150684932
#
#
#  At random state 47 , the testing accuracy is :- 0.6493432324386065
#  At random state 47 , the testing accuracy is :- 0.519406392694064
#
#
#  At random state 48 , the testing accuracy is :- 0.6669046259280411
#  At random state 48 , the testing accuracy is :- 0.4897260273972603
#
#
#  At random state 49 , the testing accuracy is :- 0.6557681324957167
#  At random state 49 , the testing accuracy is :- 0.5148401826484018
#
#
#  At random state 50 , the testing accuracy is :- 0.6584808680753855
#  At random state 50 , the testing accuracy is :- 0.4954337899543379
#
#
#  At random state 51 , the testing accuracy is :- 0.6627641347801256
#  At random state 51 , the testing accuracy is :- 0.4977168949771689
#
#
#  At random state 52 , the testing accuracy is :- 0.6486293546544831
#  At random state 52 , the testing accuracy is :- 0.5325342465753424
#
#
#  At random state 53 , the testing accuracy is :- 0.6546259280411194
#  At random state 53 , the testing accuracy is :- 0.5017123287671232
#
#
#  At random state 54 , the testing accuracy is :- 0.6611936036550543
#  At random state 54 , the testing accuracy is :- 0.4931506849315068
#
#
#  At random state 55 , the testing accuracy is :- 0.653483723586522
#  At random state 55 , the testing accuracy is :- 0.5159817351598174
#
#
#  At random state 56 , the testing accuracy is :- 0.6536264991433467
#  At random state 56 , the testing accuracy is :- 0.4988584474885845
#
#
#  At random state 57 , the testing accuracy is :- 0.6589091947458595
#  At random state 57 , the testing accuracy is :- 0.5148401826484018
#
#
#  At random state 58 , the testing accuracy is :- 0.6617647058823529
#  At random state 58 , the testing accuracy is :- 0.5017123287671232
#
#
#  At random state 59 , the testing accuracy is :- 0.6600513992004569
#  At random state 59 , the testing accuracy is :- 0.4863013698630137
#
#
#  At random state 60 , the testing accuracy is :- 0.6606225014277556
#  At random state 60 , the testing accuracy is :- 0.5085616438356164
#
#
#  At random state 61 , the testing accuracy is :- 0.665191319246145
#  At random state 61 , the testing accuracy is :- 0.502283105022831
#
#
#  At random state 62 , the testing accuracy is :- 0.6516276413478013
#  At random state 62 , the testing accuracy is :- 0.5228310502283106
#
#
#  At random state 63 , the testing accuracy is :- 0.655625356938892
#  At random state 63 , the testing accuracy is :- 0.5051369863013698
#
#
#  At random state 64 , the testing accuracy is :- 0.6661907481439178
#  At random state 64 , the testing accuracy is :- 0.5062785388127854
#
#
#  At random state 65 , the testing accuracy is :- 0.6594802969731582
#  At random state 65 , the testing accuracy is :- 0.4868721461187215
#
#
#  At random state 66 , the testing accuracy is :- 0.6563392347230155
#  At random state 66 , the testing accuracy is :- 0.5085616438356164
#
#
#  At random state 67 , the testing accuracy is :- 0.6644774414620217
#  At random state 67 , the testing accuracy is :- 0.4988584474885845
#
#
#  At random state 68 , the testing accuracy is :- 0.6596230725299829
#  At random state 68 , the testing accuracy is :- 0.5102739726027398
#
#
#  At random state 69 , the testing accuracy is :- 0.6604797258709308
#  At random state 69 , the testing accuracy is :- 0.4954337899543379
#
#
#  At random state 70 , the testing accuracy is :- 0.6603369503141062
#  At random state 70 , the testing accuracy is :- 0.509703196347032
#
#
#  At random state 71 , the testing accuracy is :- 0.6564820102798401
#  At random state 71 , the testing accuracy is :- 0.4960045662100457
#
#
#  At random state 72 , the testing accuracy is :- 0.6561964591661907
#  At random state 72 , the testing accuracy is :- 0.5114155251141552
#
#
#  At random state 73 , the testing accuracy is :- 0.6581953169617362
#  At random state 73 , the testing accuracy is :- 0.5057077625570776
#
#
#  At random state 74 , the testing accuracy is :- 0.6589091947458595
#  At random state 74 , the testing accuracy is :- 0.4931506849315068
#
#
#  At random state 75 , the testing accuracy is :- 0.6607652769845802
#  At random state 75 , the testing accuracy is :- 0.5154109589041096
#
#
#  At random state 76 , the testing accuracy is :- 0.6574814391776128
#  At random state 76 , the testing accuracy is :- 0.5148401826484018
#
#
#  At random state 77 , the testing accuracy is :- 0.6593375214163335
#  At random state 77 , the testing accuracy is :- 0.5017123287671232
#
#
#  At random state 78 , the testing accuracy is :- 0.65434037692747
#  At random state 78 , the testing accuracy is :- 0.5005707762557078
#
#
#  At random state 79 , the testing accuracy is :- 0.6563392347230155
#  At random state 79 , the testing accuracy is :- 0.5165525114155252
#
#
#  At random state 80 , the testing accuracy is :- 0.6583380925185608
#  At random state 80 , the testing accuracy is :- 0.488013698630137
#
#
#  At random state 81 , the testing accuracy is :- 0.6621930325528269
#  At random state 81 , the testing accuracy is :- 0.5045662100456622
#
#
#  At random state 82 , the testing accuracy is :- 0.6581953169617362
#  At random state 82 , the testing accuracy is :- 0.5034246575342466
#
#
#  At random state 83 , the testing accuracy is :- 0.6560536836093661
#  At random state 83 , the testing accuracy is :- 0.502283105022831
#
#
#  At random state 84 , the testing accuracy is :- 0.6604797258709308
#  At random state 84 , the testing accuracy is :- 0.5011415525114156
#
#
#  At random state 85 , the testing accuracy is :- 0.6610508280982296
#  At random state 85 , the testing accuracy is :- 0.5057077625570776
#
#
#  At random state 86 , the testing accuracy is :- 0.6536264991433467
#  At random state 86 , the testing accuracy is :- 0.5051369863013698
#
#
#  At random state 87 , the testing accuracy is :- 0.6610508280982296
#  At random state 87 , the testing accuracy is :- 0.5091324200913242
#
#
#  At random state 88 , the testing accuracy is :- 0.653912050256996
#  At random state 88 , the testing accuracy is :- 0.5091324200913242
#
#
#  At random state 89 , the testing accuracy is :- 0.655625356938892
#  At random state 89 , the testing accuracy is :- 0.5222602739726028
#
#
#  At random state 90 , the testing accuracy is :- 0.6586236436322102
#  At random state 90 , the testing accuracy is :- 0.5068493150684932
#
#
#  At random state 91 , the testing accuracy is :- 0.65434037692747
#  At random state 91 , the testing accuracy is :- 0.490296803652968
#
#
#  At random state 92 , the testing accuracy is :- 0.6624785836664763
#  At random state 92 , the testing accuracy is :- 0.4960045662100457
#
#
#  At random state 93 , the testing accuracy is :- 0.6527698458023986
#  At random state 93 , the testing accuracy is :- 0.5251141552511416
#
#
#  At random state 94 , the testing accuracy is :- 0.653483723586522
#  At random state 94 , the testing accuracy is :- 0.5125570776255708
#
#
#  At random state 95 , the testing accuracy is :- 0.6557681324957167
#  At random state 95 , the testing accuracy is :- 0.5136986301369864
#
#
#  At random state 96 , the testing accuracy is :- 0.6583380925185608
#  At random state 96 , the testing accuracy is :- 0.4937214611872146
#
#
#  At random state 97 , the testing accuracy is :- 0.6571958880639635
#  At random state 97 , the testing accuracy is :- 0.4965753424657534
#
#
#  At random state 98 , the testing accuracy is :- 0.6580525414049114
#  At random state 98 , the testing accuracy is :- 0.521689497716895
#
#
#  At random state 99 , the testing accuracy is :- 0.6563392347230155
#  At random state 99 , the testing accuracy is :- 0.5062785388127854

# %% [markdown]
# For KNN we select Random State - 52

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=52)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_train,y_train)#Training Score
# Out:
# 0.6486293546544831

# %%
knn.score(x_test,y_test)#Testing Score
# Out:
# 0.5325342465753424

# %% [markdown]
# # Lets check with AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    ada.fit(x_train,y_train)
    x_pred=ada.predict(x_train)
    y_pred=ada.predict(x_test)
    print(f" At random state {i} , the testing accuracy is :- {accuracy_score(y_train,x_pred)}")
    print(f" At random state {i} , the testing accuracy is :- {accuracy_score(y_test,y_pred)}")
    print("\n")
# Out:
#  At random state 0 , the testing accuracy is :- 0.8513706453455169
#  At random state 0 , the testing accuracy is :- 0.8527397260273972
#
#
#  At random state 1 , the testing accuracy is :- 0.9274700171330669
#  At random state 1 , the testing accuracy is :- 0.9189497716894978
#
#
#  At random state 2 , the testing accuracy is :- 0.8135351227869788
#  At random state 2 , the testing accuracy is :- 0.795662100456621
#
#
#  At random state 3 , the testing accuracy is :- 0.8472301541976014
#  At random state 3 , the testing accuracy is :- 0.8327625570776256
#
#
#  At random state 4 , the testing accuracy is :- 0.9503141062250143
#  At random state 4 , the testing accuracy is :- 0.9474885844748858
#
#
#  At random state 5 , the testing accuracy is :- 0.915191319246145
#  At random state 5 , the testing accuracy is :- 0.9115296803652968
#
#
#  At random state 6 , the testing accuracy is :- 0.8388063963449457
#  At random state 6 , the testing accuracy is :- 0.8287671232876712
#
#
#  At random state 7 , the testing accuracy is :- 0.7975442604226156
#  At random state 7 , the testing accuracy is :- 0.7791095890410958
#
#
#  At random state 8 , the testing accuracy is :- 0.92175899486008
#  At random state 8 , the testing accuracy is :- 0.9337899543378996
#
#
#  At random state 9 , the testing accuracy is :- 0.9219017704169046
#  At random state 9 , the testing accuracy is :- 0.9172374429223744
#
#
#  At random state 10 , the testing accuracy is :- 0.8366647629925756
#  At random state 10 , the testing accuracy is :- 0.8299086757990868
#
#
#  At random state 11 , the testing accuracy is :- 0.8517989720159909
#  At random state 11 , the testing accuracy is :- 0.8624429223744292
#
#
#  At random state 12 , the testing accuracy is :- 0.8530839520274129
#  At random state 12 , the testing accuracy is :- 0.8498858447488584
#
#
#  At random state 13 , the testing accuracy is :- 0.8529411764705882
#  At random state 13 , the testing accuracy is :- 0.8493150684931506
#
#
#  At random state 14 , the testing accuracy is :- 0.7988292404340377
#  At random state 14 , the testing accuracy is :- 0.8127853881278538
#
#
#  At random state 15 , the testing accuracy is :- 0.8479440319817247
#  At random state 15 , the testing accuracy is :- 0.865296803652968
#
#
#  At random state 16 , the testing accuracy is :- 0.9367504283266704
#  At random state 16 , the testing accuracy is :- 0.934931506849315
#
#
#  At random state 17 , the testing accuracy is :- 0.7769845802398629
#  At random state 17 , the testing accuracy is :- 0.7722602739726028
#
#
#  At random state 18 , the testing accuracy is :- 0.8507995431182181
#  At random state 18 , the testing accuracy is :- 0.8470319634703196
#
#
#  At random state 19 , the testing accuracy is :- 0.8849229011993147
#  At random state 19 , the testing accuracy is :- 0.867579908675799
#
#
#  At random state 20 , the testing accuracy is :- 0.8513706453455169
#  At random state 20 , the testing accuracy is :- 0.8327625570776256
#
#
#  At random state 21 , the testing accuracy is :- 0.8512278697886921
#  At random state 21 , the testing accuracy is :- 0.8573059360730594
#
#
#  At random state 22 , the testing accuracy is :- 0.7475728155339806
#  At random state 22 , the testing accuracy is :- 0.7545662100456622
#
#
#  At random state 23 , the testing accuracy is :- 0.8960593946316391
#  At random state 23 , the testing accuracy is :- 0.8904109589041096
#
#
#  At random state 24 , the testing accuracy is :- 0.8433752141633353
#  At random state 24 , the testing accuracy is :- 0.8401826484018264
#
#
#  At random state 25 , the testing accuracy is :- 0.7815533980582524
#  At random state 25 , the testing accuracy is :- 0.7705479452054794
#
#
#  At random state 26 , the testing accuracy is :- 0.8503712164477442
#  At random state 26 , the testing accuracy is :- 0.8584474885844748
#
#
#  At random state 27 , the testing accuracy is :- 0.8155339805825242
#  At random state 27 , the testing accuracy is :- 0.8190639269406392
#
#
#  At random state 28 , the testing accuracy is :- 0.8542261564820103
#  At random state 28 , the testing accuracy is :- 0.8493150684931506
#
#
#  At random state 29 , the testing accuracy is :- 0.796973158195317
#  At random state 29 , the testing accuracy is :- 0.7985159817351598
#
#
#  At random state 30 , the testing accuracy is :- 0.8486579097658481
#  At random state 30 , the testing accuracy is :- 0.8441780821917808
#
#
#  At random state 31 , the testing accuracy is :- 0.8196744717304397
#  At random state 31 , the testing accuracy is :- 0.8093607305936074
#
#
#  At random state 32 , the testing accuracy is :- 0.7984009137635637
#  At random state 32 , the testing accuracy is :- 0.8036529680365296
#
#
#  At random state 33 , the testing accuracy is :- 0.9231867504283267
#  At random state 33 , the testing accuracy is :- 0.9212328767123288
#
#
#  At random state 34 , the testing accuracy is :- 0.9183323814962878
#  At random state 34 , the testing accuracy is :- 0.922945205479452
#
#
#  At random state 35 , the testing accuracy is :- 0.9264705882352942
#  At random state 35 , the testing accuracy is :- 0.9200913242009132
#
#
#  At random state 36 , the testing accuracy is :- 0.7675613934894346
#  At random state 36 , the testing accuracy is :- 0.7711187214611872
#
#
#  At random state 37 , the testing accuracy is :- 0.8535122786978869
#  At random state 37 , the testing accuracy is :- 0.8590182648401826
#
#
#  At random state 38 , the testing accuracy is :- 0.8526556253569388
#  At random state 38 , the testing accuracy is :- 0.8595890410958904
#
#
#  At random state 39 , the testing accuracy is :- 0.8567961165048543
#  At random state 39 , the testing accuracy is :- 0.8527397260273972
#
#
#  At random state 40 , the testing accuracy is :- 0.8499428897772702
#  At random state 40 , the testing accuracy is :- 0.8418949771689498
#
#
#  At random state 41 , the testing accuracy is :- 0.8513706453455169
#  At random state 41 , the testing accuracy is :- 0.860730593607306
#
#
#  At random state 42 , the testing accuracy is :- 0.9169046259280411
#  At random state 42 , the testing accuracy is :- 0.9103881278538812
#
#
#  At random state 43 , the testing accuracy is :- 0.8522272986864649
#  At random state 43 , the testing accuracy is :- 0.843607305936073
#
#
#  At random state 44 , the testing accuracy is :- 0.8242432895488292
#  At random state 44 , the testing accuracy is :- 0.8333333333333334
#
#
#  At random state 45 , the testing accuracy is :- 0.9163335237007424
#  At random state 45 , the testing accuracy is :- 0.9218036529680366
#
#
#  At random state 46 , the testing accuracy is :- 0.6928897772701313
#  At random state 46 , the testing accuracy is :- 0.6837899543378996
#
#
#  At random state 47 , the testing accuracy is :- 0.8168189605939463
#  At random state 47 , the testing accuracy is :- 0.8350456621004566
#
#
#  At random state 48 , the testing accuracy is :- 0.8485151342090235
#  At random state 48 , the testing accuracy is :- 0.8578767123287672
#
#
#  At random state 49 , the testing accuracy is :- 0.9263278126784694
#  At random state 49 , the testing accuracy is :- 0.928082191780822
#
#
#  At random state 50 , the testing accuracy is :- 0.8480868075385494
#  At random state 50 , the testing accuracy is :- 0.8384703196347032
#
#
#  At random state 51 , the testing accuracy is :- 0.7778412335808109
#  At random state 51 , the testing accuracy is :- 0.7722602739726028
#
#
#  At random state 52 , the testing accuracy is :- 0.8500856653340948
#  At random state 52 , the testing accuracy is :- 0.8521689497716894
#
#
#  At random state 53 , the testing accuracy is :- 0.9201884637350086
#  At random state 53 , the testing accuracy is :- 0.9178082191780822
#
#
#  At random state 54 , the testing accuracy is :- 0.8565105653912051
#  At random state 54 , the testing accuracy is :- 0.8458904109589042
#
#
#  At random state 55 , the testing accuracy is :- 0.8567961165048543
#  At random state 55 , the testing accuracy is :- 0.8635844748858448
#
#
#  At random state 56 , the testing accuracy is :- 0.9106225014277556
#  At random state 56 , the testing accuracy is :- 0.9098173515981736
#
#
#  At random state 57 , the testing accuracy is :- 0.8719303255282695
#  At random state 57 , the testing accuracy is :- 0.8738584474885844
#
#
#  At random state 58 , the testing accuracy is :- 0.854797258709309
#  At random state 58 , the testing accuracy is :- 0.8590182648401826
#
#
#  At random state 59 , the testing accuracy is :- 0.8533695031410623
#  At random state 59 , the testing accuracy is :- 0.848744292237443
#
#
#  At random state 60 , the testing accuracy is :- 0.9240434037692747
#  At random state 60 , the testing accuracy is :- 0.9098173515981736
#
#
#  At random state 61 , the testing accuracy is :- 0.8806396344945745
#  At random state 61 , the testing accuracy is :- 0.8789954337899544
#
#
#  At random state 62 , the testing accuracy is :- 0.8495145631067961
#  At random state 62 , the testing accuracy is :- 0.8624429223744292
#
#
#  At random state 63 , the testing accuracy is :- 0.7785551113649343
#  At random state 63 , the testing accuracy is :- 0.769406392694064
#
#
#  At random state 64 , the testing accuracy is :- 0.9113363792118789
#  At random state 64 , the testing accuracy is :- 0.9058219178082192
#
#
#  At random state 65 , the testing accuracy is :- 0.8529411764705882
#  At random state 65 , the testing accuracy is :- 0.8430365296803652
#
#
#  At random state 66 , the testing accuracy is :- 0.8466590519703027
#  At random state 66 , the testing accuracy is :- 0.8590182648401826
#
#
#  At random state 67 , the testing accuracy is :- 0.9116219303255283
#  At random state 67 , the testing accuracy is :- 0.9143835616438356
#
#
#  At random state 68 , the testing accuracy is :- 0.8499428897772702
#  At random state 68 , the testing accuracy is :- 0.8647260273972602
#
#
#  At random state 69 , the testing accuracy is :- 0.9288977727013136
#  At random state 69 , the testing accuracy is :- 0.9155251141552512
#
#
#  At random state 70 , the testing accuracy is :- 0.8001142204454598
#  At random state 70 , the testing accuracy is :- 0.8082191780821918
#
#
#  At random state 71 , the testing accuracy is :- 0.8339520274129069
#  At random state 71 , the testing accuracy is :- 0.827054794520548
#
#
#  At random state 72 , the testing accuracy is :- 0.8356653340948029
#  At random state 72 , the testing accuracy is :- 0.8453196347031964
#
#
#  At random state 73 , the testing accuracy is :- 0.7641347801256425
#  At random state 73 , the testing accuracy is :- 0.7671232876712328
#
#
#  At random state 74 , the testing accuracy is :- 0.8482295830953741
#  At random state 74 , the testing accuracy is :- 0.8224885844748858
#
#
#  At random state 75 , the testing accuracy is :- 0.857795545402627
#  At random state 75 , the testing accuracy is :- 0.8464611872146118
#
#
#  At random state 76 , the testing accuracy is :- 0.8946316390633924
#  At random state 76 , the testing accuracy is :- 0.8904109589041096
#
#
#  At random state 77 , the testing accuracy is :- 0.895202741290691
#  At random state 77 , the testing accuracy is :- 0.8926940639269406
#
#
#  At random state 78 , the testing accuracy is :- 0.8580810965162764
#  At random state 78 , the testing accuracy is :- 0.860730593607306
#
#
#  At random state 79 , the testing accuracy is :- 0.768275271273558
#  At random state 79 , the testing accuracy is :- 0.7722602739726028
#
#
#  At random state 80 , the testing accuracy is :- 0.8555111364934324
#  At random state 80 , the testing accuracy is :- 0.8504566210045662
#
#
#  At random state 81 , the testing accuracy is :- 0.8873500856653341
#  At random state 81 , the testing accuracy is :- 0.8835616438356164
#
#
#  At random state 82 , the testing accuracy is :- 0.9076242147344374
#  At random state 82 , the testing accuracy is :- 0.9189497716894978
#
#
#  At random state 83 , the testing accuracy is :- 0.9257567104511708
#  At random state 83 , the testing accuracy is :- 0.9178082191780822
#
#
#  At random state 84 , the testing accuracy is :- 0.8513706453455169
#  At random state 84 , the testing accuracy is :- 0.851027397260274
#
#
#  At random state 85 , the testing accuracy is :- 0.9370359794403198
#  At random state 85 , the testing accuracy is :- 0.9389269406392694
#
#
#  At random state 86 , the testing accuracy is :- 0.797829811536265
#  At random state 86 , the testing accuracy is :- 0.7968036529680366
#
#
#  At random state 87 , the testing accuracy is :- 0.8489434608794975
#  At random state 87 , the testing accuracy is :- 0.8470319634703196
#
#
#  At random state 88 , the testing accuracy is :- 0.9176185037121645
#  At random state 88 , the testing accuracy is :- 0.9297945205479452
#
#
#  At random state 89 , the testing accuracy is :- 0.8358081096516277
#  At random state 89 , the testing accuracy is :- 0.8264840182648402
#
#
#  At random state 90 , the testing accuracy is :- 0.8959166190748143
#  At random state 90 , the testing accuracy is :- 0.8761415525114156
#
#
#  At random state 91 , the testing accuracy is :- 0.75214163335237
#  At random state 91 , the testing accuracy is :- 0.7682648401826484
#
#
#  At random state 92 , the testing accuracy is :- 0.8505139920045688
#  At random state 92 , the testing accuracy is :- 0.851027397260274
#
#
#  At random state 93 , the testing accuracy is :- 0.8519417475728155
#  At random state 93 , the testing accuracy is :- 0.8493150684931506
#
#
#  At random state 94 , the testing accuracy is :- 0.9404625928041119
#  At random state 94 , the testing accuracy is :- 0.9360730593607306
#
#
#  At random state 95 , the testing accuracy is :- 0.92390062821245
#  At random state 95 , the testing accuracy is :- 0.9172374429223744
#
#
#  At random state 96 , the testing accuracy is :- 0.8490862364363221
#  At random state 96 , the testing accuracy is :- 0.853310502283105
#
#
#  At random state 97 , the testing accuracy is :- 0.8509423186750429
#  At random state 97 , the testing accuracy is :- 0.851027397260274
#
#
#  At random state 98 , the testing accuracy is :- 0.9073386636207881
#  At random state 98 , the testing accuracy is :- 0.9046803652968036
#
#
#  At random state 99 , the testing accuracy is :- 0.8299543118218161
#  At random state 99 , the testing accuracy is :- 0.8321917808219178

# %% [markdown]
# For AdaBoostClassifier we select Random State - 4

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
ada.score(x_train,y_train)#Training Score
# Out:
# 0.9503141062250143

# %%
ada.score(x_test,y_test)#Testing Score
# Out:
# 0.9474885844748858

# %% [markdown]
# # Lets check with Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    rf.fit(x_train,y_train)
    x_pred=rf.predict(x_train)
    y_pred=rf.predict(x_test)
    print(f" At random state {i} , the testing accuracy is :- {accuracy_score(y_train,x_pred)}")
    print(f" At random state {i} , the testing accuracy is :- {accuracy_score(y_test,y_pred)}")
    print("\n")
# Out:
#  At random state 0 , the testing accuracy is :- 1.0
#  At random state 0 , the testing accuracy is :- 0.976027397260274
#
#
#  At random state 1 , the testing accuracy is :- 1.0
#  At random state 1 , the testing accuracy is :- 0.976027397260274
#
#
#  At random state 2 , the testing accuracy is :- 1.0
#  At random state 2 , the testing accuracy is :- 0.968607305936073
#
#
#  At random state 3 , the testing accuracy is :- 1.0
#  At random state 3 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 4 , the testing accuracy is :- 1.0
#  At random state 4 , the testing accuracy is :- 0.9748858447488584
#
#
#  At random state 5 , the testing accuracy is :- 1.0
#  At random state 5 , the testing accuracy is :- 0.9811643835616438
#
#
#  At random state 6 , the testing accuracy is :- 1.0
#  At random state 6 , the testing accuracy is :- 0.976027397260274
#
#
#  At random state 7 , the testing accuracy is :- 1.0
#  At random state 7 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 8 , the testing accuracy is :- 1.0
#  At random state 8 , the testing accuracy is :- 0.978310502283105
#
#
#  At random state 9 , the testing accuracy is :- 1.0
#  At random state 9 , the testing accuracy is :- 0.9794520547945206
#
#
#  At random state 10 , the testing accuracy is :- 1.0
#  At random state 10 , the testing accuracy is :- 0.9788812785388128
#
#
#  At random state 11 , the testing accuracy is :- 1.0
#  At random state 11 , the testing accuracy is :- 0.978310502283105
#
#
#  At random state 12 , the testing accuracy is :- 1.0
#  At random state 12 , the testing accuracy is :- 0.9731735159817352
#
#
#  At random state 13 , the testing accuracy is :- 1.0
#  At random state 13 , the testing accuracy is :- 0.985730593607306
#
#
#  At random state 14 , the testing accuracy is :- 1.0
#  At random state 14 , the testing accuracy is :- 0.978310502283105
#
#
#  At random state 15 , the testing accuracy is :- 1.0
#  At random state 15 , the testing accuracy is :- 0.9754566210045662
#
#
#  At random state 16 , the testing accuracy is :- 1.0
#  At random state 16 , the testing accuracy is :- 0.9817351598173516
#
#
#  At random state 17 , the testing accuracy is :- 1.0
#  At random state 17 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 18 , the testing accuracy is :- 1.0
#  At random state 18 , the testing accuracy is :- 0.9794520547945206
#
#
#  At random state 19 , the testing accuracy is :- 1.0
#  At random state 19 , the testing accuracy is :- 0.966324200913242
#
#
#  At random state 20 , the testing accuracy is :- 1.0
#  At random state 20 , the testing accuracy is :- 0.9788812785388128
#
#
#  At random state 21 , the testing accuracy is :- 1.0
#  At random state 21 , the testing accuracy is :- 0.9765981735159818
#
#
#  At random state 22 , the testing accuracy is :- 1.0
#  At random state 22 , the testing accuracy is :- 0.9777397260273972
#
#
#  At random state 23 , the testing accuracy is :- 1.0
#  At random state 23 , the testing accuracy is :- 0.9765981735159818
#
#
#  At random state 24 , the testing accuracy is :- 1.0
#  At random state 24 , the testing accuracy is :- 0.9823059360730594
#
#
#  At random state 25 , the testing accuracy is :- 1.0
#  At random state 25 , the testing accuracy is :- 0.9811643835616438
#
#
#  At random state 26 , the testing accuracy is :- 1.0
#  At random state 26 , the testing accuracy is :- 0.9748858447488584
#
#
#  At random state 27 , the testing accuracy is :- 1.0
#  At random state 27 , the testing accuracy is :- 0.9771689497716894
#
#
#  At random state 28 , the testing accuracy is :- 1.0
#  At random state 28 , the testing accuracy is :- 0.9823059360730594
#
#
#  At random state 29 , the testing accuracy is :- 0.9998572244431754
#  At random state 29 , the testing accuracy is :- 0.978310502283105
#
#
#  At random state 30 , the testing accuracy is :- 1.0
#  At random state 30 , the testing accuracy is :- 0.9777397260273972
#
#
#  At random state 31 , the testing accuracy is :- 1.0
#  At random state 31 , the testing accuracy is :- 0.9788812785388128
#
#
#  At random state 32 , the testing accuracy is :- 1.0
#  At random state 32 , the testing accuracy is :- 0.9828767123287672
#
#
#  At random state 33 , the testing accuracy is :- 1.0
#  At random state 33 , the testing accuracy is :- 0.9800228310502284
#
#
#  At random state 34 , the testing accuracy is :- 1.0
#  At random state 34 , the testing accuracy is :- 0.9771689497716894
#
#
#  At random state 35 , the testing accuracy is :- 1.0
#  At random state 35 , the testing accuracy is :- 0.976027397260274
#
#
#  At random state 36 , the testing accuracy is :- 1.0
#  At random state 36 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 37 , the testing accuracy is :- 1.0
#  At random state 37 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 38 , the testing accuracy is :- 1.0
#  At random state 38 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 39 , the testing accuracy is :- 1.0
#  At random state 39 , the testing accuracy is :- 0.9817351598173516
#
#
#  At random state 40 , the testing accuracy is :- 1.0
#  At random state 40 , the testing accuracy is :- 0.9771689497716894
#
#
#  At random state 41 , the testing accuracy is :- 1.0
#  At random state 41 , the testing accuracy is :- 0.9788812785388128
#
#
#  At random state 42 , the testing accuracy is :- 1.0
#  At random state 42 , the testing accuracy is :- 0.9714611872146118
#
#
#  At random state 43 , the testing accuracy is :- 1.0
#  At random state 43 , the testing accuracy is :- 0.9800228310502284
#
#
#  At random state 44 , the testing accuracy is :- 1.0
#  At random state 44 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 45 , the testing accuracy is :- 1.0
#  At random state 45 , the testing accuracy is :- 0.9840182648401826
#
#
#  At random state 46 , the testing accuracy is :- 1.0
#  At random state 46 , the testing accuracy is :- 0.9811643835616438
#
#
#  At random state 47 , the testing accuracy is :- 1.0
#  At random state 47 , the testing accuracy is :- 0.9748858447488584
#
#
#  At random state 48 , the testing accuracy is :- 1.0
#  At random state 48 , the testing accuracy is :- 0.9817351598173516
#
#
#  At random state 49 , the testing accuracy is :- 1.0
#  At random state 49 , the testing accuracy is :- 0.9771689497716894
#
#
#  At random state 50 , the testing accuracy is :- 1.0
#  At random state 50 , the testing accuracy is :- 0.9731735159817352
#
#
#  At random state 51 , the testing accuracy is :- 1.0
#  At random state 51 , the testing accuracy is :- 0.9748858447488584
#
#
#  At random state 52 , the testing accuracy is :- 1.0
#  At random state 52 , the testing accuracy is :- 0.9800228310502284
#
#
#  At random state 53 , the testing accuracy is :- 1.0
#  At random state 53 , the testing accuracy is :- 0.9777397260273972
#
#
#  At random state 54 , the testing accuracy is :- 1.0
#  At random state 54 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 55 , the testing accuracy is :- 1.0
#  At random state 55 , the testing accuracy is :- 0.9777397260273972
#
#
#  At random state 56 , the testing accuracy is :- 1.0
#  At random state 56 , the testing accuracy is :- 0.976027397260274
#
#
#  At random state 57 , the testing accuracy is :- 1.0
#  At random state 57 , the testing accuracy is :- 0.9754566210045662
#
#
#  At random state 58 , the testing accuracy is :- 1.0
#  At random state 58 , the testing accuracy is :- 0.9708904109589042
#
#
#  At random state 59 , the testing accuracy is :- 1.0
#  At random state 59 , the testing accuracy is :- 0.9800228310502284
#
#
#  At random state 60 , the testing accuracy is :- 1.0
#  At random state 60 , the testing accuracy is :- 0.9754566210045662
#
#
#  At random state 61 , the testing accuracy is :- 1.0
#  At random state 61 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 62 , the testing accuracy is :- 1.0
#  At random state 62 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 63 , the testing accuracy is :- 1.0
#  At random state 63 , the testing accuracy is :- 0.9771689497716894
#
#
#  At random state 64 , the testing accuracy is :- 1.0
#  At random state 64 , the testing accuracy is :- 0.9788812785388128
#
#
#  At random state 65 , the testing accuracy is :- 1.0
#  At random state 65 , the testing accuracy is :- 0.976027397260274
#
#
#  At random state 66 , the testing accuracy is :- 1.0
#  At random state 66 , the testing accuracy is :- 0.9823059360730594
#
#
#  At random state 67 , the testing accuracy is :- 1.0
#  At random state 67 , the testing accuracy is :- 0.976027397260274
#
#
#  At random state 68 , the testing accuracy is :- 1.0
#  At random state 68 , the testing accuracy is :- 0.9771689497716894
#
#
#  At random state 69 , the testing accuracy is :- 1.0
#  At random state 69 , the testing accuracy is :- 0.9765981735159818
#
#
#  At random state 70 , the testing accuracy is :- 1.0
#  At random state 70 , the testing accuracy is :- 0.9788812785388128
#
#
#  At random state 71 , the testing accuracy is :- 1.0
#  At random state 71 , the testing accuracy is :- 0.976027397260274
#
#
#  At random state 72 , the testing accuracy is :- 1.0
#  At random state 72 , the testing accuracy is :- 0.9771689497716894
#
#
#  At random state 73 , the testing accuracy is :- 1.0
#  At random state 73 , the testing accuracy is :- 0.9817351598173516
#
#
#  At random state 74 , the testing accuracy is :- 1.0
#  At random state 74 , the testing accuracy is :- 0.9834474885844748
#
#
#  At random state 75 , the testing accuracy is :- 1.0
#  At random state 75 , the testing accuracy is :- 0.973744292237443
#
#
#  At random state 76 , the testing accuracy is :- 1.0
#  At random state 76 , the testing accuracy is :- 0.9800228310502284
#
#
#  At random state 77 , the testing accuracy is :- 1.0
#  At random state 77 , the testing accuracy is :- 0.9765981735159818
#
#
#  At random state 78 , the testing accuracy is :- 1.0
#  At random state 78 , the testing accuracy is :- 0.9703196347031964
#
#
#  At random state 79 , the testing accuracy is :- 1.0
#  At random state 79 , the testing accuracy is :- 0.9794520547945206
#
#
#  At random state 80 , the testing accuracy is :- 1.0
#  At random state 80 , the testing accuracy is :- 0.976027397260274
#
#
#  At random state 81 , the testing accuracy is :- 1.0
#  At random state 81 , the testing accuracy is :- 0.9754566210045662
#
#
#  At random state 82 , the testing accuracy is :- 1.0
#  At random state 82 , the testing accuracy is :- 0.9794520547945206
#
#
#  At random state 83 , the testing accuracy is :- 1.0
#  At random state 83 , the testing accuracy is :- 0.9771689497716894
#
#
#  At random state 84 , the testing accuracy is :- 1.0
#  At random state 84 , the testing accuracy is :- 0.9777397260273972
#
#
#  At random state 85 , the testing accuracy is :- 1.0
#  At random state 85 , the testing accuracy is :- 0.976027397260274
#
#
#  At random state 86 , the testing accuracy is :- 1.0
#  At random state 86 , the testing accuracy is :- 0.980593607305936
#
#
#  At random state 87 , the testing accuracy is :- 1.0
#  At random state 87 , the testing accuracy is :- 0.9828767123287672
#
#
#  At random state 88 , the testing accuracy is :- 1.0
#  At random state 88 , the testing accuracy is :- 0.9834474885844748
#
#
#  At random state 89 , the testing accuracy is :- 1.0
#  At random state 89 , the testing accuracy is :- 0.978310502283105
#
#
#  At random state 90 , the testing accuracy is :- 1.0
#  At random state 90 , the testing accuracy is :- 0.9771689497716894
#
#
#  At random state 91 , the testing accuracy is :- 1.0
#  At random state 91 , the testing accuracy is :- 0.9765981735159818
#
#
#  At random state 92 , the testing accuracy is :- 1.0
#  At random state 92 , the testing accuracy is :- 0.9811643835616438
#
#
#  At random state 93 , the testing accuracy is :- 1.0
#  At random state 93 , the testing accuracy is :- 0.9743150684931506
#
#
#  At random state 94 , the testing accuracy is :- 1.0
#  At random state 94 , the testing accuracy is :- 0.9840182648401826
#
#
#  At random state 95 , the testing accuracy is :- 1.0
#  At random state 95 , the testing accuracy is :- 0.9703196347031964
#
#
#  At random state 96 , the testing accuracy is :- 1.0
#  At random state 96 , the testing accuracy is :- 0.978310502283105
#
#
#  At random state 97 , the testing accuracy is :- 1.0
#  At random state 97 , the testing accuracy is :- 0.9765981735159818
#
#
#  At random state 98 , the testing accuracy is :- 1.0
#  At random state 98 , the testing accuracy is :- 0.9771689497716894
#
#
#  At random state 99 , the testing accuracy is :- 1.0
#  At random state 99 , the testing accuracy is :- 0.9788812785388128

# %% [markdown]
# For AdaBoostClassifier we select Random State - 13

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=13)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(x_train,y_train)
# Out:
# 1.0

# %%
rf.score(x_test,y_test)
# Out:
# 0.9863013698630136

# %% [markdown]
# # Do Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_param={
    'criterion':['ginni','entropy'],
    'max_depth': range(10,15),
    'min_samples_leaf':range(2,6),
    'min_samples_split':range(3,8),
    'max_leaf_nodes':range(5,10)}

# %%
grid_search=GridSearchCV(estimator=rf,
                         param_grid=grid_param,
                         cv=5,
                        n_jobs=-1)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['ginni', 'entropy'],
#                          'max_depth': range(10, 15),
#                          'max_leaf_nodes': range(5, 10),
#                          'min_samples_leaf': range(2, 6),
#                          'min_samples_split': range(3, 8)})

# %%
cnn=RandomForestClassifier(criterion='gini',max_depth=12,max_leaf_nodes=4,min_samples_split= 5)

# %%
best_parameter=grid_search.best_params_
print(best_parameter)
# Out:
# {'criterion': 'entropy', 'max_depth': 13, 'max_leaf_nodes': 9, 'min_samples_leaf': 4, 'min_samples_split': 3}

# %%
#Train the model
cnn.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=12, max_leaf_nodes=4, min_samples_split=5)

# %%
cnn.score(x_train,y_train)
# Out:
# 0.8596516276413478

# %%
cnn.score(x_test,y_test)
# Out:
# 0.8590182648401826

# %% [markdown]
# # ROC_AUC Curve

# %%
from sklearn.metrics import roc_curve, auc

# %%
#predicting the data
y_pred_cnb = rf.predict(x_test)
y_prob_pred_cnb = rf.predict_proba(x_test)

# %%
# roc curve for classes
fpr = {}
tpr = {}
thresh ={}

n_class = 4

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, y_prob_pred_cnb[:,i], pos_label=i)
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--', label='Class 1 vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--', label='Class 2 vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--', label='Class 3 vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--', label='Class 4 vs Rest')


plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')

# %% [markdown]
# # Lets Save Our Model

# %%
import pickle
filename='Zomato.'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# # Conclusion

# %%
loaded_model=pickle.load(open('Zomato','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 98.63013698630137

# %%
# batch  No - ds0522
# Data Trained
